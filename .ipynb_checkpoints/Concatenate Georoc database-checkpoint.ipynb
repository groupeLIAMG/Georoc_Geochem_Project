# %% [markdown]
# To do:
#
# - remove files that are not location -DONE
#
# - check for duplicates using ID -DONE
#
# - add column with location from filename -DONE
#
# - do data QA/QC
#
# - Unnamed 171?

# %% [markdown]
# # Concatenation

# %%
# %matplotlib inline

import time

import pandas as pd
import numpy as np
import os
import re
from itertools import count
from copy import deepcopy

pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows', 150)

# %%
dir_ = os.curdir + '/Georoc_files'
files = os.listdir(dir_)

nb_data = 0

for file, file_no in zip(files[:5], count()):

    file = pd.read_csv(dir_ + '/' + file, encoding='iso-8859-1', dtype=object)

    index = np.where(file.CITATIONS.values == 'References:')[0][0]
    file = file[:index]
    file.insert(0, 'FILENAME', files[file_no])

    nb_data += file.shape[0]
    files[file_no] = file

# %%
master_file = pd.DataFrame(index=np.arange(0, nb_data), columns=files[0].axes[1])
current_row = 0

row_no = 0
for file in files[:5]:
    for _, row in file.iterrows():
        master_file.loc[row_no] = row
        row_no += 1

file = None

# %%
master_file = master_file.drop_duplicates(subset='UNIQUE_ID')

# %%
print ('Shape of the dataset after transformation:' + str(master_file.shape))
master_file[0:5]
# Out:
# Shape of the dataset after transformation:(4689, 173)
#            FILENAME       CITATIONS      TECTONIC SETTING  \
# 0  ADRIA_DOMAIN.csv  [14868][14875]  INTRAPLATE VOLCANICS
# 1  ADRIA_DOMAIN.csv         [11431]  INTRAPLATE VOLCANICS
# 2  ADRIA_DOMAIN.csv         [11431]  INTRAPLATE VOLCANICS
# 3  ADRIA_DOMAIN.csv         [11431]  INTRAPLATE VOLCANICS
# 4  ADRIA_DOMAIN.csv         [11431]  INTRAPLATE VOLCANICS
#
#                                             LOCATION LOCATION COMMENT  \
# 0  ADRIA DOMAIN / SOUTHERN ALPS / VENETO VOLCANIC...      CALCERANICA
# 1  ADRIA DOMAIN / ADRIATIC FORELAND / ABRUZZO / M...              NaN
# 2  ADRIA DOMAIN / ADRIATIC FORELAND / ABRUZZO / M...              NaN
# 3  ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...              NaN
# 4  ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...              NaN
#
#   LATITUDE MIN LATITUDE MAX LONGITUDE MIN LONGITUDE MAX LAND OR SEA  \
# ...

# %%
print(pd.Series(master_file.axes[1]))
# Out:
# 0              FILENAME
# 1             CITATIONS
# 2      TECTONIC SETTING
# 3              LOCATION
# 4      LOCATION COMMENT
# 5          LATITUDE MIN
# 6          LATITUDE MAX
# 7         LONGITUDE MIN
# 8         LONGITUDE MAX
# 9           LAND OR SEA
# 10        ELEVATION MIN
# 11        ELEVATION MAX
# 12          SAMPLE NAME
# 13            ROCK NAME
# 14      MIN. AGE (YRS.)
# 15      MAX. AGE (YRS.)
# 16                GEOL.
# 17                  AGE
# 18         ERUPTION DAY
# 19       ERUPTION MONTH
# 20        ERUPTION YEAR
# 21         ROCK TEXTURE
# 22            ROCK TYPE
# 23      DRILL DEPTH MIN
# 24        DRILL DEPTHAX
# 25           ALTERATION
# 26              MINERAL
# 27             MATERIAL
# 28            SIO2(WT%)
# 29            TIO2(WT%)
# 30            B2O3(WT%)
# 31           AL2O3(WT%)
# 32           CR2O3(WT%)
# 33           FE2O3(WT%)
# 34             FEO(WT%)
# 35            FEOT(WT%)
# 36             CAO(WT%)
# 37             MGO(WT%)
# ...

# %%
master_file['FILENAME'].value_counts()
# Out:
# AEOLIAN_ARC.csv           2353
# AEGEAN_ARC.csv            1962
# ADRIA_DOMAIN.csv           338
# AHU_VOLCANIC_FIELD.csv      32
# AGULHAS_RIDGE.csv            4
# Name: FILENAME, dtype: int64

# %%
master_file['LOCATION'].value_counts()
# Out:
# AEOLIAN ARC / ITALY / STROMBOLI / STROMBOLI / TYRRHENIAN SEA                                                     932
# AEGEAN ARC / SOUTH AEGEAN VOLCANIC ARC / SANTORINI / AEGEAN SEA                                                  544
# AEGEAN ARC / SOUTH AEGEAN VOLCANIC ARC / NISYROS / NISYROS / AEGEAN SEA                                          362
# AEOLIAN ARC / ITALY / VULCANO / LA FOSSA DI VULCANO / TYRRHENIAN SEA                                             204
# ADRIA DOMAIN / SOUTHERN ALPS / VENETO VOLCANIC PROVINCE                                                          186
# AEOLIAN ARC / ITALY / LIPARI / TYRRHENIAN SEA                                                                    148
# AEOLIAN ARC / ITALY / VULCANO / LA FOSSA / TYRRHENIAN SEA                                                        109
# ADRIA DOMAIN / SOUTHERN ALPS / VENETO VOLCANIC PROVINCE / MONTI LESSINI                                          107
# ...

# %%
master_file['ROCK TYPE'].value_counts()
# Out:
# VOLCANIC ROCK       4335
# PLUTONIC ROCK        164
# MANTLE XENOLITH      106
# METAMORPHIC ROCK      76
# VEIN                   7
# SEDIMENTARY ROCK       1
# Name: ROCK TYPE, dtype: int64

# %%
master_file['ROCK NAME'].value_counts()
# Out:
# NOT GIVEN [4670]                                                                          136
# NOT GIVEN [3932]                                                                           85
# NOT GIVEN [13023]                                                                          63
# NOT GIVEN [5522]                                                                           61
# RHYOLITE [14712]                                                                           51
# ANDESITE, BASALTIC [10230]                                                                 50
# ANDESITE, BASALTIC [13283]                                                                 48
# SHOSHONITE [4673]                                                                          48
# ANDESITE, BASALTIC, CALC-ALKALINE [4671]                                                   47
# NOT GIVEN [15108]                                                                          46
# ...

# %%
master_file.dtypes
# Out:
# FILENAME            object
# CITATIONS           object
# TECTONIC SETTING    object
# LOCATION            object
# LOCATION COMMENT    object
# LATITUDE MIN        object
# LATITUDE MAX        object
# LONGITUDE MIN       object
# LONGITUDE MAX       object
# LAND OR SEA         object
# ELEVATION MIN       object
# ELEVATION MAX       object
# SAMPLE NAME         object
# ROCK NAME           object
# MIN. AGE (YRS.)     object
# MAX. AGE (YRS.)     object
# GEOL.               object
# AGE                 object
# ERUPTION DAY        object
# ERUPTION MONTH      object
# ERUPTION YEAR       object
# ROCK TEXTURE        object
# ROCK TYPE           object
# DRILL DEPTH MIN     object
# DRILL DEPTHAX       object
# ALTERATION          object
# MINERAL             object
# MATERIAL            object
# SIO2(WT%)           object
# TIO2(WT%)           object
# B2O3(WT%)           object
# AL2O3(WT%)          object
# CR2O3(WT%)          object
# FE2O3(WT%)          object
# ...

# %% [markdown]
# # QA/QC

# %%
filtered_file = deepcopy(master_file)

# %%
a = filtered_file.iloc[:, 28:173].count(axis=0)
a = len(filtered_file.index) - a
a[a != 0]
# Out:
# SIO2(WT%)           504
# TIO2(WT%)           544
# B2O3(WT%)          4689
# AL2O3(WT%)          604
# CR2O3(WT%)         4654
# FE2O3(WT%)         2206
# FEO(WT%)           2256
# FEOT(WT%)          3058
# CAO(WT%)            578
# MGO(WT%)            616
# MNO(WT%)            723
# NIO(WT%)           4689
# K2O(WT%)            535
# NA2O(WT%)           629
# P2O5(WT%)           759
# H2O(WT%)           4180
# H2OP(WT%)          4140
# H2OM(WT%)          4433
# H2OT(WT%)          4689
# CO2(WT%)           4539
# CO1(WT%)           4689
# F(WT%)             4650
# CL(WT%)            4585
# CL2(WT%)           4689
# OH(WT%)            4689
# CH4(WT%)           4689
# SO2(WT%)           4689
# SO3(WT%)           4624
# SO4(WT%)           4666
# S(WT%)             4635
# LOI(WT%)           2332
# VOLATILES(WT%)     4689
# O(WT%)             4689
# OTHERS(WT%)        4689
# HE(CCM/G)          4689
# HE(CCMSTP/G)       4664
# HE3(CCMSTP/G)      4689
# HE3(AT/G)          4689
# ...

# %%
value = 2000

######### Removing columns with too many missing data
filtered_file.drop(a[a > value].index.values, axis=1, inplace=True)

######## Removing samples with missing data
filtered_file.dropna(subset=a[a <= value].index.values, inplace=True)

# %%
print ('Shape of the df dataset after transformation:', str(filtered_file.shape), 'Out of:', str(master_file.shape))
filtered_file.head()
# Out:
# Shape of the df dataset after transformation: (1955, 47) Out of: (4689, 173)
#            FILENAME       CITATIONS      TECTONIC SETTING  \
# 0  ADRIA_DOMAIN.csv  [14868][14875]  INTRAPLATE VOLCANICS
# 1  ADRIA_DOMAIN.csv         [11431]  INTRAPLATE VOLCANICS
# 3  ADRIA_DOMAIN.csv         [11431]  INTRAPLATE VOLCANICS
# 4  ADRIA_DOMAIN.csv         [11431]  INTRAPLATE VOLCANICS
# 5  ADRIA_DOMAIN.csv         [11431]  INTRAPLATE VOLCANICS
#
#                                             LOCATION LOCATION COMMENT  \
# 0  ADRIA DOMAIN / SOUTHERN ALPS / VENETO VOLCANIC...      CALCERANICA
# 1  ADRIA DOMAIN / ADRIATIC FORELAND / ABRUZZO / M...              NaN
# 3  ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...              NaN
# 4  ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...              NaN
# 5  ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...              NaN
#
#   LATITUDE MIN LATITUDE MAX LONGITUDE MIN LONGITUDE MAX LAND OR SEA  \
# ...
