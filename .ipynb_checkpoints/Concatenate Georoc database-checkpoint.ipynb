# %% [markdown]
# # Discriminating rock samples' tectonic settings using machine learning
#
# (...)

# %%
import sys
import getpass
print("User :", getpass.getuser())
print("Python version :", sys.version)
# %load_ext watermark
# %watermark -i -v -m -p pandas,numpy,matplotlib,sklearn
# Out:
# User : simonje
# Python version : 3.6.1 | packaged by conda-forge | (default, May 23 2017, 14:21:39) [MSC v.1900 64 bit (AMD64)]
# 2017-07-12T09:27:40-04:00
#
# CPython 3.6.1
# IPython 6.1.0
#
# pandas 0.20.2
# numpy 1.13.0
# matplotlib 2.0.0
# sklearn 0.18.1
#
# compiler   : MSC v.1900 64 bit (AMD64)
# system     : Windows
# release    : 7
# machine    : AMD64
# processor  : Intel64 Family 6 Model 26 Stepping 5, GenuineIntel
# CPU cores  : 16
# interpreter: 64bit

# %%
# %matplotlib inline

import time
import datetime

import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import random as rd
import numpy as np
import os
import re

from itertools import count, cycle
from sklearn.svm import SVC
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (f1_score, make_scorer, confusion_matrix, mean_absolute_error, 
                             median_absolute_error, mean_squared_error)
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, LeavePGroupsOut, cross_val_predict

pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows', 150)

from matplotlib.colors import Normalize

class MidpointNormalize(Normalize):
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y))

# %% [markdown]
# ## Concatenate Georoc database

# %% [markdown]
# ### Concatenation
#
# Concatenation of the *.csv* files contained in */Georoc_files* into a single *master.csv* file at source.

# %%
# Files from /Georoc_files are opened one by one and stored as DataFrames in the *files* list.

dir_ = os.curdir + '/Georoc_files'
files = os.listdir(dir_)

nb_data = 0

for file, file_no in zip(files, count()):

    file = pd.read_csv(dir_ + '/' + file, encoding='iso-8859-1', dtype=object)

    index = np.where(file.CITATIONS.values == 'References:')[0][0]
    file = file[:index]
    file.insert(0, 'FILENAME', files[file_no])

    nb_data += file.shape[0]
    files[file_no] = file

# %%
# Files are regrouped in *master_file*. *nb_data* was needed because of the *.append* method being resources-expensive.

master_file = pd.DataFrame(index=np.arange(0, nb_data), columns=files[0].axes[1])
current_row = 0

row_no = 0
for file in files:
    for _, row in file.iterrows():
        master_file.loc[row_no] = row
        row_no += 1

file = None

# %%
# Volcanic rocks, duplicates and unnecessary columns are removed, and tectonics settings are formatted identically.

master_file = master_file[master_file['ROCK TYPE'] == 'VOLCANIC ROCK']
master_file.drop_duplicates(subset='UNIQUE_ID', inplace=True)
master_file.drop('Unnamed: 171', axis=1, inplace=True)

master_file['TECTONIC SETTING'] = master_file['TECTONIC SETTING'].str.upper()

master_file = master_file.reset_index(drop=True)  # Removing data messes with the indexing

# %%
# Data under limit of detection is formatted to half the limit of detection.

for row_no, row in master_file.iloc[:, 29:171].iterrows():
    for col_no, data in zip(count(), row):
        data = str(data).strip()

        if data[0] == '-':  # Data under limit of detection has format *-data*. *<data* is not used
            master_file.iloc[row_no, col_no + 29] = -float(data) / 2

        # elif data[0] == '<':
        #     print(master_file.iloc[row_no, col_no + 29])
        #     master_file.iloc[row_no, col_no + 29] = float(data.lstrip(['<', '='])) / 2
        #     print(master_file.iloc[row_no, col_no + 29])
        # else:
        #     data = float(data)  # failsafe

# %%
# Data is saved in *master.csv* at source, allowing it to be reloaded for future uses.

master_file.to_csv(os.curdir + '/master.csv', index=False)

# %% [markdown]
# ### Load master

# %%
# Should be used on reloads to produce faster results.

master_file = pd.read_csv(os.curdir + '/master.csv', encoding='iso-8859-1', dtype=object)

# %% [markdown]
# ### Statistics

# %%
print ('Shape of the dataset after transformation:' + str(master_file.shape))
master_file.head()
# Out:
# Shape of the dataset after transformation:(273918, 172)
#            FILENAME CITATIONS      TECTONIC SETTING  \
# 0  ADRIA_DOMAIN.csv   [11431]  INTRAPLATE VOLCANICS
# 1  ADRIA_DOMAIN.csv   [11431]  INTRAPLATE VOLCANICS
# 2  ADRIA_DOMAIN.csv   [11431]  INTRAPLATE VOLCANICS
# 3  ADRIA_DOMAIN.csv   [11689]  INTRAPLATE VOLCANICS
# 4  ADRIA_DOMAIN.csv   [11689]  INTRAPLATE VOLCANICS
#
#                                             LOCATION       LOCATION COMMENT  \
# 0  ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...                    NaN
# 1  ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...                    NaN
# 2  ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...                    NaN
# 3  ADRIA DOMAIN / SOUTHERN ALPS / VENETO VOLCANIC...                    NaN
# 4  ADRIA DOMAIN / SOUTHERN ALPS / VENETO VOLCANIC...  WESTERN MONTI LESSINI
#
#   LATITUDE MIN LATITUDE MAX LONGITUDE MIN LONGITUDE MAX LAND OR SEA  \
# 0         39.5         40.5            16          16.5   SUBAERIAL
# 1         39.5         40.5            16          16.5   SUBAERIAL
# 2         39.5         40.5            16          16.5   SUBAERIAL
# 3        45.83        45.83         11.17         11.17   SUBAERIAL
# 4        45.68        45.68         11.22         11.22   SUBAERIAL
#
#   ELEVATION MIN ELEVATION MAX     SAMPLE NAME                  ROCK NAME  \
# 0           NaN           NaN    s 88 [11431]          NOT GIVEN [11431]
# 1           NaN           NaN   s 124 [11431]          NOT GIVEN [11431]
# 2           NaN           NaN   s 125 [11431]          NOT GIVEN [11431]
# 3           NaN           NaN  s PDF1 [11689]  NEPHELINITE, MELA [11689]
# 4           NaN           NaN   s 12D [11689]  NEPHELINITE, MELA [11689]
#
#   MIN. AGE (YRS.) MAX. AGE (YRS.) GEOL.                AGE ERUPTION DAY  \
# 0             NaN             NaN   NaN  PALEOGENE [11431]          NaN
# 1             NaN             NaN   NaN  PALEOGENE [11431]          NaN
# 2             NaN             NaN   NaN  PALEOGENE [11431]          NaN
# 3             NaN             NaN   NaN  PALEOGENE [11689]          NaN
# 4             NaN             NaN   NaN  PALEOGENE [11689]          NaN
#
#   ERUPTION MONTH ERUPTION YEAR ROCK TEXTURE      ROCK TYPE DRILL DEPTH MIN  \
# 0            NaN           NaN          NaN  VOLCANIC ROCK             NaN
# 1            NaN           NaN          NaN  VOLCANIC ROCK             NaN
# 2            NaN           NaN          NaN  VOLCANIC ROCK             NaN
# 3            NaN           NaN          NaN  VOLCANIC ROCK             NaN
# 4            NaN           NaN          NaN  VOLCANIC ROCK             NaN
#
#   DRILL DEPTHAX ALTERATION MINERAL             MATERIAL SIO2(WT%) TIO2(WT%)  \
# 0           NaN        NaN     NaN  WHOLE_ROCK [11431]      44.59      2.79
# 1           NaN        NaN     NaN  WHOLE_ROCK [11431]      40.38      2.79
# 2           NaN        NaN     NaN  WHOLE_ROCK [11431]      42.56      2.78
# 3           NaN        NaN     NaN  WHOLE_ROCK [11689]      38.48      2.22
# 4           NaN        NaN     NaN  WHOLE_ROCK [11689]       40.2      2.48
#
#   B2O3(WT%) AL2O3(WT%) CR2O3(WT%) FE2O3(WT%) FEO(WT%) FEOT(WT%) CAO(WT%)  \
# 0       NaN      11.06        NaN        NaN      NaN     11.79    10.95
# 1       NaN      10.27        NaN        NaN      NaN      9.25    16.76
# 2       NaN      10.45        NaN        NaN      NaN      8.88    15.98
# 3       NaN      12.31        NaN       1.43     9.55       NaN    13.86
# 4       NaN       10.7        NaN       1.39      9.3       NaN    11.41
#
#   MGO(WT%) MNO(WT%) NIO(WT%) K2O(WT%) NA2O(WT%) P2O5(WT%) H2O(WT%) H2OP(WT%)  \
# 0     8.86     0.18      NaN     2.37      3.19      0.79      NaN       NaN
# 1     9.18     0.16      NaN     0.74      5.09      0.82      NaN       NaN
# 2    10.05     0.14      NaN      1.5      3.91      0.83      NaN       NaN
# 3     9.87     0.15      NaN     1.09      1.78      1.19      NaN       NaN
# 4     16.7     0.15      NaN     1.15      1.53      1.64      NaN       NaN
#
#   H2OM(WT%) H2OT(WT%) CO2(WT%) CO1(WT%) F(WT%) CL(WT%) CL2(WT%) OH(WT%)  \
# 0       NaN       NaN      NaN      NaN    NaN     NaN      NaN     NaN
# 1       NaN       NaN      NaN      NaN    NaN     NaN      NaN     NaN
# 2       NaN       NaN      NaN      NaN    NaN     NaN      NaN     NaN
# 3       NaN       NaN      NaN      NaN    NaN     NaN      NaN     NaN
# 4       NaN       NaN      NaN      NaN    NaN     NaN      NaN     NaN
#
#   CH4(WT%) SO2(WT%) SO3(WT%) SO4(WT%) S(WT%) LOI(WT%) VOLATILES(WT%) O(WT%)  \
# 0      NaN      NaN      NaN      NaN    NaN     2.11            NaN    NaN
# 1      NaN      NaN      NaN      NaN    NaN     3.52            NaN    NaN
# 2      NaN      NaN      NaN      NaN    NaN     1.92            NaN    NaN
# 3      NaN      NaN      NaN      NaN    NaN     8.08            NaN    NaN
# 4      NaN      NaN      NaN      NaN    NaN     3.35            NaN    NaN
#
#   OTHERS(WT%) HE(CCM/G) HE(CCMSTP/G) HE3(CCMSTP/G) HE3(AT/G) HE4(CCM/G)  \
# 0         NaN       NaN          NaN           NaN       NaN        NaN
# 1         NaN       NaN          NaN           NaN       NaN        NaN
# 2         NaN       NaN          NaN           NaN       NaN        NaN
# 3         NaN       NaN          NaN           NaN       NaN        NaN
# 4         NaN       NaN          NaN           NaN       NaN        NaN
#
#   HE4(CCMSTP/G) HE4(AT/G) HE4(MOLE/G) HE4(NCC/G) HE(NCC/G) LI(PPM) BE(PPM)  \
# 0           NaN       NaN         NaN        NaN       NaN     NaN     NaN
# 1           NaN       NaN         NaN        NaN       NaN     NaN     NaN
# 2           NaN       NaN         NaN        NaN       NaN     NaN     NaN
# 3           NaN       NaN         NaN        NaN       NaN     NaN     NaN
# 4           NaN       NaN         NaN        NaN       NaN     NaN     NaN
#
#   B(PPM)    ...    GE(PPM) AS(PPM) SE(PPM) BR(PPM) RB(PPM) SR(PPM) Y(PPM)  \
# 0    NaN    ...        NaN     NaN     NaN     NaN      31     575   26.4
# 1    NaN    ...        NaN     NaN     NaN     NaN      18     688   26.4
# 2    NaN    ...        NaN     NaN     NaN     NaN      22     680   23.7
# 3    NaN    ...        NaN     NaN     NaN     NaN      32    1036   24.1
# 4    NaN    ...        NaN     NaN     NaN     NaN      25     890   25.7
#
#   ZR(PPM) NB(PPM) MO(PPM) RU(PPM) RH(PPM) PD(PPM) AG(PPM) CD(PPM) IN(PPM)  \
# 0     269      74     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     284      89     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     282      68     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     284      79     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     266      73     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   SN(PPM) SB(PPM) TE(PPM) I(PPM) CS(PPM) BA(PPM) LA(PPM) CE(PPM) PR(PPM)  \
# 0     NaN     NaN     NaN    NaN     NaN     707    52.5     101      12
# 1     NaN     NaN     NaN    NaN     NaN     391    67.1     129      16
# 2     NaN     NaN     NaN    NaN     NaN     673      54     109    13.5
# 3     NaN     NaN     NaN    NaN     NaN     468    65.9     135    15.9
# 4     NaN     NaN     NaN    NaN     NaN     738    69.7     138    16.3
#
#   ND(PPM) SM(PPM) EU(PPM) GD(PPM) TB(PPM) DY(PPM) HO(PPM) ER(PPM) TM(PPM)  \
# 0    50.9      10    2.86     9.1    1.25    5.84    0.98    2.61    0.32
# 1    66.2    12.5    3.61    10.5    1.41    6.74    1.01    2.58     0.3
# 2      58    11.3    3.43      10    1.34    5.86    0.95    2.32    0.26
# 3    60.8    11.1    3.19    10.9     1.3    6.53    0.98    2.35    0.28
# 4    64.1    11.9    3.51    10.9    1.34    6.64    1.03    2.41    0.29
#
#   YB(PPM) LU(PPM) HF(PPM) TA(PPM) W(PPM) RE(PPM) OS(PPM) IR(PPM) PT(PPM)  \
# 0    1.79    0.25     NaN     NaN    NaN     NaN     NaN     NaN     NaN
# 1    1.75    0.24     NaN     NaN    NaN     NaN     NaN     NaN     NaN
# 2    1.65    0.22     NaN     NaN    NaN     NaN     NaN     NaN     NaN
# 3    1.67    0.22     NaN     NaN    NaN     NaN     NaN     NaN     NaN
# 4    1.67    0.22     NaN     NaN    NaN     NaN     NaN     NaN     NaN
#
#   AU(PPM) HG(PPM) TL(PPM) PB(PPM) BI(PPM) TH(PPM) U(PPM) ND143_ND144  \
# 0     NaN     NaN     NaN     NaN     NaN     6.4   1.58         NaN
# 1     NaN     NaN     NaN     NaN     NaN    9.06   2.46         NaN
# 2     NaN     NaN     NaN     NaN     NaN    5.79   1.46         NaN
# 3     NaN     NaN     NaN     NaN     NaN    6.39   1.54         NaN
# 4     NaN     NaN     NaN     NaN     NaN    8.05   2.36         NaN
#
#   ND143_ND144_INI EPSILON_ND SR87_SR86 SR87_SR86_INI PB206_PB204  \
# 0             NaN        NaN       NaN           NaN         NaN
# 1             NaN        NaN       NaN           NaN         NaN
# 2             NaN        NaN       NaN           NaN         NaN
# 3             NaN        NaN       NaN           NaN         NaN
# 4             NaN        NaN       NaN           NaN         NaN
#
#   PB206_PB204_INI PB207_PB204 PB207_PB204_INI PB208_PB204 PB208_PB204_INI  \
# 0             NaN         NaN             NaN         NaN             NaN
# 1             NaN         NaN             NaN         NaN             NaN
# 2             NaN         NaN             NaN         NaN             NaN
# 3             NaN         NaN             NaN         NaN             NaN
# 4             NaN         NaN             NaN         NaN             NaN
#
#   OS184_OS188 OS186_OS188 OS187_OS186 OS187_OS188 RE187_OS186 RE187_OS188  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   HF176_HF177 HE3_HE4 HE3_HE4(R/R(A)) HE4_HE3 HE4_HE3(R/R(A)) K40_AR40  \
# 0         NaN     NaN             NaN     NaN             NaN      NaN
# 1         NaN     NaN             NaN     NaN             NaN      NaN
# 2         NaN     NaN             NaN     NaN             NaN      NaN
# 3         NaN     NaN             NaN     NaN             NaN      NaN
# 4         NaN     NaN             NaN     NaN             NaN      NaN
#
#   AR40_K40 UNIQUE_ID
# 0      NaN    336642
# 1      NaN    336643
# 2      NaN    336644
# 3      NaN    487272
# 4      NaN    487273
#
# [5 rows x 172 columns]

# %%
# Column names

pd.Series(master_file.axes[1])
# Out:
# 0              FILENAME
# 1             CITATIONS
# 2      TECTONIC SETTING
# 3              LOCATION
# 4      LOCATION COMMENT
# 5          LATITUDE MIN
# 6          LATITUDE MAX
# 7         LONGITUDE MIN
# 8         LONGITUDE MAX
# 9           LAND OR SEA
# 10        ELEVATION MIN
# 11        ELEVATION MAX
# 12          SAMPLE NAME
# 13            ROCK NAME
# 14      MIN. AGE (YRS.)
# 15      MAX. AGE (YRS.)
# 16                GEOL.
# 17                  AGE
# 18         ERUPTION DAY
# 19       ERUPTION MONTH
# 20        ERUPTION YEAR
# 21         ROCK TEXTURE
# 22            ROCK TYPE
# 23      DRILL DEPTH MIN
# 24        DRILL DEPTHAX
# 25           ALTERATION
# 26              MINERAL
# 27             MATERIAL
# 28            SIO2(WT%)
# 29            TIO2(WT%)
# 30            B2O3(WT%)
# 31           AL2O3(WT%)
# 32           CR2O3(WT%)
# 33           FE2O3(WT%)
# 34             FEO(WT%)
# 35            FEOT(WT%)
# 36             CAO(WT%)
# 37             MGO(WT%)
# 38             MNO(WT%)
# 39             NIO(WT%)
# 40             K2O(WT%)
# 41            NA2O(WT%)
# 42            P2O5(WT%)
# 43             H2O(WT%)
# 44            H2OP(WT%)
# 45            H2OM(WT%)
# 46            H2OT(WT%)
# 47             CO2(WT%)
# 48             CO1(WT%)
# 49               F(WT%)
# 50              CL(WT%)
# 51             CL2(WT%)
# 52              OH(WT%)
# 53             CH4(WT%)
# 54             SO2(WT%)
# 55             SO3(WT%)
# 56             SO4(WT%)
# 57               S(WT%)
# 58             LOI(WT%)
# 59       VOLATILES(WT%)
# 60               O(WT%)
# 61          OTHERS(WT%)
# 62            HE(CCM/G)
# 63         HE(CCMSTP/G)
# 64        HE3(CCMSTP/G)
# 65            HE3(AT/G)
# 66           HE4(CCM/G)
# 67        HE4(CCMSTP/G)
# 68            HE4(AT/G)
# 69          HE4(MOLE/G)
# 70           HE4(NCC/G)
# 71            HE(NCC/G)
# 72              LI(PPM)
# 73              BE(PPM)
# 74               B(PPM)
#              ...
# 97              GE(PPM)
# 98              AS(PPM)
# 99              SE(PPM)
# 100             BR(PPM)
# 101             RB(PPM)
# 102             SR(PPM)
# 103              Y(PPM)
# 104             ZR(PPM)
# 105             NB(PPM)
# 106             MO(PPM)
# 107             RU(PPM)
# 108             RH(PPM)
# 109             PD(PPM)
# 110             AG(PPM)
# 111             CD(PPM)
# 112             IN(PPM)
# 113             SN(PPM)
# 114             SB(PPM)
# 115             TE(PPM)
# 116              I(PPM)
# 117             CS(PPM)
# 118             BA(PPM)
# 119             LA(PPM)
# 120             CE(PPM)
# 121             PR(PPM)
# 122             ND(PPM)
# 123             SM(PPM)
# 124             EU(PPM)
# 125             GD(PPM)
# 126             TB(PPM)
# 127             DY(PPM)
# 128             HO(PPM)
# 129             ER(PPM)
# 130             TM(PPM)
# 131             YB(PPM)
# 132             LU(PPM)
# 133             HF(PPM)
# 134             TA(PPM)
# 135              W(PPM)
# 136             RE(PPM)
# 137             OS(PPM)
# 138             IR(PPM)
# 139             PT(PPM)
# 140             AU(PPM)
# 141             HG(PPM)
# 142             TL(PPM)
# 143             PB(PPM)
# 144             BI(PPM)
# 145             TH(PPM)
# 146              U(PPM)
# 147         ND143_ND144
# 148     ND143_ND144_INI
# 149          EPSILON_ND
# 150           SR87_SR86
# 151       SR87_SR86_INI
# 152         PB206_PB204
# 153     PB206_PB204_INI
# 154         PB207_PB204
# 155     PB207_PB204_INI
# 156         PB208_PB204
# 157     PB208_PB204_INI
# 158         OS184_OS188
# 159         OS186_OS188
# 160         OS187_OS186
# 161         OS187_OS188
# 162         RE187_OS186
# 163         RE187_OS188
# 164         HF176_HF177
# 165             HE3_HE4
# 166     HE3_HE4(R/R(A))
# 167             HE4_HE3
# 168     HE4_HE3(R/R(A))
# 169            K40_AR40
# 170            AR40_K40
# 171           UNIQUE_ID
# dtype: object

# %%
# Samples contained per file

master_file['FILENAME'].value_counts()
# Out:
# APENNINIC-MAGHREBIDES_CHAIN.csv                        10571
# ICELAND.csv                                             9163
# HAWAIIAN_ISLANDS_1.csv                                  8058
# HONSHU_ARC_1.csv                                        7657
# YELLOWSTONE-SNAKE_RIVER_PLAIN_VOLCANIC_PROVINCE.csv     7093
# ANATOLIA-IRAN_BELT_-_CENOZOIC_QUATERNARY.csv            6572
# ANDEAN_ARC_1.csv                                        6412
# CENTRAL_ASIAN_FOLDBELT_-_CENOZOIC_QUATERNARY.csv        6319
# ANDEAN_ARC_2.csv                                        6303
# EAST_AFRICAN_RIFT.csv                                   6183
# IZU-BONIN_ARC.csv                                       5658
# HONSHU_ARC_2.csv                                        5375
# MEXICAN_VOLCANIC_BELTS.csv                              5069
# BASIN_AND_RANGE_-_GREAT_BASIN.csv                       4925
# NORTH_ATLANTIC_IGNEOUS_PROVINCE_OR_NAIP.csv             4621
# NEW_ZEALAND.csv                                         4455
# CASCADES.csv                                            4346
# EUROPEAN_OROGENIC_BELT_-_CENOZOIC_QUATERNARY.csv        4284
# KAMCHATKA_ARC.csv                                       4281
# CENTRAL_ASIAN_FOLDBELT_-_MESOZOIC.csv                   4259
# HAWAIIAN_ISLANDS_2.csv                                  3922
# SUPERIOR_PROVINCE_ARCHEAN.csv                           3754
# CANARY_ISLANDS.csv                                      3743
# CAPE_VERDE_ISLANDS.csv                                  3743
# CENTRAL_AMERICAN_VOLCANIC_ARC.csv                       3678
# CENTRAL_ASIAN_FOLDBELT_-_PALEOZOIC.csv                  3407
# SIBERIAN_TRAPS.csv                                      3390
# AUSTRALIA_001.csv                                       3381
# DECCAN.csv                                              3051
# ALEUTIAN_ARC.csv                                        2975
# TONGA_ARC.csv                                           2819
# KAROO_AND_FERRAR_PROVINCES.csv                          2740
# LESSER_ANTILLES.csv                                     2659
# WEST_AUSTRALIAN_CRATON.csv                              2506
# KURILE_ARC.csv                                          2458
# CARPATHIAN_BELT_AND_PANNONIAN_BASIN.csv                 2426
# EUROPEAN_OROGENIC_BELT_-_PALEOZOIC.csv                  2396
# RYUKYU_ARC.csv                                          2269
# SUNDA_ARC.csv                                           2242
# KAAPVAAL_CRATON_ARCHEAN.csv                             2172
# AEOLIAN_ARC.csv                                         2163
# BALTIC_SHIELD_-_PROTEROZOIC.csv                         2059
# NEW_ZEALAND_001.csv                                     1989
# ETNA_SICILY.csv                                         1983
# AEGEAN_ARC.csv                                          1919
# APPALACHIANS.csv                                        1909
# CENTRAL_ATLANTIC_MAGMATIC_PROVINCE_-_CAMP.csv           1888
# MARIANA_ARC.csv                                         1877
# BALTIC_SHIELD_-_ARCHEAN.csv                             1835
# PARANA.csv                                              1707
# LUZON_ARC.csv                                           1613
# CENTRAL_ASIAN_FOLDBELT_-_PROTEROZOIC.csv                1584
# NORTH_AMERICAN_CORDILLERA_-_CENOZOIC-QUATERNARY.csv     1503
# MASCARENE_ISLANDS_INCL_REUNION.csv                      1481
# ARABIAN-NUBIAN_SHIELD_-_CENOZOIC_QUATERNARY.csv         1479
# ARABIAN-NUBIAN_SHIELD_-_PROTEROZOIC.csv                 1457
# NEW_HEBRIDES_ARC_-_VANUATU_ARCHIPELAGO.csv              1410
# DHARWAR_CRATON_ARCHEAN.csv                              1378
# SCOTIA_ARC.csv                                          1325
# GREATER_ANTILLES.csv                                    1316
# AZORES.csv                                              1300
# BISMARCK_ARC_-_NEW_BRITAIN_ARC.csv                      1282
# LIGURIA-SARDO-TYRRHENIAN_ARC.csv                        1280
# MEXICAN_BASIN_AND_RANGE.csv                             1215
# ANTARCTICA.csv                                          1205
# GALAPAGOS_ISLANDS.csv                                   1106
# MID-AFRICAN_RIFT_SYSTEM.csv                             1090
# EMEISHAN.csv                                            1079
# ROSS_ISLAND.csv                                         1039
# ETHIOPIAN_PLATEAU.csv                                    916
# AUSTRAL-COOK_ISLANDS.csv                                 837
# CARIBBEAN-COLOMBIAN_PLATEAU.csv                          801
# MARQUESAS.csv                                            770
# MIDCONTINENT_RIFT_SYSTEM_-_KEWEENAWAN.csv                750
# NORTH_ATLANTIC_CRATON_ARCHEAN.csv                        729
#                                                        ...
# ANGOLA_SHIELD_MESOZOIC.csv                                11
# s_TASMANTID_SEAMOUNTS.csv                                 11
# TAMAULIPAS;MEXICO.csv                                     11
# ANGOLA_SHIELD_PROTEROZOIC.csv                             10
# s_NORTH_ATLANTIC_SEAMOUNTS.csv                            10
# s_BAHIA_CHAIN.csv                                         10
# MAUD_RISE.csv                                              9
# PARNAIBA_SEDIMENTARY_BASIN_PALEOZOIC.csv                   9
# s_KINAN_ESCARPMENT.csv                                     9
# s_IZU-BONIN_BACK-ARC_SEAMOUNT_CHAIN.csv                    9
# AVANAVERA_LARGE_IGNEOUS_PROVINCE.csv                       9
# APENNINIC-MAGHREBIDES_CHAIN_2.csv                          9
# ANTARCTICA_-_PALEOZOIC.csv                                 9
# s_BETIC-RIF_OROGENIC_BELT_OR_GIBRALTAR_ARC.csv             9
# CONGO_CRATON.csv                                           8
# s_MARION_ISLANDS.csv                                       8
# s_BATHYMETRISTS_OR_GRIMALDI_SEAMOUNT_CHAIN.csv             8
# s_EAST_SHIKOKU_BASIN_SEAMOUNTS.csv                         7
# EAST_PACIFIC_RISE.csv                                      7
# UBENDIAN_BELT.csv                                          7
# TANZANIA_CRATON_CENOZOIC_QUATERNARY.csv                    7
# NAMAQUALAND_NATAL_BELT_CENOZOIC.csv                        7
# MENDOZA_RIFT.csv                                           6
# MID-ATLANTIC_RIDGE.csv                                     6
# NAMAQUALAND_NATAL_BELT_PALEOZOIC.csv                       6
# CARNEGIE__RIDGE.csv                                        6
# CARIBBEAN_LARGE_IGNEOUS_PROVINCE.csv                       6
# s_DE_GERLACH_SEAMOUNTS.csv                                 6
# s_SOUTHWESTERN_SEAMOUNT_PROVINCE.csv                       5
# s_AZORES.csv                                               5
# SCOTT_ISLAND.csv                                           5
# s_RED_SEA_SEMOUNTS.csv                                     5
# s_LORD_HOWE_SEAMOUNT_CHAIN.csv                             5
# MCDONALD_ISLANDS.csv                                       5
# s_GENROKU_SEAMOUNT_CHAIN.csv                               5
# NORTH_ATLANTIC_CRATON_MESOZOIC.csv                         5
# ZIMBABWE_CRATON.csv                                        5
# MADAGASCAR_RIDGE.csv                                       5
# AGULHAS_RIDGE.csv                                          4
# s_ENPO_SEAMOUNT_CHAIN.csv                                  4
# COSTA_RICA_RIFT.csv                                        4
# MEDITERRANEAN_RIDGE.csv                                    4
# TUPA_VOLCANIC_FIELD.csv                                    4
# s_UJLAN_SEAMOUNTS.csv                                      4
# BRAZIL_BASIN.csv                                           4
# J-ANOMALY_RIDGE.csv                                        3
# DHARWAR_CRATON_MESOZOIC.csv                                3
# PACIFIC_ANTARCTIC_RIDGE.csv                                3
# s_CASTOR_GUYOT.csv                                         3
# MAGELLAN_RISE.csv                                          3
# s_DISCOVERY_TABLEMOUNT.csv                                 3
# CAPE_VERDE_RISE.csv                                        3
# s_TYPHOON_SEAMOUNT_GROUP.csv                               2
# MADAGASCAR_SEYCHELLES_PROTEROZOIC.csv                      2
# COIBA_RIDGE.csv                                            2
# s_SOLITARY_SEAMOUNTS.csv                                   2
# PENOKEAN_OROGEN.csv                                        2
# s_TARAVA_SEAMOUNT_CHAIN.csv                                2
# s_SHIKOKU_BASIN_FLOOR_NEAR_KINAN_SEAMOUNT_CHAIN.csv        2
# SOUTH_ATLANTIC_RIDGE.csv                                   2
# UKRAINIAN_SHIELD_PROTEROZOIC.csv                           2
# SOUTH_WEST_INDIAN_RIDGE.csv                                2
# MIDDLE_AMERICA_TRENCH.csv                                  2
# s_COIBA_RIDGE_SEAMOUNTS.csv                                2
# CUVIER_OR_WALLABY_PLATEAU.csv                              2
# s_UNION_SEAMOUNT_CHAIN.csv                                 1
# s_KAMCHATKA.csv                                            1
# FINGER_LAKES_FIELD_NEW_YORK.csv                            1
# s_JAPANESE_SEAMOUNT_TRAIL.csv                              1
# SIBERIAN_CRATON_CENOZOIC_QUATERNARY.csv                    1
# s_EXPLORER_SEAMOUNT_CHAIN.csv                              1
# SAO_PAULO_PLATEAU.csv                                      1
# MATSUMAE_PLATEAU.csv                                       1
# TUAMOTU_ISLANDS.csv                                        1
# SOUTHERN_MOHNS_RIDGE.csv                                   1
# Name: FILENAME, dtype: int64

# %%
# Samples obtained per location

master_file['LOCATION'].value_counts()
# Out:
# ICELAND / ICELAND / NORTHERN ICELAND RIFT ZONE / ATLANTIC OCEAN                                                                                                           2007
# ICELAND / ICELAND / ATLANTIC OCEAN                                                                                                                                        1968
# YELLOWSTONE-SNAKE RIVER PLAIN VOLCANIC PROVINCE / COLUMBIA PLATEAU-BLUE MOUNTAINS PROVINCE / GRANDE RONDE BASALT                                                          1661
# HAWAIIAN ISLANDS / HAWAII / KILAUEA / SHIELD STAGE / EAST RIFT ZONE / PUU OO ERUPTION / PACIFIC OCEAN                                                                     1599
# CAPE VERDE ISLANDS / FOGO / ATLANTIC OCEAN                                                                                                                                1424
# DECCAN / NORTHERN DECCAN                                                                                                                                                  1170
# SIBERIAN TRAPS / YAKUTIAN KIMBERLITE FIELDS / NYURBA (NURBINSKAYA) KIMBERLITE PIPE                                                                                        1146
# HAWAIIAN ISLANDS / HAWAII / MAUNA KEA / PACIFIC OCEAN                                                                                                                     1067
# HONSHU ARC / NORTHEASTERN HONSHU ARC / HOKKAIDO / YOTEI / PACIFIC OCEAN                                                                                                    995
# ROSS ISLAND / ROSS ISLAND / MOUNT EREBUS / PACIFIC OCEAN                                                                                                                   940
# NORTH AMERICAN CORDILLERA - CENOZOIC-QUATERNARY / CANADIAN CORDILLERA / BRITISH COLUMBIA / TANZILLA VOLCANO                                                                  1
# YEMEN PLATEAU / SOUTHERN YEMEN PLATEAU / IFTAR ALKALB UNIT                                                                                                                   1
# ANDEAN ARC / CENTRAL ANDEAN VOLCANIC ZONE / BOLIVIA / PATAPATANI FORMATION / PACIFIC OCEAN                                                                                   1
# ANDEAN ARC / SOUTHERN ANDEAN VOLCANIC ZONE / ARGENTINA / LA PARVA / PACIFIC OCEAN                                                                                            1
# NEW ZEALAND / COROMANDEL-TAUPO / TAUPO VOLCANIC ZONE / PUKATEKAHI / PACIFIC OCEAN                                                                                            1
# ICELAND / ICELAND / KLEIFARVATN / WESTERN ICELAND RIFT ZONE / ATLANTIC OCEAN                                                                                                 1
# CARPATHIAN BELT AND PANNONIAN BASIN / EASTERN ALPINE-WESTERN CARPATHIAN-NORTHERN PANNONIAN (ALCAPA) TERRAIN / NOGRAD-GÖMÖR VOLCANIC FIELD / NAGY-SALGO                       1
# RYUKYU ARC / RYUKYU ARC / NAKANO-SHIMA/NAKANOJIMA / NAKANO-SHIMA / NIGORIURA VOLCANICS / PACIFIC OCEAN                                                                       1
# Name: LOCATION, dtype: int64

# %%
# Samples obtained per rock name

temp = master_file['ROCK NAME'].value_counts()
filter_ = r'\[(\d)*\]'

# Citations are removed from the index so that identical rock names have identical indexes.
temp.index = temp.index.astype(str).str.replace(filter_,'').str.strip().str.replace('  ',' ')

# Samples with identical rock names are regrouped
temp = temp.groupby(temp.index).sum().sort_values(ascending=False)
print(temp)
# Out:
# NOT GIVEN                                                                    54856
# BASALT                                                                       54381
# ANDESITE                                                                     19487
# RHYOLITE                                                                     17287
# THOLEIITE                                                                    11967
# ANDESITE, BASALTIC                                                           11047
# DACITE                                                                       10120
# BASALT, ALKALINE                                                              7692
# TRACHYTE                                                                      5041
# BASANITE                                                                      4748
# KIMBERLITE                                                                    4501
# BASALT, THOLEIITIC                                                            3645
# KOMATIITE                                                                     3492
# DOLERITE                                                                      3145
# PHONOLITE                                                                     2871
# TRACHYBASALT                                                                  2854
# HAWAIITE                                                                      2377
# TRACHYANDESITE                                                                2127
# PICRITE                                                                       2015
# BASALT, OLIVINE                                                               1948
# RHYODACITE                                                                    1617
# DIABASE                                                                       1502
# TRACHYANDESITE, BASALTIC                                                      1333
# THOLEIITE, OLIVINE                                                            1287
# BASALT, ALKALINE, OLIVINE                                                     1281
# BASALT, TRANSITIONAL                                                          1112
# SHOSHONITE                                                                    1063
# NEPHELINITE                                                                    979
# MUGEARITE                                                                      894
# ADAKITE                                                                        891
# TEPHRITE                                                                       790
# LATITE                                                                         788
# BASALT, KOMATIITIC                                                             778
# BONINITE                                                                       696
# ANDESITE, AUGITE-HYPERSTHENE                                                   666
# ANKARAMITE                                                                     596
# BASALT / NOT GIVEN                                                             590
# LAMPROITE                                                                      573
# BASALT, CALC-ALKALINE                                                          525
# THOLEIITE, QUARTZ                                                              503
# PHONOTEPHRITE                                                                  499
# BENMOREITE                                                                     489
# BASALT, ANDESITIC                                                              447
# PANTELLERITE                                                                   430
# ANDESITE, PYROXENE                                                             423
# THOLEIITE / BASALT                                                             422
# PHONOLITE, TEPHRI                                                              416
# COMENDITE                                                                      408
# BASALT, SUBALKALINE                                                            405
# NEPHELINITE, OLIVINE                                                           385
# TRACHYDACITE                                                                   366
# ANDESITE, THOLEIITIC                                                           357
# ANDESITE / NOT GIVEN                                                           317
# TRACHYTE, ALKALINE                                                             316
# ANDESITE, HORNBLENDE                                                           313
# BASALT, PICRITIC                                                               297
# KOMATIITE, PERIDOTITIC                                                         291
# ANDESITE, HYPERSTHENE-AUGITE                                                   271
# LEUCITITE                                                                      270
# NOT GIVEN / BASALT                                                             262
# CARBONATITE                                                                    251
# FOIDITE                                                                        250
# BASALT / THOLEIITE                                                             229
# PICRITE, FERRO                                                                 216
# OCEANITE                                                                       207
# ANDESITE, 2-PYROXENE                                                           200
# LATITE, QUARTZ                                                                 197
# ANDESITE, CALC-ALKALINE                                                        197
# ANDESITE, BASALTIC / NOT GIVEN                                                 191
# BASALT, ALKALINE / BASALT                                                      182
# MELILITITE, OLIVINE                                                            180
# BASALT, OLIVINE-AUGITE                                                         178
# MELILITITE                                                                     174
# TEPHRITE, LEUCITE                                                              169
# RHYOLITE, PERALKALINE                                                          167
#                                                                              ...
# DACITE, FELDSPAR                                                                 1
# DACITE, GARNET                                                                   1
# DACITE, GARNET-BIOTITE                                                           1
# DACITE, AUGITE-HYPERSTHENE, BIOTITE-HORNBLENDE-BEARING                           1
# DACITE, AUGITE, QUARTZ                                                           1
# VULSINITE, BIOTITE                                                               1
# DACITE / BASALT, HYPERSTHENE                                                     1
# COMENDITE / TRACHYTE                                                             1
# COMENDITE, AEGIRINE-ARFVEDSONITE                                                 1
# TRACHYANDESITE, LABRADORITE                                                      1
# TRACHYANDESITE, KAERSUTITE-AEGIRINAUGITE-SODALITE                                1
# TRACHYANDESITE, HYPERSTHENE-CLINOPYROXENE-PHLOGOPITE-PLAGIOCLASE-SANIDINE        1
# DACITE / ANDESITE / NOT GIVEN                                                    1
# TRACHYANDESITE, HYPERSTHENE-AUGITE / TRACHYANDESITE                              1
# DACITE / BASALT / ICELANDITE                                                     1
# DACITE / BASALT, ALKALINE / BASALT                                               1
# DACITE / BONINITE                                                                1
# TRACHYANDESITE, FELDSPAR                                                         1
# DACITE / DACITE, THOLEIITIC                                                      1
# DACITE / LATITE / NOT GIVEN                                                      1
# DACITE / NOT GIVEN / DACITE, THOLEIITIC                                          1
# DACITE / NOT GIVEN / RHYOLITE                                                    1
# DACITE / PORPHYRY, QUARTZ-FELDSPAR                                               1
# DACITE / RHYODACITE                                                              1
# DACITE, 2-PYROXENE-AMPHIBOLE-PLAGIOCLASE / NOT GIVEN                             1
# DACITE, 2-PYROXENE-BIOTITE-HORNBLENDE / DACITE                                   1
# DACITE, 2-PYROXENE-QUARTZ                                                        1
# DACITE, HORNBLENDE / ANDESITE, HORNBLENDE                                        1
# DACITE, HORNBLENDE-AUGITE-HYPERSTHENE / DACITE                                   1
# DACITE, HORNBLENDE-BIOTITE-AUGITE                                                1
# DELLENITE, BIOTITE-OLIGOCLASE                                                    1
# DACITE, QUARTZ-HORNBLENDE                                                        1
# DACITE, QUARTZ-HORNBLENDE-2-PYROXENE                                             1
# DACITE, QUARTZ-HORNBLENDE-HYPERSTHENE                                            1
# DACITE, QUARTZ-PLAGIOCLASE                                                       1
# DACITE, SANIDINE-BIOTITE-PLAGIOCLASE                                             1
# DACITE, THOLEIITIC / NOT GIVEN / DACITE                                          1
# TRACHYANDESITE, BASALTIC / SHOSHONITE                                            1
# DACITE, TRACHYTIC / DACITE                                                       1
# DACITE, TRACHYTIC / RHYODACITE, ALKALINE                                         1
# TRACHYANDESITE, BASALTIC / NOT GIVEN / TEPHRIPHONOLITE                           1
# DACITE, HORNBLENDE-OLIGOCLASE                                                    1
# DIABASE / BASALT                                                                 1
# DIABASE, HORNBLENDE-AUGITE                                                       1
# TRACHYANDESITE, AUGITE-OLIVINE                                                   1
# DIORITE, HORNBLENDE                                                              1
# TRACHYANDESITE, AUGITE-BIOTITE                                                   1
# DOLERITE / BASALT, ALKALINE                                                      1
# DOLERITE / DOLERITE, CLINOPYROXENE                                               1
# DOLERITE / DOLERITE, OLIVINE                                                     1
# DOLERITE / DOLERITE, OLIVINE-CLINOPYROXENE                                       1
# DACITE, QUARTZ-CLINOPYROXENE-ORTHOPYROXENE-HORNBLENDE                            1
# DACITE, QUARTZ-BIOTITE-PLAGIOCLASE                                               1
# DACITE, QUARTZ-AUGITE-HYPERSTHENE-BIOTITE-HORNBLENDE / DACITE                    1
# DACITE, QUARTZ-AUGITE-HYPERSTHENE                                                1
# DACITE, HORNBLENDE-ORTHOPYROXENE                                                 1
# DACITE, HORNBLENDE-ORTHOPYROXENE-CLINOPYROXENE                                   1
# TRACHYANDESITE, BIOTITE                                                          1
# DACITE, HYPERSTHENE / BONINITE                                                   1
# DACITE, HYPERSTHENE / DACITE                                                     1
# TRACHYANDESITE, BASALTIC / TRACHYTE                                              1
# DACITE, HYPERSTHENE-BIOTITE                                                      1
# DACITE, HYPERSTHENE-HORNBLENDE-QUARTZ / DACITE, HYPERSTHENE-QUARTZ               1
# DACITE, LABRADORITE / ANDESITE, LABRADORITE                                      1
# DACITE, LABRADORITE-AUGITE                                                       1
# DACITE, OLIVINE                                                                  1
# DACITE, OLIVINE-AUGITE                                                           1
# DACITE, OLIVINE-HYPERSTHENE-AUGITE                                               1
# DACITE, ORTHOPYROXENE-CLINOPYROXENE-HORNBLENDE                                   1
# TRACHYANDESITE, BASALTIC / TRACHYANDESITE / TRACHYTE                             1
# DACITE, PYROXENE-OLIGOCLASE                                                      1
# DACITE, PYROXENE-OLIVINE                                                         1
# DACITE, PYROXENE-QUARTZ-BIOTITE                                                  1
# DACITE, QUARTZ-AUGITE-FAYALITE                                                   1
# DOLERITE / THOLEIITE, OLIVINE / BASALT                                           1
# Name: ROCK NAME, dtype: int64

# %%
# Samples obtained per rock name

master_file['TECTONIC SETTING'].value_counts()
# Out:
# CONVERGENT MARGIN                              96893
# INTRAPLATE VOLCANICS                           56864
# OCEAN ISLAND                                   41105
# CONTINENTAL FLOOD BASALT                       31614
# RIFT VOLCANICS                                 19066
# ARCHEAN CRATON (INCLUDING GREENSTONE BELTS)    14265
# SEAMOUNT                                        6519
# OCEANIC PLATEAU                                 2903
# COMPLEX VOLCANIC SETTINGS                       2479
# SUBMARINE RIDGE                                 1392
# OCEAN-BASIN FLOOD BASALT                         818
# Name: TECTONIC SETTING, dtype: int64

# %% [markdown]
# ### QA/QC
#
# Elements columns that doesn't contain enough data are dropped. Next, samples with missing observations in the remaining columns are dropped.

# %%
# Number of missing observations per element.

a = master_file.iloc[:, 29:-1].count(axis=0)
a = len(master_file.index) - a
print(a)
# Out:
# TIO2(WT%)           46102
# B2O3(WT%)          273908
# AL2O3(WT%)          46460
# CR2O3(WT%)         267847
# FE2O3(WT%)         200277
# FEO(WT%)           205416
# FEOT(WT%)          116191
# CAO(WT%)            46397
# MGO(WT%)            44739
# MNO(WT%)            52942
# NIO(WT%)           271435
# K2O(WT%)            41384
# NA2O(WT%)           47593
# P2O5(WT%)           59461
# H2O(WT%)           255227
# H2OP(WT%)          242983
# H2OM(WT%)          248055
# H2OT(WT%)          273918
# CO2(WT%)           252808
# CO1(WT%)           273894
# F(WT%)             266835
# CL(WT%)            263599
# CL2(WT%)           273615
# OH(WT%)            273672
# CH4(WT%)           273902
# SO2(WT%)           273169
# SO3(WT%)           268957
# SO4(WT%)           273884
# S(WT%)             264383
# LOI(WT%)           164921
# VOLATILES(WT%)     273918
# O(WT%)             273916
# OTHERS(WT%)        273895
# HE(CCM/G)          273918
# HE(CCMSTP/G)       272969
# HE3(CCMSTP/G)      273918
# HE3(AT/G)          273918
# HE4(CCM/G)         273918
# HE4(CCMSTP/G)      273918
# HE4(AT/G)          273918
# HE4(MOLE/G)        273918
# HE4(NCC/G)         273918
# HE(NCC/G)          273918
# LI(PPM)            255354
# BE(PPM)            261590
# B(PPM)             269673
# C(PPM)             273622
# CO2(PPM)           273048
# F(PPM)             270620
# NA(PPM)            273854
# MG(PPM)            273628
# AL(PPM)            273726
# P(PPM)             271957
# S(PPM)             266387
# CL(PPM)            266522
# K(PPM)             270853
# CA(PPM)            272926
# SC(PPM)            173965
# TI(PPM)            264531
# V(PPM)             147865
# CR(PPM)            132816
# MN(PPM)            269691
# FE(PPM)            273687
# CO(PPM)            180632
# NI(PPM)            128310
# CU(PPM)            185843
# ZN(PPM)            175978
# GA(PPM)            209721
# GE(PPM)            270261
# AS(PPM)            266471
# SE(PPM)            272871
# BR(PPM)            273161
# RB(PPM)             99963
# SR(PPM)             94110
# Y(PPM)             117760
# ZR(PPM)            107233
# NB(PPM)            125538
# MO(PPM)            260655
# RU(PPM)            271235
# RH(PPM)            271726
# PD(PPM)            270533
# AG(PPM)            271213
# CD(PPM)            270210
# IN(PPM)            272515
# SN(PPM)            261682
# SB(PPM)            263834
# TE(PPM)            273524
# I(PPM)             273691
# CS(PPM)            211316
# BA(PPM)            112347
# LA(PPM)            139405
# CE(PPM)            138968
# PR(PPM)            200301
# ND(PPM)            150550
# SM(PPM)            158361
# EU(PPM)            164844
# GD(PPM)            188431
# TB(PPM)            179112
# DY(PPM)            189645
# HO(PPM)            200175
# ER(PPM)            191503
# TM(PPM)            208699
# YB(PPM)            165010
# LU(PPM)            173051
# HF(PPM)            181500
# TA(PPM)            188379
# W(PPM)             264069
# RE(PPM)            271212
# OS(PPM)            270615
# IR(PPM)            270678
# PT(PPM)            270619
# AU(PPM)            270774
# HG(PPM)            273432
# TL(PPM)            266266
# PB(PPM)            179228
# BI(PPM)            270440
# TH(PPM)            149101
# U(PPM)             177720
# ND143_ND144        227650
# ND143_ND144_INI    273514
# EPSILON_ND         273642
# SR87_SR86          218700
# SR87_SR86_INI      272379
# PB206_PB204        245084
# PB206_PB204_INI    273645
# PB207_PB204        245191
# PB207_PB204_INI    273646
# PB208_PB204        245180
# PB208_PB204_INI    273645
# OS184_OS188        273870
# OS186_OS188        273849
# OS187_OS186        273699
# OS187_OS188        271675
# RE187_OS186        273773
# RE187_OS188        272363
# HF176_HF177        266808
# HE3_HE4            273042
# HE3_HE4(R/R(A))    271466
# HE4_HE3            273700
# HE4_HE3(R/R(A))    273825
# K40_AR40           273918
# AR40_K40           273772
# dtype: int64

# %%
# Elements with quantity of missing observations over *value* are dropped, with the exception of elements 
# in *index_keep*, and with the addition of elements in *index_drop*.

# PARAMETERS #
value = 152000  # Deletion threshold  (52: 152000)
index_drop = []  # Deleted elements
index_keep = []  # ['TIO2(WT%)', 'NB(PPM)', 'AL2O3(WT%)']  # Preserved elements
##############

index_ = (a > value) & ~ a.index.isin(index_keep) | a.index.isin(index_drop)

# %%
# A file with deleted data is created. The original is unaltered.

filtered_file = master_file.copy();

# Removes columns with too much missing data
filtered_file.drop(a[index_].index.values, axis=1, inplace=True)

# Removes samples with missing data
filtered_file.dropna(subset=a[~ index_].index.values, inplace=True)

filtered_file = filtered_file.reset_index(drop=True)  # Removing data messes with the indexing

# %%
print('Shape of the dataset after transformation:', str(filtered_file.shape), 'Out of:', str(master_file.shape), '\n')
print(filtered_file.iloc[:, 29:-1].axes[1])
filtered_file.head()
# Out:
# Shape of the dataset after transformation: (48338, 52) Out of: (273918, 172)
#
# Index(['TIO2(WT%)', 'AL2O3(WT%)', 'FEOT(WT%)', 'CAO(WT%)', 'MGO(WT%)',
#        'MNO(WT%)', 'K2O(WT%)', 'NA2O(WT%)', 'P2O5(WT%)', 'V(PPM)', 'CR(PPM)',
#        'NI(PPM)', 'RB(PPM)', 'SR(PPM)', 'Y(PPM)', 'ZR(PPM)', 'NB(PPM)',
#        'BA(PPM)', 'LA(PPM)', 'CE(PPM)', 'ND(PPM)', 'TH(PPM)'],
#       dtype='object')
#            FILENAME CITATIONS      TECTONIC SETTING  \
# 0  ADRIA_DOMAIN.csv   [11431]  INTRAPLATE VOLCANICS
# 1  ADRIA_DOMAIN.csv   [11431]  INTRAPLATE VOLCANICS
# 2  ADRIA_DOMAIN.csv   [11431]  INTRAPLATE VOLCANICS
# 3  ADRIA_DOMAIN.csv    [9694]  INTRAPLATE VOLCANICS
# 4  ADRIA_DOMAIN.csv    [9694]  INTRAPLATE VOLCANICS
#
#                                             LOCATION LOCATION COMMENT  \
# 0  ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...              NaN
# 1  ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...              NaN
# 2  ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...              NaN
# 3  ADRIA DOMAIN / SOUTHERN ALPS / VENETO VOLCANIC...              NaN
# 4  ADRIA DOMAIN / SOUTHERN ALPS / VENETO VOLCANIC...              NaN
#
#   LATITUDE MIN LATITUDE MAX LONGITUDE MIN LONGITUDE MAX LAND OR SEA  \
# 0         39.5         40.5            16          16.5   SUBAERIAL
# 1         39.5         40.5            16          16.5   SUBAERIAL
# 2         39.5         40.5            16          16.5   SUBAERIAL
# 3        45.68        45.68         11.22         11.22   SUBAERIAL
# 4        45.68        45.68         11.22         11.22   SUBAERIAL
#
#   ELEVATION MIN ELEVATION MAX    SAMPLE NAME          ROCK NAME  \
# 0           NaN           NaN   s 88 [11431]  NOT GIVEN [11431]
# 1           NaN           NaN  s 124 [11431]  NOT GIVEN [11431]
# 2           NaN           NaN  s 125 [11431]  NOT GIVEN [11431]
# 3           NaN           NaN   s 5MB [9694]    BASANITE [9694]
# 4           NaN           NaN   s 6MB [9694]    BASANITE [9694]
#
#   MIN. AGE (YRS.) MAX. AGE (YRS.) GEOL.                AGE ERUPTION DAY  \
# 0             NaN             NaN   NaN  PALEOGENE [11431]          NaN
# 1             NaN             NaN   NaN  PALEOGENE [11431]          NaN
# 2             NaN             NaN   NaN  PALEOGENE [11431]          NaN
# 3             NaN             NaN   NaN   PALEOGENE [9694]          NaN
# 4             NaN             NaN   NaN   PALEOGENE [9694]          NaN
#
#   ERUPTION MONTH ERUPTION YEAR ROCK TEXTURE      ROCK TYPE DRILL DEPTH MIN  \
# 0            NaN           NaN          NaN  VOLCANIC ROCK             NaN
# 1            NaN           NaN          NaN  VOLCANIC ROCK             NaN
# 2            NaN           NaN          NaN  VOLCANIC ROCK             NaN
# 3            NaN           NaN          NaN  VOLCANIC ROCK             NaN
# 4            NaN           NaN          NaN  VOLCANIC ROCK             NaN
#
#   DRILL DEPTHAX ALTERATION MINERAL             MATERIAL SIO2(WT%) TIO2(WT%)  \
# 0           NaN        NaN     NaN  WHOLE_ROCK [11431]      44.59      2.79
# 1           NaN        NaN     NaN  WHOLE_ROCK [11431]      40.38      2.79
# 2           NaN        NaN     NaN  WHOLE_ROCK [11431]      42.56      2.78
# 3           NaN        NaN     NaN   WHOLE_ROCK [9694]      42.45      2.98
# 4           NaN        NaN     NaN   WHOLE_ROCK [9694]      42.17      2.92
#
#   AL2O3(WT%) FEOT(WT%) CAO(WT%) MGO(WT%) MNO(WT%) K2O(WT%) NA2O(WT%)  \
# 0      11.06     11.79    10.95     8.86     0.18     2.37      3.19
# 1      10.27      9.25    16.76     9.18     0.16     0.74      5.09
# 2      10.45      8.88    15.98    10.05     0.14      1.5      3.91
# 3      12.91     12.02    10.49    11.12     0.19     1.77      3.06
# 4       12.8     12.03    10.36    11.39     0.19     1.63      3.11
#
#   P2O5(WT%) V(PPM) CR(PPM) NI(PPM) RB(PPM) SR(PPM) Y(PPM) ZR(PPM) NB(PPM)  \
# 0      0.79    235     302     206      31     575   26.4     269      74
# 1      0.82    234     112      59      18     688   26.4     284      89
# 2      0.83    232     232      69      22     680   23.7     282      68
# 3      1.09    243     304     259    39.5     937   28.6     258    63.8
# 4      0.99    242     312     282    38.1     943   28.9     254    61.9
#
#   BA(PPM) LA(PPM) CE(PPM) ND(PPM) TH(PPM) UNIQUE_ID
# 0     707    52.5     101    50.9     6.4    336642
# 1     391    67.1     129    66.2    9.06    336643
# 2     673      54     109      58    5.79    336644
# 3     807    68.6     131    56.6    11.6    487564
# 4     799    67.8     129    55.6    11.3    487565

# %% [markdown]
# ## Analysis
#
# Use either *lazy* or *custom* creation of sets.

# %% [markdown]
# ##### Lazy creation of training and testing sets:

# %%
X = filtered_file.iloc[:, 29:-1]
y = filtered_file['TECTONIC SETTING']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.55, random_state=42)

# %% [markdown]
# ##### Custom creation of training and testing sets:
# Allows splitting data by filenames.

# %%
def file_split_gen(file, n_out=1, n_splits=1, seed=None):

    if n_out * n_splits > len(file.unique()):
        raise IndexError

    if seed is not None:
        rd.seed(seed)

    groups = list(file.unique())
    rd.shuffle(groups)
    current = 0

    for _ in range(n_splits):
        train_set = file.copy()
        test_set = file.copy()

        group = groups[current:current + n_out]
        train_set = train_set[~ train_set.isin(group)]
        test_set = test_set[test_set.isin(group)]
        current += n_out

        yield train_set.index, test_set.index

# %%
# Reinitializes the generator.

generator = file_split_gen(filtered_file['FILENAME'], n_out=21, n_splits=3, seed=43)

# %%
# Splits the data. Run this cell again to progress through the splits.

train_ind, test_ind = next(generator)
X = filtered_file.iloc[:, 29:-1]
y = filtered_file['TECTONIC SETTING']

X_train, X_test = X.iloc[train_ind].reset_index(drop=True), X.iloc[test_ind].reset_index(drop=True)
y_train, y_test = y.iloc[train_ind].reset_index(drop=True), y.iloc[test_ind].reset_index(drop=True)
filenames_train = filtered_file['FILENAME'].iloc[train_ind].reset_index(drop=True)
filenames_test = filtered_file['FILENAME'].iloc[test_ind].reset_index(drop=True)

count_ = y_test.value_counts()
print(count_)
print(len(count_), 'settings out of 11.')
print("Test data:", y_test.shape[0], "Out of:", filtered_file.shape[0])
# Out:
# CONTINENTAL FLOOD BASALT                       1136
# OCEAN ISLAND                                    782
# CONVERGENT MARGIN                               669
# RIFT VOLCANICS                                  391
# INTRAPLATE VOLCANICS                            209
# SEAMOUNT                                        181
# ARCHEAN CRATON (INCLUDING GREENSTONE BELTS)      48
# Name: TECTONIC SETTING, dtype: int64
# 7 settings out of 11.
# Test data: 3416 Out of: 48338

# %% [markdown]
# ### 1) SVM

# %%
# Launching the grid search.

C_range = 10.0 ** (np.arange(1, 4) / 2)
gamma_range= 10.0 ** (np.arange(-5, -2) / 2)
param_grid = dict(svc__C=C_range, svc__gamma=gamma_range)
pipeline = make_pipeline(StandardScaler(), SVC(cache_size=2000))
f1_scorer = make_scorer(f1_score, average='weighted')

start = datetime.datetime.now()
print("Start time :", start)

# Regular grid search.
# grid = GridSearchCV(pipeline, param_grid, cv=2, scoring=f1_scorer, n_jobs=-1, verbose=2)

# Grid search using file splitting.
cv = file_split_gen(filenames_train, n_out=8, n_splits=2, seed=43)
grid = GridSearchCV(pipeline, param_grid, cv=cv, scoring=f1_scorer, n_jobs=-1, verbose=2)

# Data fitting.
clf = grid.fit(X_train, y_train)  # Will take quite some time. View the progress on the console.

end = datetime.datetime.now()
print("Start time:", end)
print("Time elapsed:", end - start, '\n')

print("Best parameters set found on development set:")
print(clf.cv_results_['params'][clf.best_index_])
print("Score: %0.03f" % clf.best_score_)
# Out:
# Start time : 2017-07-12 09:48:59.777114
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  18 | elapsed: 11.4min remaining: 17.9min
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed: 14.3min finished
# Start time: 2017-07-12 10:05:20.749211
# Time elapsed: 0:16:20.972097
#
# Best parameters set found on development set:
# {'svc__C': 31.622776601683793, 'svc__gamma': 0.0031622776601683794}
# Score: 0.669

# %%
# Visualizing score per combination.

scores = clf.cv_results_['mean_test_score'].reshape((len(C_range), len(gamma_range)))
print("Mean scores:", '\n', scores)

stddev = clf.cv_results_['std_test_score'].reshape((len(C_range), len(gamma_range)))
print("Standard deviation:", '\n', stddev)

plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=0.3, right=0.8, bottom=0.3, top=0.8)
plt.imshow(scores, interpolation='nearest', cmap=plt.cm.hot, norm=MidpointNormalize(vmin=0.5, midpoint=0.83))
plt.xlabel('gamma')
plt.ylabel('C')
plt.colorbar()
plt.xticks(np.arange(len(gamma_range)), gamma_range, rotation=45)
plt.yticks(np.arange(len(C_range)), C_range)
plt.title('Validation accuracy')
plt.show()
# Out:
# Mean scores:
#  [[ 0.64847438  0.66526435  0.65967195]
#  [ 0.66073559  0.66721072  0.64994433]
#  [ 0.66866709  0.6630652   0.63639502]]
# Standard deviation:
#  [[ 0.04249328  0.0545927   0.04460655]
#  [ 0.05452629  0.05356126  0.04529155]
#  [ 0.06220229  0.05191722  0.04340654]]

# %%
# Selecting the best parameters and estimating success scores on test data.

best_C     = 10**(2 / 2)
best_gamma = 10**(-4 / 2)

pipeline = make_pipeline(StandardScaler(), SVC(C=best_C, gamma=best_gamma, cache_size=2000))
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)

# %%
# Viewing validation results.

f1 = f1_score(y_test, y_pred, average='weighted')

conf = confusion_matrix(y_test, y_pred)
conf = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]  # Normalizes
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.gray)
plt.xlabel('Predicted')
plt.ylabel('Data')
plt.colorbar()
labels = ['ARCHEAN CRATON',  # VERIFY LABELING
          'CMPL. VOLC. SET.',
          'CONT. FL. BSLT.',
          'CONV. MARGIN',
          'INTRPLT. VOLC.',
          'OCEAN ISLAND',
          'OCEAN-BS. FL. BSLT.',
          'OCEANIC PLT.',
          'RIFT VOLC.',
          'SEAMOUNT',
          'SUBMARINE RIDGE']
range_ = np.arange(len(labels))
plt.xticks(range_, labels, rotation=90)
plt.yticks(range_, labels)
plt.title('Validation accuracy')

print('f1:', str(f1))
print('Train data:', y_train.shape[0], 'Test data:', y_test.shape[0])
plt.show()
# Out:
# C:\Users\simonje\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\simonje\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# C:\Users\simonje\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide
# f1: 0.623989071678
# Train data: 41192 Test data: 7146

# %% [markdown]
# ### 2) Nearest Neighbors

# %%
# Launching the grid search.

# neighbors_range = np.arange(10, 101, 10)
neighbors_range = np.arange(1, 11)
# neighbors_range = 10.0 ** (np.arange(0, 5))
weights = ['uniform', 'distance']
param_grid = dict(kneighborsclassifier__n_neighbors=neighbors_range, kneighborsclassifier__weights=weights)
pipeline = make_pipeline(StandardScaler(), KNeighborsClassifier())
# print(pipeline.get_params().keys())
f1_scorer = make_scorer(f1_score, average='weighted')

start = datetime.datetime.now()
print("Start time :", start)

# Regular grid search.
# grid = GridSearchCV(pipeline, param_grid, cv=2, scoring=f1_scorer, n_jobs=-1, verbose=2)

# Grid search using file splitting.
cv = file_split_gen(filenames_train, n_out=8, n_splits=2, seed=43)
grid = GridSearchCV(pipeline, param_grid, cv=cv, scoring=f1_scorer, n_jobs=-1, verbose=2)

# Data fitting.
clf = grid.fit(X_train, y_train)  # Will take quite some time. View the progress on the console.

end = datetime.datetime.now()
print("Start time:", end)
print("Time elapsed:", end - start, '\n')

print("Best parameters set found on development set:")
print(clf.cv_results_['params'][clf.best_index_])
print("Score: %0.03f" % clf.best_score_)
# Out:
# Start time : 2017-07-12 10:56:15.509255
# Fitting 2 folds for each of 20 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  40 | elapsed:   33.2s remaining:   11.0s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   36.5s finished
# Start time: 2017-07-12 10:56:52.757980
# Time elapsed: 0:00:37.248725
#
# Best parameters set found on development set:
# {'kneighborsclassifier__n_neighbors': 10, 'kneighborsclassifier__weights': 'uniform'}
# Score: 0.530

# %%
# Visualizing score per combination.

scores = clf.cv_results_['mean_test_score'].reshape((len(neighbors_range), len(weights)))
print("Mean scores:", '\n', scores)

stddev = clf.cv_results_['std_test_score'].reshape((len(neighbors_range), len(weights)))
print("Standard deviation:", '\n', stddev)

plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=0.3, right=0.8, bottom=0.3, top=0.8)
plt.imshow(scores, interpolation='nearest', cmap=plt.cm.hot, norm=MidpointNormalize(vmin=0.4, midpoint=0.83))
plt.xlabel('Weights')
plt.ylabel('Quantity of neighbors')
plt.colorbar()
plt.xticks(np.arange(len(weights)), weights, rotation=45)
plt.yticks(np.arange(len(neighbors_range)), neighbors_range)
plt.title('Validation accuracy')
plt.show()
# Out:
# Mean scores:
#  [[ 0.48602454  0.48602454]
#  [ 0.5009514   0.48602454]
#  [ 0.50000833  0.49636495]
#  [ 0.51556226  0.49619362]
#  [ 0.5075455   0.50403671]
#  [ 0.52198429  0.49963876]
#  [ 0.50823989  0.50562779]
#  [ 0.52527365  0.50789283]
#  [ 0.52053578  0.51222797]
#  [ 0.53028261  0.51191456]]
# Standard deviation:
#  [[ 0.09754879  0.09754879]
#  [ 0.08139817  0.09754879]
#  [ 0.09526071  0.0929065 ]
#  [ 0.09694893  0.09938599]
#  [ 0.09535495  0.09229699]
#  [ 0.0943341   0.09695426]
#  [ 0.09238518  0.09593573]
#  [ 0.09573978  0.09967458]
#  [ 0.08744055  0.09403929]
#  [ 0.0841304   0.0956608 ]]

# %%
# Selecting the best parameters and estimating success scores on test data.

best_n      = 8
best_weight = 'distance'

pipeline = make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=best_n, weights=best_weight))
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)

# %%
# Viewing validation results.

f1 = f1_score(y_test, y_pred, average='weighted')

conf = confusion_matrix(y_test, y_pred)
conf = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]  # Normalizes
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.gray)
plt.xlabel('Predicted')
plt.ylabel('Data')
plt.colorbar()
labels = ['ARCHEAN CRATON',  # VERIFY LABELING
          'CMPL. VOLC. SET.',
          'CONT. FL. BSLT.',
          'CONV. MARGIN',
          'INTRPLT. VOLC.',
          'OCEAN ISLAND',
          'OCEAN-BS. FL. BSLT.',
          'OCEANIC PLT.',
          'RIFT VOLC.',
          'SEAMOUNT',
          'SUBMARINE RIDGE']
range_ = np.arange(len(labels))
plt.xticks(range_, labels, rotation=90)
plt.yticks(range_, labels)
plt.title('Validation accuracy')

print('f1:', str(f1))
print('Train data:', y_train.shape[0], 'Test data:', y_test.shape[0])
plt.show()
# Out:
# C:\Users\simonje\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# f1: 0.499985534496
# Train data: 9436 Test data: 6241

# %% [markdown]
# ### 3) Random forest

# %%
# Launching the grid search.

depth_range      = np.arange(40, 101, 20)
# features_range   = np.arange(1, 25, 4)
estimators_range = np.arange(40, 101, 20)
param_grid = dict(extratreesclassifier__max_depth=depth_range, 
#                  extratreesclassifier__max_features=features_range,
                  extratreesclassifier__n_estimators=estimators_range)
pipeline = make_pipeline(StandardScaler(), ExtraTreesClassifier())
# print(pipeline.get_params().keys())
f1_scorer = make_scorer(f1_score, average='weighted')

start = datetime.datetime.now()
print("Start time :", start)

# Regular grid search.
grid = GridSearchCV(pipeline, param_grid, cv=2, scoring=f1_scorer, n_jobs=-1, verbose=2)

# Grid search using file splitting.
# cv = file_split_gen(filenames_train, n_out=8, n_splits=2, seed=43)
# grid = GridSearchCV(pipeline, param_grid, cv=cv, scoring=f1_scorer, n_jobs=-1, verbose=2)

# Data fitting.
clf = grid.fit(X_train, y_train)  # Will take quite some time. View the progress on the console.

end = datetime.datetime.now()
print("Start time:", end)
print("Time elapsed:", end - start, '\n')

print("Best parameters set found on development set:")
print(clf.cv_results_['params'][clf.best_index_])
print("Score: %0.03f" % clf.best_score_)
# Out:
# Start time : 2017-07-12 11:09:29.678664
# Fitting 2 folds for each of 16 candidates, totalling 32 fits
# [Parallel(n_jobs=-1)]: Done  18 out of  32 | elapsed:   26.5s remaining:   20.6s
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:   33.7s finished
# Start time: 2017-07-12 11:10:14.150111
# Time elapsed: 0:00:44.471447
#
# Best parameters set found on development set:
# {'extratreesclassifier__max_depth': 40, 'extratreesclassifier__n_estimators': 100}
# Score: 0.547

# %%
# Visualizing score per combination.

scores = clf.cv_results_['mean_test_score'].reshape((len(depth_range), len(estimators_range)))
print("Mean scores:", '\n', scores)

stddev = clf.cv_results_['std_test_score'].reshape((len(depth_range), len(estimators_range)))
print("Standard deviation:", '\n', stddev)

plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=0.3, right=0.8, bottom=0.3, top=0.8)
plt.imshow(scores, interpolation='nearest', cmap=plt.cm.hot, norm=MidpointNormalize(vmin=0.4, midpoint=0.6))
plt.xlabel('Trees')
plt.ylabel('Depth')
plt.colorbar()
plt.xticks(np.arange(len(estimators_range)), estimators_range, rotation=45)
plt.yticks(np.arange(len(depth_range)), depth_range)
plt.title('Validation accuracy')
plt.show()
# Out:
# Mean scores:
#  [[ 0.53836136  0.54034934  0.54301542  0.54662782]
#  [ 0.53840589  0.54455134  0.54495169  0.54608749]
#  [ 0.53999385  0.5404824   0.54527093  0.54405024]
#  [ 0.53727482  0.54188614  0.54354719  0.54506993]]
# Standard deviation:
#  [[ 0.00300478  0.00396048  0.00292618  0.00234605]
#  [ 0.00661928  0.00510713  0.00161827  0.00641699]
#  [ 0.00233111  0.00386383  0.00314455  0.00390963]
#  [ 0.00464284  0.00383505  0.00354032  0.00290473]]

# %%
# Selecting the best parameters and estimating success scores on test data.

best_depth      = 50
best_estimators = 100

clf = ExtraTreesClassifier(max_depth=best_depth, n_estimators=best_estimators)
pipeline = make_pipeline(StandardScaler(), clf)
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)

# %%
# Viewing validation results.

f1 = f1_score(y_test, y_pred, average='weighted')

conf = confusion_matrix(y_test, y_pred)
conf = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]  # Normalizes
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.gray)
plt.xlabel('Predicted')
plt.ylabel('Data')
plt.colorbar()
labels = ['ARCHEAN CRATON',  # VERIFY LABELING
          'CMPL. VOLC. SET.',
          'CONT. FL. BSLT.',
          'CONV. MARGIN',
          'INTRPLT. VOLC.',
          'OCEAN ISLAND',
          'OCEAN-BS. FL. BSLT.',
          'OCEANIC PLT.',
          'RIFT VOLC.',
          'SEAMOUNT',
          'SUBMARINE RIDGE']
range_ = np.arange(len(labels))
plt.xticks(range_, labels, rotation=90)
plt.yticks(range_, labels)
plt.title('Validation accuracy')

print('f1:', str(f1))
print('Train data:', y_train.shape[0], 'Test data:', y_test.shape[0])
plt.show()
# Out:
# C:\Users\simonje\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# C:\Users\simonje\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide
# f1: 0.534846899171
# Train data: 44922 Test data: 3416

# %%
# Importance of each element regarding classification.

feature_importance = clf.feature_importances_
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
plt.subplot(1, 2, 2)
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, filtered_file.iloc[:, 29:-1].axes[1].values[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()
