# %% [markdown]
# To do:
#
# - remove files that are not location -DONE
#
# - check for duplicates using ID -DONE
#
# - add column with location from filename -DONE
#
# - do data QA/QC -DONE

# %%
# %matplotlib inline

import time

import pandas as pd
import numpy as np
import os
import re
from itertools import count

pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows', 150)

# %% [markdown]
# # Concatenation
#
# (...)

# %%
# (...)

dir_ = os.curdir + '/Georoc_files'
files = os.listdir(dir_)

nb_data = 0

for file, file_no in zip(files, count()):

    file = pd.read_csv(dir_ + '/' + file, encoding='iso-8859-1').astype(str)  # , dtype=object)

    index = np.where(file.CITATIONS.values == 'References:')[0][0]
    file = file[:index]
    file.insert(0, 'FILENAME', files[file_no])

    nb_data += file.shape[0]
    files[file_no] = file

# %%
# (...)

master_file = pd.DataFrame(index=np.arange(0, nb_data), columns=files[0].axes[1])
current_row = 0

row_no = 0
for file in files:
    for _, row in file.iterrows():
        master_file.loc[row_no] = row
        row_no += 1

file = None

master_file.drop_duplicates(subset='UNIQUE_ID', inplace=True)
master_file.drop('Unnamed: 171', axis=1, inplace=True);

# %%
# (...)

master_file.to_csv(os.curdir + '/master.csv', index=False)

# %% [markdown]
# # Load master

# %%
# (...)

master_file = pd.read_csv(os.curdir + '/master.csv', encoding='iso-8859-1', dtype=str)  # , dtype=object)

# %% [markdown]
# # Statistics
#
# (...)

# %%
print ('Shape of the dataset after transformation:' + str(master_file.shape))
master_file.head()
# Out:
# Shape of the dataset after transformation:(330089, 172)
#            FILENAME       CITATIONS      TECTONIC SETTING  \
# 0  ADRIA_DOMAIN.csv  [14868][14875]  INTRAPLATE VOLCANICS
# 1  ADRIA_DOMAIN.csv         [11431]  INTRAPLATE VOLCANICS
# 2  ADRIA_DOMAIN.csv         [11431]  INTRAPLATE VOLCANICS
# 3  ADRIA_DOMAIN.csv         [11431]  INTRAPLATE VOLCANICS
# 4  ADRIA_DOMAIN.csv         [11431]  INTRAPLATE VOLCANICS
#
#                                             LOCATION LOCATION COMMENT  \
# 0  ADRIA DOMAIN / SOUTHERN ALPS / VENETO VOLCANIC...      CALCERANICA
# 1  ADRIA DOMAIN / ADRIATIC FORELAND / ABRUZZO / M...              NaN
# 2  ADRIA DOMAIN / ADRIATIC FORELAND / ABRUZZO / M...              NaN
# 3  ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...              NaN
# 4  ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...              NaN
#
#   LATITUDE MIN LATITUDE MAX LONGITUDE MIN LONGITUDE MAX LAND OR SEA  \
# 0           46           46         11.24         11.24   SUBAERIAL
# 1           42           42            14            14   SUBAERIAL
# 2           42           42            14            14   SUBAERIAL
# 3         39.5         40.5            16          16.5   SUBAERIAL
# 4         39.5         40.5            16          16.5   SUBAERIAL
#
#   ELEVATION MIN ELEVATION MAX                           SAMPLE NAME  \
# 0           NaN           NaN  s CALC38 [14868] / s CALC 38 [14875]
# 1           NaN           NaN                    s QUEGLIA1 [11431]
# 2           NaN           NaN                    s QUEGLIA2 [11431]
# 3           NaN           NaN                          s 88 [11431]
# 4           NaN           NaN                         s 124 [11431]
#
#                                    ROCK NAME MIN. AGE (YRS.) MAX. AGE (YRS.)  \
# 0  MONCHIQUITE [14868] / LAMPROPHYRE [14875]             NaN             NaN
# 1                        LAMPROPHYRE [11431]             NaN             NaN
# 2                        LAMPROPHYRE [11431]             NaN             NaN
# 3                          NOT GIVEN [11431]             NaN             NaN
# 4                          NOT GIVEN [11431]             NaN             NaN
#
#            GEOL.                 AGE ERUPTION DAY ERUPTION MONTH  \
# 0  UPPER [14868]  CRETACEOUS [14868]          NaN            NaN
# 1            NaN      EOCENE [11431]          NaN            NaN
# 2            NaN      EOCENE [11431]          NaN            NaN
# 3            NaN   PALEOGENE [11431]          NaN            NaN
# 4            NaN   PALEOGENE [11431]          NaN            NaN
#
#   ERUPTION YEAR ROCK TEXTURE      ROCK TYPE DRILL DEPTH MIN DRILL DEPTHAX  \
# 0           NaN          NaN           VEIN             NaN           NaN
# 1           NaN          NaN  PLUTONIC ROCK             NaN           NaN
# 2           NaN          NaN  PLUTONIC ROCK             NaN           NaN
# 3           NaN          NaN  VOLCANIC ROCK             NaN           NaN
# 4           NaN          NaN  VOLCANIC ROCK             NaN           NaN
#
#   ALTERATION MINERAL             MATERIAL SIO2(WT%) TIO2(WT%) B2O3(WT%)  \
# 0        NaN     NaN  WHOLE_ROCK [14868]      36.98      2.64       NaN
# 1        NaN     NaN  WHOLE_ROCK [11431]       34.6      3.38       NaN
# 2        NaN     NaN  WHOLE_ROCK [11431]      36.37      3.63       NaN
# 3        NaN     NaN  WHOLE_ROCK [11431]      44.59      2.79       NaN
# 4        NaN     NaN  WHOLE_ROCK [11431]      40.38      2.79       NaN
#
#   AL2O3(WT%) CR2O3(WT%) FE2O3(WT%) FEO(WT%) FEOT(WT%) CAO(WT%) MGO(WT%)  \
# 0      12.42        NaN       1.71    10.26       NaN    11.43     8.74
# 1       8.38        NaN        NaN      NaN      8.98    15.92    17.66
# 2       8.28        NaN        NaN      NaN      9.23    12.87    19.04
# 3      11.06        NaN        NaN      NaN     11.79    10.95     8.86
# 4      10.27        NaN        NaN      NaN      9.25    16.76     9.18
#
#   MNO(WT%) NIO(WT%) K2O(WT%) NA2O(WT%) P2O5(WT%) H2O(WT%) H2OP(WT%) H2OM(WT%)  \
# 0     0.18      NaN     1.66      3.95      1.62      NaN       NaN       NaN
# 1     0.18      NaN     0.53      0.38      0.98      NaN       NaN       NaN
# 2     0.18      NaN      0.5      0.35      0.95      NaN       NaN       NaN
# 3     0.18      NaN     2.37      3.19      0.79      NaN       NaN       NaN
# 4     0.16      NaN     0.74      5.09      0.82      NaN       NaN       NaN
#
#   H2OT(WT%) CO2(WT%) CO1(WT%) F(WT%) CL(WT%) CL2(WT%) OH(WT%) CH4(WT%)  \
# 0       NaN      NaN      NaN    NaN     NaN      NaN     NaN      NaN
# 1       NaN      NaN      NaN    NaN     NaN      NaN     NaN      NaN
# 2       NaN      NaN      NaN    NaN     NaN      NaN     NaN      NaN
# 3       NaN      NaN      NaN    NaN     NaN      NaN     NaN      NaN
# 4       NaN      NaN      NaN    NaN     NaN      NaN     NaN      NaN
#
#   SO2(WT%) SO3(WT%) SO4(WT%) S(WT%) LOI(WT%) VOLATILES(WT%) O(WT%)  \
# 0      NaN      NaN      NaN    NaN     8.43            NaN    NaN
# 1      NaN      NaN      NaN    NaN     8.01            NaN    NaN
# 2      NaN      NaN      NaN    NaN     7.57            NaN    NaN
# 3      NaN      NaN      NaN    NaN     2.11            NaN    NaN
# 4      NaN      NaN      NaN    NaN     3.52            NaN    NaN
#
#   OTHERS(WT%) HE(CCM/G) HE(CCMSTP/G) HE3(CCMSTP/G) HE3(AT/G) HE4(CCM/G)  \
# 0         NaN       NaN          NaN           NaN       NaN        NaN
# 1         NaN       NaN          NaN           NaN       NaN        NaN
# 2         NaN       NaN          NaN           NaN       NaN        NaN
# 3         NaN       NaN          NaN           NaN       NaN        NaN
# 4         NaN       NaN          NaN           NaN       NaN        NaN
#
#   HE4(CCMSTP/G) HE4(AT/G) HE4(MOLE/G) HE4(NCC/G) HE(NCC/G) LI(PPM) BE(PPM)  \
# 0           NaN       NaN         NaN        NaN       NaN     NaN     NaN
# 1           NaN       NaN         NaN        NaN       NaN     NaN     NaN
# 2           NaN       NaN         NaN        NaN       NaN     NaN     NaN
# 3           NaN       NaN         NaN        NaN       NaN     NaN     NaN
# 4           NaN       NaN         NaN        NaN       NaN     NaN     NaN
#
#   B(PPM)      ...       GE(PPM) AS(PPM) SE(PPM) BR(PPM) RB(PPM) SR(PPM)  \
# 0    NaN      ...           NaN     NaN     NaN     NaN      38    1434
# 1    NaN      ...           NaN     NaN     NaN     NaN      21     811
# 2    NaN      ...           NaN     NaN     NaN     NaN      18     593
# 3    NaN      ...           NaN     NaN     NaN     NaN      31     575
# 4    NaN      ...           NaN     NaN     NaN     NaN      18     688
#
#   Y(PPM) ZR(PPM) NB(PPM) MO(PPM) RU(PPM) RH(PPM) PD(PPM) AG(PPM) CD(PPM)  \
# 0     36     319      88     NaN     NaN     NaN     NaN     NaN     NaN
# 1   31.1     362     122     NaN     NaN     NaN     NaN     NaN     NaN
# 2     30     343     125     NaN     NaN     NaN     NaN     NaN     NaN
# 3   26.4     269      74     NaN     NaN     NaN     NaN     NaN     NaN
# 4   26.4     284      89     NaN     NaN     NaN     NaN     NaN     NaN
#
#   IN(PPM) SN(PPM) SB(PPM) TE(PPM) I(PPM) CS(PPM) BA(PPM) LA(PPM) CE(PPM)  \
# 0     NaN     NaN     NaN     NaN    NaN     NaN     910      80     173
# 1     NaN     NaN     NaN     NaN    NaN     NaN    1089      89     150
# 2     NaN     NaN     NaN     NaN    NaN     NaN     NaN    82.4     150
# 3     NaN     NaN     NaN     NaN    NaN     NaN     707    52.5     101
# 4     NaN     NaN     NaN     NaN    NaN     NaN     391    67.1     129
#
#   PR(PPM) ND(PPM) SM(PPM) EU(PPM) GD(PPM) TB(PPM) DY(PPM) HO(PPM) ER(PPM)  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1    17.3    66.8    13.3    3.84    11.2    1.47    7.31    1.21    3.01
# 2    17.3    67.5    13.5    4.21    11.9    1.48    7.33    1.22    3.14
# 3      12    50.9      10    2.86     9.1    1.25    5.84    0.98    2.61
# 4      16    66.2    12.5    3.61    10.5    1.41    6.74    1.01    2.58
#
#   TM(PPM) YB(PPM) LU(PPM) HF(PPM) TA(PPM) W(PPM) RE(PPM) OS(PPM) IR(PPM)  \
# 0     NaN     NaN     NaN     NaN     NaN    NaN     NaN     NaN     NaN
# 1     0.4    2.16    0.28     NaN     NaN    NaN     NaN     NaN     NaN
# 2    0.38    2.06     0.3     NaN     NaN    NaN     NaN     NaN     NaN
# 3    0.32    1.79    0.25     NaN     NaN    NaN     NaN     NaN     NaN
# 4     0.3    1.75    0.24     NaN     NaN    NaN     NaN     NaN     NaN
#
#   PT(PPM) AU(PPM) HG(PPM) TL(PPM) PB(PPM) BI(PPM) TH(PPM) U(PPM) ND143_ND144  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN      10    NaN    0.512893
# 1     NaN     NaN     NaN     NaN     NaN     NaN    9.49   2.99         NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     9.4      3         NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     6.4   1.58         NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN    9.06   2.46         NaN
#
#   ND143_ND144_INI EPSILON_ND SR87_SR86 SR87_SR86_INI PB206_PB204  \
# 0             NaN        NaN  0.703667           NaN         NaN
# 1             NaN        NaN       NaN           NaN         NaN
# 2             NaN        NaN       NaN           NaN         NaN
# 3             NaN        NaN       NaN           NaN         NaN
# 4             NaN        NaN       NaN           NaN         NaN
#
#   PB206_PB204_INI PB207_PB204 PB207_PB204_INI PB208_PB204 PB208_PB204_INI  \
# 0             NaN         NaN             NaN         NaN             NaN
# 1             NaN         NaN             NaN         NaN             NaN
# 2             NaN         NaN             NaN         NaN             NaN
# 3             NaN         NaN             NaN         NaN             NaN
# 4             NaN         NaN             NaN         NaN             NaN
#
#   OS184_OS188 OS186_OS188 OS187_OS186 OS187_OS188 RE187_OS186 RE187_OS188  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   HF176_HF177 HE3_HE4 HE3_HE4(R/R(A)) HE4_HE3 HE4_HE3(R/R(A)) K40_AR40  \
# 0         NaN     NaN             NaN     NaN             NaN      NaN
# 1         NaN     NaN             NaN     NaN             NaN      NaN
# 2         NaN     NaN             NaN     NaN             NaN      NaN
# 3         NaN     NaN             NaN     NaN             NaN      NaN
# 4         NaN     NaN             NaN     NaN             NaN      NaN
#
#   AR40_K40      UNIQUE_ID
# 0      NaN  106683-CALC38
# 1      NaN         336640
# 2      NaN         336641
# 3      NaN         336642
# 4      NaN         336643
#
# [5 rows x 172 columns]

# %%
# (...)

pd.Series(master_file.axes[1])
# Out:
# 0              FILENAME
# 1             CITATIONS
# 2      TECTONIC SETTING
# 3              LOCATION
# 4      LOCATION COMMENT
# 5          LATITUDE MIN
# 6          LATITUDE MAX
# 7         LONGITUDE MIN
# 8         LONGITUDE MAX
# 9           LAND OR SEA
# 10        ELEVATION MIN
# 11        ELEVATION MAX
# 12          SAMPLE NAME
# 13            ROCK NAME
# 14      MIN. AGE (YRS.)
# 15      MAX. AGE (YRS.)
# 16                GEOL.
# 17                  AGE
# 18         ERUPTION DAY
# 19       ERUPTION MONTH
# 20        ERUPTION YEAR
# 21         ROCK TEXTURE
# 22            ROCK TYPE
# 23      DRILL DEPTH MIN
# 24        DRILL DEPTHAX
# 25           ALTERATION
# 26              MINERAL
# 27             MATERIAL
# 28            SIO2(WT%)
# 29            TIO2(WT%)
# 30            B2O3(WT%)
# 31           AL2O3(WT%)
# 32           CR2O3(WT%)
# 33           FE2O3(WT%)
# 34             FEO(WT%)
# 35            FEOT(WT%)
# 36             CAO(WT%)
# 37             MGO(WT%)
# 38             MNO(WT%)
# 39             NIO(WT%)
# 40             K2O(WT%)
# 41            NA2O(WT%)
# 42            P2O5(WT%)
# 43             H2O(WT%)
# 44            H2OP(WT%)
# 45            H2OM(WT%)
# 46            H2OT(WT%)
# 47             CO2(WT%)
# 48             CO1(WT%)
# 49               F(WT%)
# 50              CL(WT%)
# 51             CL2(WT%)
# 52              OH(WT%)
# 53             CH4(WT%)
# 54             SO2(WT%)
# 55             SO3(WT%)
# 56             SO4(WT%)
# 57               S(WT%)
# 58             LOI(WT%)
# 59       VOLATILES(WT%)
# 60               O(WT%)
# 61          OTHERS(WT%)
# 62            HE(CCM/G)
# 63         HE(CCMSTP/G)
# 64        HE3(CCMSTP/G)
# 65            HE3(AT/G)
# 66           HE4(CCM/G)
# 67        HE4(CCMSTP/G)
# 68            HE4(AT/G)
# 69          HE4(MOLE/G)
# 70           HE4(NCC/G)
# 71            HE(NCC/G)
# 72              LI(PPM)
# 73              BE(PPM)
# 74               B(PPM)
#              ...
# 97              GE(PPM)
# 98              AS(PPM)
# 99              SE(PPM)
# 100             BR(PPM)
# 101             RB(PPM)
# 102             SR(PPM)
# 103              Y(PPM)
# 104             ZR(PPM)
# 105             NB(PPM)
# 106             MO(PPM)
# 107             RU(PPM)
# 108             RH(PPM)
# 109             PD(PPM)
# 110             AG(PPM)
# 111             CD(PPM)
# 112             IN(PPM)
# 113             SN(PPM)
# 114             SB(PPM)
# 115             TE(PPM)
# 116              I(PPM)
# 117             CS(PPM)
# 118             BA(PPM)
# 119             LA(PPM)
# 120             CE(PPM)
# 121             PR(PPM)
# 122             ND(PPM)
# 123             SM(PPM)
# 124             EU(PPM)
# 125             GD(PPM)
# 126             TB(PPM)
# 127             DY(PPM)
# 128             HO(PPM)
# 129             ER(PPM)
# 130             TM(PPM)
# 131             YB(PPM)
# 132             LU(PPM)
# 133             HF(PPM)
# 134             TA(PPM)
# 135              W(PPM)
# 136             RE(PPM)
# 137             OS(PPM)
# 138             IR(PPM)
# 139             PT(PPM)
# 140             AU(PPM)
# 141             HG(PPM)
# 142             TL(PPM)
# 143             PB(PPM)
# 144             BI(PPM)
# 145             TH(PPM)
# 146              U(PPM)
# 147         ND143_ND144
# 148     ND143_ND144_INI
# 149          EPSILON_ND
# 150           SR87_SR86
# 151       SR87_SR86_INI
# 152         PB206_PB204
# 153     PB206_PB204_INI
# 154         PB207_PB204
# 155     PB207_PB204_INI
# 156         PB208_PB204
# 157     PB208_PB204_INI
# 158         OS184_OS188
# 159         OS186_OS188
# 160         OS187_OS186
# 161         OS187_OS188
# 162         RE187_OS186
# 163         RE187_OS188
# 164         HF176_HF177
# 165             HE3_HE4
# 166     HE3_HE4(R/R(A))
# 167             HE4_HE3
# 168     HE4_HE3(R/R(A))
# 169            K40_AR40
# 170            AR40_K40
# 171           UNIQUE_ID
# Length: 172, dtype: object

# %%
# (...)

master_file['FILENAME'].value_counts()
# Out:
# HONSHU_ARC_1.csv                                       11769
# APENNINIC-MAGHREBIDES_CHAIN.csv                        11444
# ICELAND.csv                                             9525
# HAWAIIAN_ISLANDS_1.csv                                  8602
# CENTRAL_ASIAN_FOLDBELT_-_CENOZOIC_QUATERNARY.csv        7833
# ANDEAN_ARC_1.csv                                        7383
# EAST_AFRICAN_RIFT.csv                                   7214
# YELLOWSTONE-SNAKE_RIVER_PLAIN_VOLCANIC_PROVINCE.csv     7148
# ANATOLIA-IRAN_BELT_-_CENOZOIC_QUATERNARY.csv            6917
# ANDEAN_ARC_2.csv                                        6878
# HONSHU_ARC_2.csv                                        6793
# IZU-BONIN_ARC.csv                                       5772
# NORTH_ATLANTIC_IGNEOUS_PROVINCE_OR_NAIP.csv             5731
# CENTRAL_ASIAN_FOLDBELT_-_MESOZOIC.csv                   5686
# SUPERIOR_PROVINCE_ARCHEAN.csv                           5493
# BASIN_AND_RANGE_-_GREAT_BASIN.csv                       5458
# MEXICAN_VOLCANIC_BELTS.csv                              5279
# EUROPEAN_OROGENIC_BELT_-_CENOZOIC_QUATERNARY.csv        5244
# AUSTRALIA_001.csv                                       4792
# NEW_ZEALAND.csv                                         4769
# KAMCHATKA_ARC.csv                                       4677
# CASCADES.csv                                            4612
# CANARY_ISLANDS.csv                                      4436
# CENTRAL_ASIAN_FOLDBELT_-_PALEOZOIC.csv                  4222
# CAPE_VERDE_ISLANDS.csv                                  4197
# HAWAIIAN_ISLANDS_2.csv                                  4050
# SIBERIAN_TRAPS.csv                                      3943
# CENTRAL_AMERICAN_VOLCANIC_ARC.csv                       3795
# DECCAN.csv                                              3661
# BALTIC_SHIELD_-_PROTEROZOIC.csv                         3619
# ALEUTIAN_ARC.csv                                        3420
# WEST_AUSTRALIAN_CRATON.csv                              3323
# TONGA_ARC.csv                                           3214
# BALTIC_SHIELD_-_ARCHEAN.csv                             3151
# EUROPEAN_OROGENIC_BELT_-_PALEOZOIC.csv                  3122
# KURILE_ARC.csv                                          3113
# CARPATHIAN_BELT_AND_PANNONIAN_BASIN.csv                 3062
# KAROO_AND_FERRAR_PROVINCES.csv                          3000
# LESSER_ANTILLES.csv                                     2797
# KAAPVAAL_CRATON_ARCHEAN.csv                             2776
# CENTRAL_ATLANTIC_MAGMATIC_PROVINCE_-_CAMP.csv           2708
# RYUKYU_ARC.csv                                          2681
# NEW_ZEALAND_001.csv                                     2471
# SUNDA_ARC.csv                                           2396
# AEOLIAN_ARC.csv                                         2353
# APPALACHIANS.csv                                        2275
# CENTRAL_ASIAN_FOLDBELT_-_PROTEROZOIC.csv                2245
# MARIANA_ARC.csv                                         2161
# ARABIAN-NUBIAN_SHIELD_-_PROTEROZOIC.csv                 2103
# ETNA_SICILY.csv                                         2049
# AEGEAN_ARC.csv                                          1962
# EMEISHAN.csv                                            1887
# NORTH_AMERICAN_CORDILLERA_-_CENOZOIC-QUATERNARY.csv     1876
# NORTH_ATLANTIC_CRATON_ARCHEAN.csv                       1820
# PARANA.csv                                              1759
# ARABIAN-NUBIAN_SHIELD_-_CENOZOIC_QUATERNARY.csv         1736
# LUZON_ARC.csv                                           1682
# ANTARCTICA.csv                                          1625
# MASCARENE_ISLANDS_INCL_REUNION.csv                      1602
# DHARWAR_CRATON_ARCHEAN.csv                              1538
# GREATER_ANTILLES.csv                                    1523
# BISMARCK_ARC_-_NEW_BRITAIN_ARC.csv                      1506
# SCOTIA_ARC.csv                                          1465
# NEW_HEBRIDES_ARC_-_VANUATU_ARCHIPELAGO.csv              1461
# AZORES.csv                                              1435
# MEXICAN_BASIN_AND_RANGE.csv                             1415
# LIGURIA-SARDO-TYRRHENIAN_ARC.csv                        1333
# MID-AFRICAN_RIFT_SYSTEM.csv                             1317
# KAAPVAAL_CRATON_MESOZOIC.csv                            1264
# AUSTRALIA.csv                                           1252
# GALAPAGOS_ISLANDS.csv                                   1150
# MIDCONTINENT_RIFT_SYSTEM_-_KEWEENAWAN.csv               1075
# ROSS_ISLAND.csv                                         1042
# MATACHEWAN_LARGE_IGNEOUS_PROVINCE.csv                   1031
# KERGUELEN.csv                                           1015
#                                                        ...
# s_COCOS_RIDGE_SEAMOUNTS.csv                               13
# s_MUSICIANS_SEAMOUNTS.csv                                 13
# s_CARNEGIE_RIDGE_SEAMOUNTS.csv                            12
# s_BETIC-RIF_OROGENIC_BELT_OR_GIBRALTAR_ARC.csv            12
# s_ANEWETAK_SEAMOUNT_TRAIL.csv                             12
# CHAGOS-LACCADIVE_RIDGE.csv                                12
# KOLBEINSEY_RIDGE.csv                                      12
# s_KERGUELEN.csv                                           12
# SARMATIAN_CRATON_ARCHEAN.csv                              11
# ANGOLA_SHIELD_MESOZOIC.csv                                11
# s_TASMANTID_SEAMOUNTS.csv                                 11
# s_BAHIA_CHAIN.csv                                         10
# ANGOLA_SHIELD_PROTEROZOIC.csv                             10
# s_NORTH_ATLANTIC_SEAMOUNTS.csv                            10
# JUAN_DE_FUCA_RIDGE.csv                                    10
# s_KINAN_ESCARPMENT.csv                                     9
# MAUD_RISE.csv                                              9
# s_IZU-BONIN_BACK-ARC_SEAMOUNT_CHAIN.csv                    9
# PARNAIBA_SEDIMENTARY_BASIN_PALEOZOIC.csv                   9
# AVANAVERA_LARGE_IGNEOUS_PROVINCE.csv                       9
# s_MARION_ISLANDS.csv                                       9
# TANZANIA_CRATON_CENOZOIC_QUATERNARY.csv                    8
# s_BATHYMETRISTS_OR_GRIMALDI_SEAMOUNT_CHAIN.csv             8
# s_EAST_SHIKOKU_BASIN_SEAMOUNTS.csv                         7
# EAST_PACIFIC_RISE.csv                                      7
# MID-ATLANTIC_RIDGE.csv                                     7
# s_DE_GERLACH_SEAMOUNTS.csv                                 6
# CARIBBEAN_LARGE_IGNEOUS_PROVINCE.csv                       6
# MENDOZA_RIFT.csv                                           6
# CARNEGIE__RIDGE.csv                                        6
# s_AZORES.csv                                               5
# MCDONALD_ISLANDS.csv                                       5
# s_LORD_HOWE_SEAMOUNT_CHAIN.csv                             5
# s_GENROKU_SEAMOUNT_CHAIN.csv                               5
# SCOTT_ISLAND.csv                                           5
# MADAGASCAR_RIDGE.csv                                       5
# s_RED_SEA_SEMOUNTS.csv                                     5
# s_SOUTHWESTERN_SEAMOUNT_PROVINCE.csv                       5
# BRAZIL_BASIN.csv                                           4
# AGULHAS_RIDGE.csv                                          4
# s_ENPO_SEAMOUNT_CHAIN.csv                                  4
# COSTA_RICA_RIFT.csv                                        4
# TUPA_VOLCANIC_FIELD.csv                                    4
# s_UJLAN_SEAMOUNTS.csv                                      4
# MEDITERRANEAN_RIDGE.csv                                    4
# CAPE_VERDE_RISE.csv                                        3
# s_DISCOVERY_TABLEMOUNT.csv                                 3
# PACIFIC_ANTARCTIC_RIDGE.csv                                3
# J-ANOMALY_RIDGE.csv                                        3
# s_CASTOR_GUYOT.csv                                         3
# DHARWAR_CRATON_MESOZOIC.csv                                3
# MAGELLAN_RISE.csv                                          3
# s_TYPHOON_SEAMOUNT_GROUP.csv                               2
# ARAVALLI_CRATON_MESOZOIC.csv                               2
# s_SOLITARY_SEAMOUNTS.csv                                   2
# SOUTH_ATLANTIC_RIDGE.csv                                   2
# COIBA_RIDGE.csv                                            2
# s_SHIKOKU_BASIN_FLOOR_NEAR_KINAN_SEAMOUNT_CHAIN.csv        2
# SOUTH_WEST_INDIAN_RIDGE.csv                                2
# CUVIER_OR_WALLABY_PLATEAU.csv                              2
# s_TARAVA_SEAMOUNT_CHAIN.csv                                2
# s_COIBA_RIDGE_SEAMOUNTS.csv                                2
# MIDDLE_AMERICA_TRENCH.csv                                  2
# s_JAPANESE_SEAMOUNT_TRAIL.csv                              1
# s_EXPLORER_SEAMOUNT_CHAIN.csv                              1
# MATSUMAE_PLATEAU.csv                                       1
# TUAMOTU_ISLANDS.csv                                        1
# FINGER_LAKES_FIELD_NEW_YORK.csv                            1
# SOUTHERN_MOHNS_RIDGE.csv                                   1
# SAO_PAULO_PLATEAU.csv                                      1
# APENNINIC-MAGHREBIDES_CHAIN_2.csv                          1
# s_UNION_SEAMOUNT_CHAIN.csv                                 1
# s_KAMCHATKA.csv                                            1
# APENNINIC-MAGHREBIDES_CHAIN_1.csv                          1
# ISLAS_ORCADAS_RISE.csv                                     1
# Name: FILENAME, Length: 443, dtype: int64

# %%
# (...)

master_file['LOCATION'].value_counts()
# Out:
# ICELAND / ICELAND / ATLANTIC OCEAN                                                                                                                                        2080
# ICELAND / ICELAND / NORTHERN ICELAND RIFT ZONE / ATLANTIC OCEAN                                                                                                           2007
# YELLOWSTONE-SNAKE RIVER PLAIN VOLCANIC PROVINCE / COLUMBIA PLATEAU-BLUE MOUNTAINS PROVINCE / GRANDE RONDE BASALT                                                          1661
# HAWAIIAN ISLANDS / HAWAII / KILAUEA / SHIELD STAGE / EAST RIFT ZONE / PUU OO ERUPTION / PACIFIC OCEAN                                                                     1599
# CAPE VERDE ISLANDS / FOGO / ATLANTIC OCEAN                                                                                                                                1444
# YELLOWSTONE-SNAKE RIVER PLAIN VOLCANIC PROVINCE / SNAKE RIVER PLAIN / BURNT BUTTE FORMATION                                                                                  1
# AUSTRALIA / SOUTH AUSTRALIAN CRATON / SOUTH AUSTRALIA / KANMANTOO GROUP - PETREL COVE FORMATION                                                                              1
# MALPELO RIDGE SEAMOUNTS / UNNAMED SEAMOUNT (MALPELO RIDGE SEAMOUNTS) / DREDGE 3 / PACIFIC OCEAN                                                                              1
# ANDEAN ARC / CENTRAL ANDEAN VOLCANIC ZONE / CHILE / CHIU CHIU IGNIMBRITE / PACIFIC OCEAN                                                                                     1
# ICELAND / ICELAND / SEYDISHOLAR / ATLANTIC OCEAN                                                                                                                             1
# IZU-BONIN ARC / IZU ARC / HONSHU / FUJI/HUZI / MARUYAMA CONE / PACIFIC OCEAN                                                                                                 1
# HONSHU ARC / CENTRAL HONSHU / HONSHU / GANKYOJI / USHIGATANI LAVA / PACIFIC OCEAN                                                                                            1
# HONSHU ARC / NORTHEASTERN HONSHU ARC / HONSHU / IWAKI / KUROMORI LAVA / PACIFIC OCEAN                                                                                        1
# HONSHU ARC / NORTHEASTERN HONSHU ARC / HONSHU / ZAO / OIWAKE LAVA / PACIFIC OCEAN                                                                                            1
# AUSTRALIA / TASMAN OROGEN / TASMANIA / MOUNT CLEVELAND FORMATION                                                                                                             1
# Name: LOCATION, Length: 18752, dtype: int64

# %%
# (...)

master_file['ROCK TYPE'].value_counts()
# Out:
# VOLCANIC ROCK       273894
# PLUTONIC ROCK        32835
# MANTLE XENOLITH       9562
# METAMORPHIC ROCK      7156
# SEDIMENTARY ROCK      4261
# VEIN                  1333
# ORE                    535
# PEGMATITE               74
# Name: ROCK TYPE, dtype: int64

# %%
# (...)

temp = master_file['ROCK NAME'].value_counts()
filter_ = re.compile('\[(\d)*\]')

temp.index = temp.index.astype(str).str.replace(filter_,'').str.strip().str.replace('  ',' ')
temp = temp.groupby(temp.index).sum().sort_values(ascending=False)
print(temp)
# Out:
# NOT GIVEN                                                             64402
# BASALT                                                                54384
# ANDESITE                                                              19487
# RHYOLITE                                                              17288
# THOLEIITE                                                             11967
# ANDESITE, BASALTIC                                                    11047
# DACITE                                                                10120
# BASALT, ALKALINE                                                       7702
# TRACHYTE                                                               5041
# BASANITE                                                               4755
# KIMBERLITE                                                             4501
# GABBRO                                                                 4295
# DOLERITE                                                               4071
# BASALT, THOLEIITIC                                                     3648
# KOMATIITE                                                              3492
# GRANITE                                                                3191
# PHONOLITE                                                              2871
# TRACHYBASALT                                                           2854
# HAWAIITE                                                               2377
# TRACHYANDESITE                                                         2127
# PICRITE                                                                2015
# BASALT, OLIVINE                                                        1948
# DIABASE                                                                1665
# RHYODACITE                                                             1617
# GRANODIORITE                                                           1563
# TRACHYANDESITE, BASALTIC                                               1333
# THOLEIITE, OLIVINE                                                     1287
# CARBONATITE                                                            1285
# BASALT, ALKALINE, OLIVINE                                              1281
# AMPHIBOLITE                                                            1256
# LHERZOLITE, SPINEL, XENOLITH                                           1210
# BASALT, TRANSITIONAL                                                   1112
# PERIDOTITE, XENOLITH                                                   1085
# SHOSHONITE                                                             1064
# NEPHELINITE                                                             980
# LAMPROPHYRE                                                             957
# LHERZOLITE, XENOLITH                                                    937
# DIORITE                                                                 916
# GNEISS                                                                  908
# MUGEARITE                                                               894
# ADAKITE                                                                 891
# SYENITE                                                                 839
# TEPHRITE                                                                790
# LATITE                                                                  788
# HARZBURGITE, XENOLITH                                                   787
# BASALT, KOMATIITIC                                                      778
# BONINITE                                                                696
# GRANULITE                                                               684
# ANDESITE, AUGITE-HYPERSTHENE                                            666
# TONALITE                                                                636
# ANKARAMITE                                                              596
# BASALT / NOT GIVEN                                                      591
# LAMPROITE                                                               573
# PERIDOTITE, SPINEL, XENOLITH                                            566
# BASALT, CALC-ALKALINE                                                   525
# THOLEIITE, QUARTZ                                                       503
# PHONOTEPHRITE                                                           499
# PYROXENITE                                                              494
# BENMOREITE                                                              489
# BASALT, ANDESITIC                                                       447
# SANDSTONE                                                               441
# SYENITE, NEPHELINE                                                      431
# PANTELLERITE                                                            430
# ANDESITE, PYROXENE                                                      423
# THOLEIITE / BASALT                                                      422
# PHONOLITE, TEPHRI                                                       416
# COMENDITE                                                               408
# BASALT, SUBALKALINE                                                     405
# DIORITE, QUARTZ                                                         392
# NEPHELINITE, OLIVINE                                                    385
# GRANOPHYRE                                                              381
# LHERZOLITE, GARNET, XENOLITH                                            375
# GREENSTONE                                                              374
# TRACHYDACITE                                                            366
# SERPENTINITE                                                            359
#                                                                       ...
# MONZOGABBRO, ALKALINE                                                     1
# MONZOGABBRO / MONZONITE                                                   1
# MONZOGABBRO / MONZODIORITE                                                1
# MONZODIORITE, QUARTZ-PYROXENE-HORNBLENDE                                  1
# MONZODIORITE, QUARTZ-HORNBLENDE                                           1
# TRACHYBASALT / SHOSHONITE                                                 1
# MONZODIORITE, QUARTZ-BIOTITE-AMPHIBOLE                                    1
# MONZODIORITE, BIOTITE-HORNBLENDE-PLAGIOCLASE                              1
# DACITE, HORNBLENDE-OLIGOCLASE                                             1
# MELILITOLITE, HAUYNE-WOLLASTONITE                                         1
# DANKJERNITE                                                               1
# DACITE, QUARTZ-AUGITE-HYPERSTHENE                                         1
# DACITE, QUARTZ-AUGITE-HYPERSTHENE-BIOTITE-HORNBLENDE / DACITE             1
# DACITE, QUARTZ-BIOTITE-PLAGIOCLASE                                        1
# DACITE, QUARTZ-CLINOPYROXENE-ORTHOPYROXENE-HORNBLENDE                     1
# DACITE, QUARTZ-HORNBLENDE                                                 1
# DACITE, QUARTZ-HORNBLENDE-2-PYROXENE                                      1
# DACITE, QUARTZ-HORNBLENDE-HYPERSTHENE                                     1
# DACITE, QUARTZ-PLAGIOCLASE                                                1
# DACITE, SANIDINE-BIOTITE-PLAGIOCLASE                                      1
# METAMUDSTONE                                                              1
# DACITE, THOLEIITIC / NOT GIVEN / DACITE                                   1
# DACITE, TRACHYTIC / DACITE                                                1
# DACITE, TRACHYTIC / RHYODACITE, ALKALINE                                  1
# SYENITE, PSEUDOLEUCITE                                                    1
# DELLENITE, BIOTITE-OLIGOCLASE                                             1
# DACITE, HORNBLENDE-ORTHOPYROXENE                                          1
# SYENITE, PYROXENE-AMPHIBOLE-BIOTITE                                       1
# METABASALT / BASALT                                                       1
# DIABASE / BASALT                                                          1
# METABASALT / ANDESITE, BASALTIC                                           1
# SYENITE, PYROXENE-AMPHIBOLE-BIOTITE-NEPHELINE                             1
# METAANDESITE                                                              1
# DIABASE, ALKALINE, OLIVINE                                                1
# SYENITE, PYROXENE-AMPHIBOLE-BIOTITE-QUARTZ                                1
# SYENITE, PYROXENE-BIOTITE-AMPHIBOLE                                       1
# MELILITOLITE, OLIVINE-MONTICELLITE                                        1
# SYENITE, PYROXNE-AMPHIBOLE-FAYALITE                                       1
# TRACHYANDESITE, SANIDINE-PLAGIOCLASE-PHLOGOPITE                           1
# MELILITOLITE, KALSILITE-LEUCITE / MELILITITE, LEUCITE-OLIVINE             1
# DIABASE, HORNBLENDE-AUGITE                                                1
# DACITE, QUARTZ-AUGITE-FAYALITE                                            1
# TRACHYBASALT / BASALT / NOT GIVEN / BASALT, ALKALINE                      1
# DACITE, PYROXENE-QUARTZ-BIOTITE                                           1
# DACITE, PYROXENE-OLIVINE                                                  1
# DACITE, HORNBLENDE-ORTHOPYROXENE-CLINOPYROXENE                            1
# MONCHIQUITE, NEPHELINE / BASALT, ALKALINE                                 1
# MONCHIQUITE, FELDSPAR                                                     1
# MONCHIQUITE / NEPHELINITE                                                 1
# MONCHIQUITE / LAMPROPHYRE                                                 1
# DACITE, HYPERSTHENE / BONINITE                                            1
# DACITE, HYPERSTHENE / DACITE                                              1
# MONCHIQUITE / BASANITE                                                    1
# SYENITE, NEPHELINE-AEGIRINE-ARFVEDSONITE-ZEOLITE-SODALITE                 1
# DACITE, HYPERSTHENE-BIOTITE                                               1
# SYENITE, NEPHELINE-AEGIRINE-ZEOLITE-SODALITE                              1
# MINETTE / LAMPROPHYRE / NOT GIVEN                                         1
# DACITE, HYPERSTHENE-HORNBLENDE-QUARTZ / DACITE, HYPERSTHENE-QUARTZ        1
# MINETTE / BASANITE                                                        1
# DACITE, LABRADORITE / ANDESITE, LABRADORITE                               1
# DACITE, LABRADORITE-AUGITE                                                1
# SYENITE, NEPHELINE-AUGITE-BIOTITE / SYENITE, NEPHELINE                    1
# DACITE, OLIVINE                                                           1
# DACITE, OLIVINE-AUGITE                                                    1
# DACITE, OLIVINE-HYPERSTHENE-AUGITE                                        1
# MIKENITE, OLIVINE                                                         1
# MIHARAITE                                                                 1
# DACITE, ORTHOPYROXENE-CLINOPYROXENE-HORNBLENDE                            1
# MIGMATITE, PLAGIOCLASE-BIOTITE                                            1
# MICASCHIST, FELDSPAR-GARNET                                               1
# SYENITE, NEPHELINE-SODALITE                                               1
# TRACHYBASALT / BASALT, ANDESINE                                           1
# METASHALE                                                                 1
# DACITE, PYROXENE-OLIGOCLASE                                               1
# HAWAIITE / BASALT, ANDESITIC                                              1
# Name: ROCK NAME, Length: 4645, dtype: int64

# %%
# (...)

# TODO
master_file.dtypes
# Out:
# FILENAME            object
# CITATIONS           object
# TECTONIC SETTING    object
# LOCATION            object
# LOCATION COMMENT    object
# LATITUDE MIN        object
# LATITUDE MAX        object
# LONGITUDE MIN       object
# LONGITUDE MAX       object
# LAND OR SEA         object
# ELEVATION MIN       object
# ELEVATION MAX       object
# SAMPLE NAME         object
# ROCK NAME           object
# MIN. AGE (YRS.)     object
# MAX. AGE (YRS.)     object
# GEOL.               object
# AGE                 object
# ERUPTION DAY        object
# ERUPTION MONTH      object
# ERUPTION YEAR       object
# ROCK TEXTURE        object
# ROCK TYPE           object
# DRILL DEPTH MIN     object
# DRILL DEPTHAX       object
# ALTERATION          object
# MINERAL             object
# MATERIAL            object
# SIO2(WT%)           object
# TIO2(WT%)           object
# B2O3(WT%)           object
# AL2O3(WT%)          object
# CR2O3(WT%)          object
# FE2O3(WT%)          object
# FEO(WT%)            object
# FEOT(WT%)           object
# CAO(WT%)            object
# MGO(WT%)            object
# MNO(WT%)            object
# NIO(WT%)            object
# K2O(WT%)            object
# NA2O(WT%)           object
# P2O5(WT%)           object
# H2O(WT%)            object
# H2OP(WT%)           object
# H2OM(WT%)           object
# H2OT(WT%)           object
# CO2(WT%)            object
# CO1(WT%)            object
# F(WT%)              object
# CL(WT%)             object
# CL2(WT%)            object
# OH(WT%)             object
# CH4(WT%)            object
# SO2(WT%)            object
# SO3(WT%)            object
# SO4(WT%)            object
# S(WT%)              object
# LOI(WT%)            object
# VOLATILES(WT%)      object
# O(WT%)              object
# OTHERS(WT%)         object
# HE(CCM/G)           object
# HE(CCMSTP/G)        object
# HE3(CCMSTP/G)       object
# HE3(AT/G)           object
# HE4(CCM/G)          object
# HE4(CCMSTP/G)       object
# HE4(AT/G)           object
# HE4(MOLE/G)         object
# HE4(NCC/G)          object
# HE(NCC/G)           object
# LI(PPM)             object
# BE(PPM)             object
# B(PPM)              object
#                      ...
# GE(PPM)             object
# AS(PPM)             object
# SE(PPM)             object
# BR(PPM)             object
# RB(PPM)             object
# SR(PPM)             object
# Y(PPM)              object
# ZR(PPM)             object
# NB(PPM)             object
# MO(PPM)             object
# RU(PPM)             object
# RH(PPM)             object
# PD(PPM)             object
# AG(PPM)             object
# CD(PPM)             object
# IN(PPM)             object
# SN(PPM)             object
# SB(PPM)             object
# TE(PPM)             object
# I(PPM)              object
# CS(PPM)             object
# BA(PPM)             object
# LA(PPM)             object
# CE(PPM)             object
# PR(PPM)             object
# ND(PPM)             object
# SM(PPM)             object
# EU(PPM)             object
# GD(PPM)             object
# TB(PPM)             object
# DY(PPM)             object
# HO(PPM)             object
# ER(PPM)             object
# TM(PPM)             object
# YB(PPM)             object
# LU(PPM)             object
# HF(PPM)             object
# TA(PPM)             object
# W(PPM)              object
# RE(PPM)             object
# OS(PPM)             object
# IR(PPM)             object
# PT(PPM)             object
# AU(PPM)             object
# HG(PPM)             object
# TL(PPM)             object
# PB(PPM)             object
# BI(PPM)             object
# TH(PPM)             object
# U(PPM)              object
# ND143_ND144         object
# ND143_ND144_INI     object
# EPSILON_ND          object
# SR87_SR86           object
# SR87_SR86_INI       object
# PB206_PB204         object
# PB206_PB204_INI     object
# PB207_PB204         object
# PB207_PB204_INI     object
# PB208_PB204         object
# PB208_PB204_INI     object
# OS184_OS188         object
# OS186_OS188         object
# OS187_OS186         object
# OS187_OS188         object
# RE187_OS186         object
# RE187_OS188         object
# HF176_HF177         object
# HE3_HE4             object
# HE3_HE4(R/R(A))     object
# HE4_HE3             object
# HE4_HE3(R/R(A))     object
# K40_AR40            object
# AR40_K40            object
# UNIQUE_ID           object
# Length: 172, dtype: object

# %% [markdown]
# # QA/QC
#
# (...)

# %%
# (...)

a = master_file.iloc[:, 29:171].count(axis=0)
a = len(master_file.index) - a
print(a)
# Out:
# TIO2(WT%)           62502
# B2O3(WT%)          330062
# AL2O3(WT%)          62636
# CR2O3(WT%)         319901
# FE2O3(WT%)         241247
# FEO(WT%)           247392
# FEOT(WT%)          147075
# CAO(WT%)            62518
# MGO(WT%)            60387
# MNO(WT%)            70211
# NIO(WT%)           325263
# K2O(WT%)            58429
# NA2O(WT%)           64170
# P2O5(WT%)           79028
# H2O(WT%)           309007
# H2OP(WT%)          292432
# H2OM(WT%)          297799
# H2OT(WT%)          330089
# CO2(WT%)           303520
# CO1(WT%)           330065
# F(WT%)             321696
# CL(WT%)            318895
# CL2(WT%)           329696
# OH(WT%)            329843
# CH4(WT%)           330073
# SO2(WT%)           329330
# SO3(WT%)           324186
# SO4(WT%)           330047
# S(WT%)             316738
# LOI(WT%)           198795
# VOLATILES(WT%)     330089
# O(WT%)             330087
# OTHERS(WT%)        330047
# HE(CCM/G)          330089
# HE(CCMSTP/G)       329035
# HE3(CCMSTP/G)      330089
# HE3(AT/G)          330089
# HE4(CCM/G)         330089
# HE4(CCMSTP/G)      330089
# HE4(AT/G)          330089
# HE4(MOLE/G)        330089
# HE4(NCC/G)         330089
# HE(NCC/G)          330089
# LI(PPM)            307447
# BE(PPM)            315190
# B(PPM)             324714
# C(PPM)             329656
# CO2(PPM)           329197
# F(PPM)             325937
# NA(PPM)            329888
# MG(PPM)            329761
# AL(PPM)            329876
# P(PPM)             327607
# S(PPM)             319831
# CL(PPM)            321218
# K(PPM)             326334
# CA(PPM)            328998
# SC(PPM)            212408
# TI(PPM)            318085
# V(PPM)             180351
# CR(PPM)            163344
# MN(PPM)            324516
# FE(PPM)            329819
# CO(PPM)            217799
# NI(PPM)            157148
# CU(PPM)            224104
# ZN(PPM)            214034
# GA(PPM)            253838
# GE(PPM)            325323
# AS(PPM)            319911
# SE(PPM)            328435
# BR(PPM)            329026
# RB(PPM)            121802
# SR(PPM)            113897
# Y(PPM)             145682
# ZR(PPM)            134304
# NB(PPM)            155409
# MO(PPM)            314394
# RU(PPM)            325409
# RH(PPM)            326538
# PD(PPM)            324025
# AG(PPM)            326374
# CD(PPM)            325485
# IN(PPM)            328300
# SN(PPM)            314397
# SB(PPM)            317713
# TE(PPM)            329417
# I(PPM)             329858
# CS(PPM)            255739
# BA(PPM)            140003
# LA(PPM)            169600
# CE(PPM)            169021
# PR(PPM)            240303
# ND(PPM)            179949
# SM(PPM)            188311
# EU(PPM)            198689
# GD(PPM)            226204
# TB(PPM)            215938
# DY(PPM)            227629
# HO(PPM)            239921
# ER(PPM)            229896
# TM(PPM)            250319
# YB(PPM)            198581
# LU(PPM)            208186
# HF(PPM)            219739
# TA(PPM)            228137
# W(PPM)             317690
# RE(PPM)            325121
# OS(PPM)            323924
# IR(PPM)            324521
# PT(PPM)            324255
# AU(PPM)            324998
# HG(PPM)            329422
# TL(PPM)            321040
# PB(PPM)            217620
# BI(PPM)            325485
# TH(PPM)            182087
# U(PPM)             214355
# ND143_ND144        273693
# ND143_ND144_INI    329634
# EPSILON_ND         329778
# SR87_SR86          261889
# SR87_SR86_INI      328314
# PB206_PB204        297436
# PB206_PB204_INI    329795
# PB207_PB204        297549
# PB207_PB204_INI    329796
# PB208_PB204        297575
# PB208_PB204_INI    329795
# OS184_OS188        330029
# OS186_OS188        329997
# OS187_OS186        329850
# OS187_OS188        325521
# RE187_OS186        329908
# RE187_OS188        326623
# HF176_HF177        322217
# HE3_HE4            328953
# HE3_HE4(R/R(A))    326929
# HE4_HE3            329426
# HE4_HE3(R/R(A))    329968
# K40_AR40           330089
# AR40_K40           329915
# dtype: int64

# %%
# (...)

# PARAMETERS #
value = 180000    # (...)
index_ignore = [] # (...)
index_keep   = [] # (...)
##############

index_ = (a > value) & ~ a.index.isin(index_keep) | a.index.isin(index_ignore)

# %%
# (...)

filtered_file = master_file.copy();

# Removes columns with too many missing data
filtered_file.drop(a[index_].index.values, axis=1, inplace=True)

# Removes samples with missing data
filtered_file.dropna(subset=a[~ index_].index.values, inplace=True)

# %%
print('Shape of the df dataset after transformation:', str(filtered_file.shape), 'Out of:', str(master_file.shape))
filtered_file.head()
# Out:
# Shape of the df dataset after transformation: (67233, 50) Out of: (330089, 172)
#              FILENAME CITATIONS      TECTONIC SETTING  \
# 1    ADRIA_DOMAIN.csv   [11431]  INTRAPLATE VOLCANICS
# 3    ADRIA_DOMAIN.csv   [11431]  INTRAPLATE VOLCANICS
# 4    ADRIA_DOMAIN.csv   [11431]  INTRAPLATE VOLCANICS
# 5    ADRIA_DOMAIN.csv   [11431]  INTRAPLATE VOLCANICS
# 126  ADRIA_DOMAIN.csv    [9694]  INTRAPLATE VOLCANICS
#
#                                               LOCATION  \
# 1    ADRIA DOMAIN / ADRIATIC FORELAND / ABRUZZO / M...
# 3    ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...
# 4    ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...
# 5    ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...
# 126  ADRIA DOMAIN / SOUTHERN ALPS / VENETO VOLCANIC...
#
#                                  LOCATION COMMENT LATITUDE MIN LATITUDE MAX  \
# 1                                             NaN           42           42
# 3                                             NaN         39.5         40.5
# 4                                             NaN         39.5         40.5
# 5                                             NaN         39.5         40.5
# 126  SAN GIOVANNI ILARIONE, EASTERN MONTI LESSINI         45.5         45.5
#
#     LONGITUDE MIN LONGITUDE MAX LAND OR SEA ELEVATION MIN ELEVATION MAX  \
# 1              14            14   SUBAERIAL           NaN           NaN
# 3              16          16.5   SUBAERIAL           NaN           NaN
# 4              16          16.5   SUBAERIAL           NaN           NaN
# 5              16          16.5   SUBAERIAL           NaN           NaN
# 126         11.25         11.25   SUBAERIAL           NaN           NaN
#
#             SAMPLE NAME                            ROCK NAME MIN. AGE (YRS.)  \
# 1    s QUEGLIA1 [11431]                  LAMPROPHYRE [11431]             NaN
# 3          s 88 [11431]                    NOT GIVEN [11431]             NaN
# 4         s 124 [11431]                    NOT GIVEN [11431]             NaN
# 5         s 125 [11431]                    NOT GIVEN [11431]             NaN
# 126       s 6MLH [9694]  LHERZOLITE, SPINEL, XENOLITH [9694]             NaN
#
#     MAX. AGE (YRS.) GEOL.                AGE ERUPTION DAY ERUPTION MONTH  \
# 1               NaN   NaN     EOCENE [11431]          NaN            NaN
# 3               NaN   NaN  PALEOGENE [11431]          NaN            NaN
# 4               NaN   NaN  PALEOGENE [11431]          NaN            NaN
# 5               NaN   NaN  PALEOGENE [11431]          NaN            NaN
# 126             NaN   NaN                NaN          NaN            NaN
#
#     ERUPTION YEAR           ROCK TEXTURE        ROCK TYPE DRILL DEPTH MIN  \
# 1             NaN                    NaN    PLUTONIC ROCK             NaN
# 3             NaN                    NaN    VOLCANIC ROCK             NaN
# 4             NaN                    NaN    VOLCANIC ROCK             NaN
# 5             NaN                    NaN    VOLCANIC ROCK             NaN
# 126           NaN  PROTOGRANULAR [9694]   MANTLE XENOLITH             NaN
#
#     DRILL DEPTHAX ALTERATION MINERAL             MATERIAL SIO2(WT%) TIO2(WT%)  \
# 1             NaN        NaN     NaN  WHOLE_ROCK [11431]       34.6      3.38
# 3             NaN        NaN     NaN  WHOLE_ROCK [11431]      44.59      2.79
# 4             NaN        NaN     NaN  WHOLE_ROCK [11431]      40.38      2.79
# 5             NaN        NaN     NaN  WHOLE_ROCK [11431]      42.56      2.78
# 126           NaN        NaN     NaN   WHOLE_ROCK [9694]      44.94      0.09
#
#     AL2O3(WT%) FEOT(WT%) CAO(WT%) MGO(WT%) MNO(WT%) K2O(WT%) NA2O(WT%)  \
# 1         8.38      8.98    15.92    17.66     0.18     0.53      0.38
# 3        11.06     11.79    10.95     8.86     0.18     2.37      3.19
# 4        10.27      9.25    16.76     9.18     0.16     0.74      5.09
# 5        10.45      8.88    15.98    10.05     0.14      1.5      3.91
# 126       3.43       7.7     3.69    37.64     0.13      0.1      0.26
#
#     P2O5(WT%) CR(PPM) NI(PPM) RB(PPM) SR(PPM) Y(PPM) ZR(PPM) NB(PPM) BA(PPM)  \
# 1        0.98     392     242      21     811   31.1     362     122    1089
# 3        0.79     302     206      31     575   26.4     269      74     707
# 4        0.82     112      59      18     688   26.4     284      89     391
# 5        0.83     232      69      22     680   23.7     282      68     673
# 126       0.1    3049    1895    4.41    20.4   3.19    3.81   0.914    9.62
#
#     LA(PPM) CE(PPM) ND(PPM) UNIQUE_ID
# 1        89     150    66.8    336640
# 3      52.5     101    50.9    336642
# 4      67.1     129    66.2    336643
# 5        54     109      58    336644
# 126    0.68    1.66    0.66    487553
