# %% [markdown]
# # Discriminating rock samples' tectonic settings using machine learning
#
# (...)

# %%
import sys
import getpass
print("User :", getpass.getuser())
print("Python version :", sys.version)
# %load_ext watermark
# %watermark -i -v -m -p pandas,numpy,matplotlib,sklearn
# Out:
# User : CloudyOverhead
# Python version : 3.6.1 |Anaconda 4.4.0 (64-bit)| (default, May 11 2017, 13:09:58)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]
# 2017-07-18T10:38:48-04:00
#
# CPython 3.6.1
# IPython 5.3.0
#
# pandas 0.20.1
# numpy 1.12.1
# matplotlib 2.0.2
# sklearn 0.18.1
#
# compiler   : GCC 4.4.7 20120313 (Red Hat 4.4.7-1)
# system     : Linux
# release    : 3.10.0-514.21.1.el7.x86_64
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 32
# interpreter: 64bit

# %%
# %matplotlib inline

import time
import datetime

import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import random as rd
import numpy as np
import os
import re

from itertools import count, cycle

from sklearn.svm import SVC
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import (f1_score, make_scorer, confusion_matrix, mean_absolute_error, 
                             median_absolute_error, mean_squared_error)
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, LeavePGroupsOut, cross_val_predict

import tensorflow as tf

from matplotlib.colors import Normalize

pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows', 150)



class MidpointNormalize(Normalize):
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y))

    
def file_split_gen(file, n_out=1, n_splits=1, seed=None):

    if n_out * n_splits > len(file.unique()):
        raise IndexError

    if seed is not None:
        rd.seed(seed)

    groups = list(file.unique())
    rd.shuffle(groups)
    current = 0

    for _ in range(n_splits):
        train_set = file.copy()
        test_set = file.copy()

        group = groups[current:current + n_out]
        train_set = train_set[~ train_set.isin(group)]
        test_set = test_set[test_set.isin(group)]
        current += n_out

        yield train_set.index, test_set.index


def to_int(y):
    y = y.replace({'ARCHEAN CRATON': 0,
                   'CONVERGENT MARGIN': 1,
                   'FLOOD BASALT': 2,
                   'INTRAPLATE VOLCANICS': 3,
                   'OCEAN ISLAND': 4,
                   'RIFT VOLCANICS': 5})
    return y


def one_hot(y):
    y = tf.constant(y.as_matrix())
    with tf.Session():
        return tf.one_hot(y, 6).eval()

# %% [markdown]
# ## Concatenate Georoc database

# %% [markdown]
# ### Concatenation
#
# Concatenation of the *.csv* files contained in */Georoc_files* into a single *master.csv* file at source.

# %%
# Files from /Georoc_files are opened one by one and stored as DataFrames in the *files* list.

dir_ = os.curdir + '/Georoc_files'
files = os.listdir(dir_)

nb_data = 0

for file, file_no in zip(files, count()):

    file = pd.read_csv(dir_ + '/' + file, encoding='iso-8859-1', dtype=object)

    index = np.where(file.CITATIONS.values == 'References:')[0][0]
    file = file[:index]
    file.insert(0, 'FILENAME', files[file_no])

    nb_data += file.shape[0]
    files[file_no] = file

# %%
# Files are regrouped in *master_file*. *nb_data* was needed because of the *.append* method being resources-expensive.

master_file = pd.DataFrame(index=np.arange(0, nb_data), columns=files[0].axes[1])
current_row = 0

row_no = 0
for file in files:
    for _, row in file.iterrows():
        master_file.loc[row_no] = row
        row_no += 1

del files, file

# %%
# Volcanic rocks, duplicates and unnecessary columns are removed.
master_file = master_file[master_file['ROCK TYPE'] == 'VOLCANIC ROCK']
master_file.drop_duplicates(subset='UNIQUE_ID', inplace=True)
master_file.drop('Unnamed: 171', axis=1, inplace=True)

# Tectonics settings are formatted identically.
master_file['TECTONIC SETTING'] = master_file['TECTONIC SETTING'].str.upper()

# *SEAMOUNT* and *SUBMARINE RIDGE* tectonic settings are removed, as those are topography types and not formation processes, and
# thus geochemistry can provide no informative insight. *COMPLEX VOLCANIC SETTINGS* is removed as this tectonic setting is an
# amalgam of settings.
master_file = master_file[~ master_file['TECTONIC SETTING'].isin(['SEAMOUNT', 'SUBMARINE RIDGE', 'COMPLEX VOLCANIC SETTINGS'])]

# *OCEAN PLATEAU*, *CONTINENTAL FLOOD BASALT* and *OCEAN-BASIN FLOOD BASALT* tectonic settings are regrouped under the label
# *FLOOD BASALT*, as they have the same formation process.
master_file = master_file.replace(['OCEANIC PLATEAU', 'CONTINENTAL FLOOD BASALT', 'OCEAN-BASIN FLOOD BASALT'], 'FLOOD BASALT')

# For praticality, *ARCHEAN CRATON (INCLUDING GREENSTONE BELTS)* is formatted into *ARCHEAN CRATON*.
master_file = master_file.replace(['ARCHEAN CRATON (INCLUDING GREENSTONE BELTS)'], 'ARCHEAN CRATON')

# Removing data messed with the indexing.
master_file = master_file.reset_index(drop=True)

# %%
# Data under limit of detection is formatted to half the limit of detection.

for row_no, row in master_file.iloc[:, 28:171].iterrows():
    for col_no, data in zip(count(), row):
        data = str(data).strip()

        if data[0] == '-':  # Data under limit of detection has format *-data*. *<data* is not used
            master_file.iloc[row_no, col_no + 28] = -float(data) / 2

#         elif data[0] == '<':
#             print(master_file.iloc[row_no, col_no + 28])
#             master_file.iloc[row_no, col_no + 28] = float(data.lstrip(['<', '='])) / 2
#             print(master_file.iloc[row_no, col_no + 28])
#         else:
#             data = float(data)  # failsafe

# %%
# Data is saved in *master.csv* at source, allowing it to be reloaded for future uses.

master_file.to_csv(os.curdir + '/master.csv', index=False)

# %% [markdown]
# ### Load master

# %%
# Should be used on reloads to produce faster results.

master_file = pd.read_csv(os.curdir + '/master.csv', encoding='iso-8859-1', dtype=object)

# %% [markdown]
# ### Statistics

# %%
print ('Shape of the dataset after transformation:' + str(master_file.shape))
master_file.head()
# Out:
# Shape of the dataset after transformation:(263528, 172)
#            FILENAME CITATIONS      TECTONIC SETTING  \
# 0  ADRIA_DOMAIN.csv   [11431]  INTRAPLATE VOLCANICS
# 1  ADRIA_DOMAIN.csv   [11431]  INTRAPLATE VOLCANICS
# 2  ADRIA_DOMAIN.csv   [11431]  INTRAPLATE VOLCANICS
# 3  ADRIA_DOMAIN.csv   [11689]  INTRAPLATE VOLCANICS
# 4  ADRIA_DOMAIN.csv   [11689]  INTRAPLATE VOLCANICS
#
#                                             LOCATION       LOCATION COMMENT  \
# 0  ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...                    NaN
# 1  ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...                    NaN
# 2  ADRIA DOMAIN / ADRIATIC FORELAND / APULIA / PI...                    NaN
# 3  ADRIA DOMAIN / SOUTHERN ALPS / VENETO VOLCANIC...                    NaN
# 4  ADRIA DOMAIN / SOUTHERN ALPS / VENETO VOLCANIC...  WESTERN MONTI LESSINI
#
#   LATITUDE MIN LATITUDE MAX LONGITUDE MIN LONGITUDE MAX LAND OR SEA  \
# 0         39.5         40.5            16          16.5   SUBAERIAL
# 1         39.5         40.5            16          16.5   SUBAERIAL
# 2         39.5         40.5            16          16.5   SUBAERIAL
# 3        45.83        45.83         11.17         11.17   SUBAERIAL
# 4        45.68        45.68         11.22         11.22   SUBAERIAL
#
#   ELEVATION MIN ELEVATION MAX     SAMPLE NAME                  ROCK NAME  \
# 0           NaN           NaN    s 88 [11431]          NOT GIVEN [11431]
# 1           NaN           NaN   s 124 [11431]          NOT GIVEN [11431]
# 2           NaN           NaN   s 125 [11431]          NOT GIVEN [11431]
# 3           NaN           NaN  s PDF1 [11689]  NEPHELINITE, MELA [11689]
# 4           NaN           NaN   s 12D [11689]  NEPHELINITE, MELA [11689]
#
#   MIN. AGE (YRS.) MAX. AGE (YRS.) GEOL.                AGE ERUPTION DAY  \
# 0             NaN             NaN   NaN  PALEOGENE [11431]          NaN
# 1             NaN             NaN   NaN  PALEOGENE [11431]          NaN
# 2             NaN             NaN   NaN  PALEOGENE [11431]          NaN
# 3             NaN             NaN   NaN  PALEOGENE [11689]          NaN
# 4             NaN             NaN   NaN  PALEOGENE [11689]          NaN
#
#   ERUPTION MONTH ERUPTION YEAR ROCK TEXTURE      ROCK TYPE DRILL DEPTH MIN  \
# 0            NaN           NaN          NaN  VOLCANIC ROCK             NaN
# 1            NaN           NaN          NaN  VOLCANIC ROCK             NaN
# 2            NaN           NaN          NaN  VOLCANIC ROCK             NaN
# 3            NaN           NaN          NaN  VOLCANIC ROCK             NaN
# 4            NaN           NaN          NaN  VOLCANIC ROCK             NaN
#
#   DRILL DEPTHAX ALTERATION MINERAL             MATERIAL SIO2(WT%) TIO2(WT%)  \
# 0           NaN        NaN     NaN  WHOLE_ROCK [11431]      44.59      2.79
# 1           NaN        NaN     NaN  WHOLE_ROCK [11431]      40.38      2.79
# 2           NaN        NaN     NaN  WHOLE_ROCK [11431]      42.56      2.78
# 3           NaN        NaN     NaN  WHOLE_ROCK [11689]      38.48      2.22
# 4           NaN        NaN     NaN  WHOLE_ROCK [11689]       40.2      2.48
#
#   B2O3(WT%) AL2O3(WT%) CR2O3(WT%) FE2O3(WT%) FEO(WT%) FEOT(WT%) CAO(WT%)  \
# 0       NaN      11.06        NaN        NaN      NaN     11.79    10.95
# 1       NaN      10.27        NaN        NaN      NaN      9.25    16.76
# 2       NaN      10.45        NaN        NaN      NaN      8.88    15.98
# 3       NaN      12.31        NaN       1.43     9.55       NaN    13.86
# 4       NaN       10.7        NaN       1.39      9.3       NaN    11.41
#
#   MGO(WT%) MNO(WT%) NIO(WT%) K2O(WT%) NA2O(WT%) P2O5(WT%) H2O(WT%) H2OP(WT%)  \
# 0     8.86     0.18      NaN     2.37      3.19      0.79      NaN       NaN
# 1     9.18     0.16      NaN     0.74      5.09      0.82      NaN       NaN
# 2    10.05     0.14      NaN      1.5      3.91      0.83      NaN       NaN
# 3     9.87     0.15      NaN     1.09      1.78      1.19      NaN       NaN
# 4     16.7     0.15      NaN     1.15      1.53      1.64      NaN       NaN
#
#   H2OM(WT%) H2OT(WT%) CO2(WT%) CO1(WT%) F(WT%) CL(WT%) CL2(WT%) OH(WT%)  \
# 0       NaN       NaN      NaN      NaN    NaN     NaN      NaN     NaN
# 1       NaN       NaN      NaN      NaN    NaN     NaN      NaN     NaN
# 2       NaN       NaN      NaN      NaN    NaN     NaN      NaN     NaN
# 3       NaN       NaN      NaN      NaN    NaN     NaN      NaN     NaN
# 4       NaN       NaN      NaN      NaN    NaN     NaN      NaN     NaN
#
#   CH4(WT%) SO2(WT%) SO3(WT%) SO4(WT%) S(WT%) LOI(WT%) VOLATILES(WT%) O(WT%)  \
# 0      NaN      NaN      NaN      NaN    NaN     2.11            NaN    NaN
# 1      NaN      NaN      NaN      NaN    NaN     3.52            NaN    NaN
# 2      NaN      NaN      NaN      NaN    NaN     1.92            NaN    NaN
# 3      NaN      NaN      NaN      NaN    NaN     8.08            NaN    NaN
# 4      NaN      NaN      NaN      NaN    NaN     3.35            NaN    NaN
#
#   OTHERS(WT%) HE(CCM/G) HE(CCMSTP/G) HE3(CCMSTP/G) HE3(AT/G) HE4(CCM/G)  \
# 0         NaN       NaN          NaN           NaN       NaN        NaN
# 1         NaN       NaN          NaN           NaN       NaN        NaN
# 2         NaN       NaN          NaN           NaN       NaN        NaN
# 3         NaN       NaN          NaN           NaN       NaN        NaN
# 4         NaN       NaN          NaN           NaN       NaN        NaN
#
#   HE4(CCMSTP/G) HE4(AT/G) HE4(MOLE/G) HE4(NCC/G) HE(NCC/G) LI(PPM) BE(PPM)  \
# 0           NaN       NaN         NaN        NaN       NaN     NaN     NaN
# 1           NaN       NaN         NaN        NaN       NaN     NaN     NaN
# 2           NaN       NaN         NaN        NaN       NaN     NaN     NaN
# 3           NaN       NaN         NaN        NaN       NaN     NaN     NaN
# 4           NaN       NaN         NaN        NaN       NaN     NaN     NaN
#
#   B(PPM)    ...    GE(PPM) AS(PPM) SE(PPM) BR(PPM) RB(PPM) SR(PPM) Y(PPM)  \
# 0    NaN    ...        NaN     NaN     NaN     NaN      31     575   26.4
# 1    NaN    ...        NaN     NaN     NaN     NaN      18     688   26.4
# 2    NaN    ...        NaN     NaN     NaN     NaN      22     680   23.7
# 3    NaN    ...        NaN     NaN     NaN     NaN      32    1036   24.1
# 4    NaN    ...        NaN     NaN     NaN     NaN      25     890   25.7
#
#   ZR(PPM) NB(PPM) MO(PPM) RU(PPM) RH(PPM) PD(PPM) AG(PPM) CD(PPM) IN(PPM)  \
# 0     269      74     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     284      89     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     282      68     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     284      79     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     266      73     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   SN(PPM) SB(PPM) TE(PPM) I(PPM) CS(PPM) BA(PPM) LA(PPM) CE(PPM) PR(PPM)  \
# 0     NaN     NaN     NaN    NaN     NaN     707    52.5     101      12
# 1     NaN     NaN     NaN    NaN     NaN     391    67.1     129      16
# 2     NaN     NaN     NaN    NaN     NaN     673      54     109    13.5
# 3     NaN     NaN     NaN    NaN     NaN     468    65.9     135    15.9
# 4     NaN     NaN     NaN    NaN     NaN     738    69.7     138    16.3
#
#   ND(PPM) SM(PPM) EU(PPM) GD(PPM) TB(PPM) DY(PPM) HO(PPM) ER(PPM) TM(PPM)  \
# 0    50.9      10    2.86     9.1    1.25    5.84    0.98    2.61    0.32
# 1    66.2    12.5    3.61    10.5    1.41    6.74    1.01    2.58     0.3
# 2      58    11.3    3.43      10    1.34    5.86    0.95    2.32    0.26
# 3    60.8    11.1    3.19    10.9     1.3    6.53    0.98    2.35    0.28
# 4    64.1    11.9    3.51    10.9    1.34    6.64    1.03    2.41    0.29
#
#   YB(PPM) LU(PPM) HF(PPM) TA(PPM) W(PPM) RE(PPM) OS(PPM) IR(PPM) PT(PPM)  \
# 0    1.79    0.25     NaN     NaN    NaN     NaN     NaN     NaN     NaN
# 1    1.75    0.24     NaN     NaN    NaN     NaN     NaN     NaN     NaN
# 2    1.65    0.22     NaN     NaN    NaN     NaN     NaN     NaN     NaN
# 3    1.67    0.22     NaN     NaN    NaN     NaN     NaN     NaN     NaN
# 4    1.67    0.22     NaN     NaN    NaN     NaN     NaN     NaN     NaN
#
#   AU(PPM) HG(PPM) TL(PPM) PB(PPM) BI(PPM) TH(PPM) U(PPM) ND143_ND144  \
# 0     NaN     NaN     NaN     NaN     NaN     6.4   1.58         NaN
# 1     NaN     NaN     NaN     NaN     NaN    9.06   2.46         NaN
# 2     NaN     NaN     NaN     NaN     NaN    5.79   1.46         NaN
# 3     NaN     NaN     NaN     NaN     NaN    6.39   1.54         NaN
# 4     NaN     NaN     NaN     NaN     NaN    8.05   2.36         NaN
#
#   ND143_ND144_INI EPSILON_ND SR87_SR86 SR87_SR86_INI PB206_PB204  \
# 0             NaN        NaN       NaN           NaN         NaN
# 1             NaN        NaN       NaN           NaN         NaN
# 2             NaN        NaN       NaN           NaN         NaN
# 3             NaN        NaN       NaN           NaN         NaN
# 4             NaN        NaN       NaN           NaN         NaN
#
#   PB206_PB204_INI PB207_PB204 PB207_PB204_INI PB208_PB204 PB208_PB204_INI  \
# 0             NaN         NaN             NaN         NaN             NaN
# 1             NaN         NaN             NaN         NaN             NaN
# 2             NaN         NaN             NaN         NaN             NaN
# 3             NaN         NaN             NaN         NaN             NaN
# 4             NaN         NaN             NaN         NaN             NaN
#
#   OS184_OS188 OS186_OS188 OS187_OS186 OS187_OS188 RE187_OS186 RE187_OS188  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   HF176_HF177 HE3_HE4 HE3_HE4(R/R(A)) HE4_HE3 HE4_HE3(R/R(A)) K40_AR40  \
# 0         NaN     NaN             NaN     NaN             NaN      NaN
# 1         NaN     NaN             NaN     NaN             NaN      NaN
# 2         NaN     NaN             NaN     NaN             NaN      NaN
# 3         NaN     NaN             NaN     NaN             NaN      NaN
# 4         NaN     NaN             NaN     NaN             NaN      NaN
#
#   AR40_K40 UNIQUE_ID
# 0      NaN    336642
# 1      NaN    336643
# 2      NaN    336644
# 3      NaN    487272
# 4      NaN    487273
#
# [5 rows x 172 columns]

# %%
# Column names

pd.Series(master_file.axes[1])
# Out:
# 0              FILENAME
# 1             CITATIONS
# 2      TECTONIC SETTING
# 3              LOCATION
# 4      LOCATION COMMENT
# 5          LATITUDE MIN
# 6          LATITUDE MAX
# 7         LONGITUDE MIN
# 8         LONGITUDE MAX
# 9           LAND OR SEA
# 10        ELEVATION MIN
# 11        ELEVATION MAX
# 12          SAMPLE NAME
# 13            ROCK NAME
# 14      MIN. AGE (YRS.)
# 15      MAX. AGE (YRS.)
# 16                GEOL.
# 17                  AGE
# 18         ERUPTION DAY
# 19       ERUPTION MONTH
# 20        ERUPTION YEAR
# 21         ROCK TEXTURE
# 22            ROCK TYPE
# 23      DRILL DEPTH MIN
# 24        DRILL DEPTHAX
# 25           ALTERATION
# 26              MINERAL
# 27             MATERIAL
# 28            SIO2(WT%)
# 29            TIO2(WT%)
# 30            B2O3(WT%)
# 31           AL2O3(WT%)
# 32           CR2O3(WT%)
# 33           FE2O3(WT%)
# 34             FEO(WT%)
# 35            FEOT(WT%)
# 36             CAO(WT%)
# 37             MGO(WT%)
# 38             MNO(WT%)
# 39             NIO(WT%)
# 40             K2O(WT%)
# 41            NA2O(WT%)
# 42            P2O5(WT%)
# 43             H2O(WT%)
# 44            H2OP(WT%)
# 45            H2OM(WT%)
# 46            H2OT(WT%)
# 47             CO2(WT%)
# 48             CO1(WT%)
# 49               F(WT%)
# 50              CL(WT%)
# 51             CL2(WT%)
# 52              OH(WT%)
# 53             CH4(WT%)
# 54             SO2(WT%)
# 55             SO3(WT%)
# 56             SO4(WT%)
# 57               S(WT%)
# 58             LOI(WT%)
# 59       VOLATILES(WT%)
# 60               O(WT%)
# 61          OTHERS(WT%)
# 62            HE(CCM/G)
# 63         HE(CCMSTP/G)
# 64        HE3(CCMSTP/G)
# 65            HE3(AT/G)
# 66           HE4(CCM/G)
# 67        HE4(CCMSTP/G)
# 68            HE4(AT/G)
# 69          HE4(MOLE/G)
# 70           HE4(NCC/G)
# 71            HE(NCC/G)
# 72              LI(PPM)
# 73              BE(PPM)
# 74               B(PPM)
#              ...
# 97              GE(PPM)
# 98              AS(PPM)
# 99              SE(PPM)
# 100             BR(PPM)
# 101             RB(PPM)
# 102             SR(PPM)
# 103              Y(PPM)
# 104             ZR(PPM)
# 105             NB(PPM)
# 106             MO(PPM)
# 107             RU(PPM)
# 108             RH(PPM)
# 109             PD(PPM)
# 110             AG(PPM)
# 111             CD(PPM)
# 112             IN(PPM)
# 113             SN(PPM)
# 114             SB(PPM)
# 115             TE(PPM)
# 116              I(PPM)
# 117             CS(PPM)
# 118             BA(PPM)
# 119             LA(PPM)
# 120             CE(PPM)
# 121             PR(PPM)
# 122             ND(PPM)
# 123             SM(PPM)
# 124             EU(PPM)
# 125             GD(PPM)
# 126             TB(PPM)
# 127             DY(PPM)
# 128             HO(PPM)
# 129             ER(PPM)
# 130             TM(PPM)
# 131             YB(PPM)
# 132             LU(PPM)
# 133             HF(PPM)
# 134             TA(PPM)
# 135              W(PPM)
# 136             RE(PPM)
# 137             OS(PPM)
# 138             IR(PPM)
# 139             PT(PPM)
# 140             AU(PPM)
# 141             HG(PPM)
# 142             TL(PPM)
# 143             PB(PPM)
# 144             BI(PPM)
# 145             TH(PPM)
# 146              U(PPM)
# 147         ND143_ND144
# 148     ND143_ND144_INI
# 149          EPSILON_ND
# 150           SR87_SR86
# 151       SR87_SR86_INI
# 152         PB206_PB204
# 153     PB206_PB204_INI
# 154         PB207_PB204
# 155     PB207_PB204_INI
# 156         PB208_PB204
# 157     PB208_PB204_INI
# 158         OS184_OS188
# 159         OS186_OS188
# 160         OS187_OS186
# 161         OS187_OS188
# 162         RE187_OS186
# 163         RE187_OS188
# 164         HF176_HF177
# 165             HE3_HE4
# 166     HE3_HE4(R/R(A))
# 167             HE4_HE3
# 168     HE4_HE3(R/R(A))
# 169            K40_AR40
# 170            AR40_K40
# 171           UNIQUE_ID
# Length: 172, dtype: object

# %%
# Samples contained per file

master_file['FILENAME'].value_counts()
# Out:
# APENNINIC-MAGHREBIDES_CHAIN.csv                          10571
# ICELAND.csv                                               9163
# HAWAIIAN_ISLANDS_1.csv                                    8058
# HONSHU_ARC_1.csv                                          7657
# YELLOWSTONE-SNAKE_RIVER_PLAIN_VOLCANIC_PROVINCE.csv       7093
# ANATOLIA-IRAN_BELT_-_CENOZOIC_QUATERNARY.csv              6572
# ANDEAN_ARC_1.csv                                          6412
# CENTRAL_ASIAN_FOLDBELT_-_CENOZOIC_QUATERNARY.csv          6319
# ANDEAN_ARC_2.csv                                          6303
# EAST_AFRICAN_RIFT.csv                                     6183
# IZU-BONIN_ARC.csv                                         5658
# HONSHU_ARC_2.csv                                          5375
# MEXICAN_VOLCANIC_BELTS.csv                                5069
# BASIN_AND_RANGE_-_GREAT_BASIN.csv                         4925
# NORTH_ATLANTIC_IGNEOUS_PROVINCE_OR_NAIP.csv               4621
# NEW_ZEALAND.csv                                           4455
# CASCADES.csv                                              4346
# EUROPEAN_OROGENIC_BELT_-_CENOZOIC_QUATERNARY.csv          4284
# KAMCHATKA_ARC.csv                                         4281
# CENTRAL_ASIAN_FOLDBELT_-_MESOZOIC.csv                     4259
# HAWAIIAN_ISLANDS_2.csv                                    3922
# SUPERIOR_PROVINCE_ARCHEAN.csv                             3754
# CAPE_VERDE_ISLANDS.csv                                    3743
# CANARY_ISLANDS.csv                                        3743
# CENTRAL_AMERICAN_VOLCANIC_ARC.csv                         3678
# CENTRAL_ASIAN_FOLDBELT_-_PALEOZOIC.csv                    3407
# SIBERIAN_TRAPS.csv                                        3390
# AUSTRALIA_001.csv                                         3381
# DECCAN.csv                                                3051
# ALEUTIAN_ARC.csv                                          2975
# TONGA_ARC.csv                                             2819
# KAROO_AND_FERRAR_PROVINCES.csv                            2740
# LESSER_ANTILLES.csv                                       2659
# WEST_AUSTRALIAN_CRATON.csv                                2506
# KURILE_ARC.csv                                            2458
# CARPATHIAN_BELT_AND_PANNONIAN_BASIN.csv                   2426
# EUROPEAN_OROGENIC_BELT_-_PALEOZOIC.csv                    2396
# RYUKYU_ARC.csv                                            2269
# SUNDA_ARC.csv                                             2242
# KAAPVAAL_CRATON_ARCHEAN.csv                               2172
# AEOLIAN_ARC.csv                                           2163
# BALTIC_SHIELD_-_PROTEROZOIC.csv                           2059
# NEW_ZEALAND_001.csv                                       1989
# AEGEAN_ARC.csv                                            1919
# APPALACHIANS.csv                                          1909
# CENTRAL_ATLANTIC_MAGMATIC_PROVINCE_-_CAMP.csv             1888
# MARIANA_ARC.csv                                           1877
# BALTIC_SHIELD_-_ARCHEAN.csv                               1835
# PARANA.csv                                                1707
# LUZON_ARC.csv                                             1613
# CENTRAL_ASIAN_FOLDBELT_-_PROTEROZOIC.csv                  1584
# NORTH_AMERICAN_CORDILLERA_-_CENOZOIC-QUATERNARY.csv       1503
# MASCARENE_ISLANDS_INCL_REUNION.csv                        1481
# ARABIAN-NUBIAN_SHIELD_-_CENOZOIC_QUATERNARY.csv           1479
# ARABIAN-NUBIAN_SHIELD_-_PROTEROZOIC.csv                   1457
# NEW_HEBRIDES_ARC_-_VANUATU_ARCHIPELAGO.csv                1410
# DHARWAR_CRATON_ARCHEAN.csv                                1378
# SCOTIA_ARC.csv                                            1325
# GREATER_ANTILLES.csv                                      1316
# AZORES.csv                                                1300
# BISMARCK_ARC_-_NEW_BRITAIN_ARC.csv                        1282
# LIGURIA-SARDO-TYRRHENIAN_ARC.csv                          1280
# MEXICAN_BASIN_AND_RANGE.csv                               1215
# ANTARCTICA.csv                                            1205
# GALAPAGOS_ISLANDS.csv                                     1106
# MID-AFRICAN_RIFT_SYSTEM.csv                               1090
# EMEISHAN.csv                                              1079
# ROSS_ISLAND.csv                                           1039
# ETHIOPIAN_PLATEAU.csv                                      916
# AUSTRAL-COOK_ISLANDS.csv                                   837
# CARIBBEAN-COLOMBIAN_PLATEAU.csv                            801
# MARQUESAS.csv                                              770
# MIDCONTINENT_RIFT_SYSTEM_-_KEWEENAWAN.csv                  750
# NORTH_ATLANTIC_CRATON_ARCHEAN.csv                          729
# RED_SEA_RIFT.csv                                           668
#                                                          ...
# ROSS_OROGEN-TRANSANTARCTIC_MOUNTAINS_-_CAMBRIAN.csv         33
# AHU_VOLCANIC_FIELD.csv                                      32
# ARGO_ABYSSAL_PLAIN;INDIAN_OCEAN.csv                         30
# SARMATIAN_CRATON_PROTEROZOIC.csv                            30
# NORTH_AMERICAN_CORDILLERA_-_PROTEROZOIC.csv                 29
# PETER_I_ISLAND.csv                                          29
# WESTERN_ALPS.csv                                            27
# DESVENTURADOS_ISLANDS.csv                                   27
# WEST-AFRICAN_COASTAL_BELTS_-_PAN-AFRICAN.csv                27
# EUROPEAN_OROGENIC_BELT_-_MESOZOIC.csv                       25
# VERKHOYANSK-CHUKOTKA_COLLISION_ZONE.csv                     25
# NATURALISTE_PLATEAU.csv                                     24
# WEST_AFRICAN_CRATON_ARCHEAN.csv                             23
# GREAT_METEOR_OR_NEW_ENGLAND_HOTSPOT_TRACK_OR_CONT.csv       23
# NANDALING_-_YANSHAN_BELT.csv                                23
# CHAGAI-RASKOH_ARC.csv                                       23
# HIKURANGI_PLATEAU.csv                                       23
# MARATHON_LARGE_IGNEOUS_PROVINCE.csv                         22
# ANGOLA_SHIELD_PALEOZOIC.csv                                 21
# KATANGAN_BASIN.csv                                          21
# KAAPVAAL_CRATON_PALEOZOIC.csv                               20
# TIBESTI_VOLCANIC_PROVINCE.csv                               20
# GULF_OF_SUEZ_RIFT.csv                                       19
# CHAD_RIFT_BASINS.csv                                        18
# SAO_LUIS_CRATON_CRATON_PROTEROZOIC.csv                      17
# APENNINIC-MAGHREBIDES_CHAIN_1.csv                           17
# EUROPEAN_OROGENIC_BELT_-_CENOZOIC.csv                       17
# CENTRAL_INDIAN_TECTONIC_ZONE.csv                            17
# AUSTRALIA_002.csv                                           16
# MASCARENE_PLATEAU.csv                                       16
# UMU_VOLCANIC_FIELD.csv                                      16
# TALKEETNA_ARC.csv                                           15
# BALLENY_ISLANDS.csv                                         15
# TANZANIA_CRATON_PROTEROZOIC.csv                             15
# MAKKOVIK-KETILIDIAN_OROGENIC_BELT.csv                       15
# GAWLER_CRATON.csv                                           14
# SIBERIAN_CRATON_PALEOZOIC.csv                               14
# SIBERIAN_CRATON_PROTEROZOIC.csv                             14
# KYUSHU-PALAU_RIDGE.csv                                      14
# VILUY_TRAPS.csv                                             14
# SOUTH_TETHYAN_SUTURE_ZONE_-_PAKISTAN.csv                    13
# UMKONDO_LARGE_IGNEOUS_PROVINCE.csv                          13
# HIMALAYA.csv                                                12
# UKRAINIAN_SHIELD_ARCHEAN.csv                                11
# ANGOLA_SHIELD_MESOZOIC.csv                                  11
# SARMATIAN_CRATON_ARCHEAN.csv                                11
# ANGOLA_SHIELD_PROTEROZOIC.csv                               10
# APENNINIC-MAGHREBIDES_CHAIN_2.csv                            9
# PARNAIBA_SEDIMENTARY_BASIN_PALEOZOIC.csv                     9
# ANTARCTICA_-_PALEOZOIC.csv                                   9
# MAUD_RISE.csv                                                9
# AVANAVERA_LARGE_IGNEOUS_PROVINCE.csv                         9
# CONGO_CRATON.csv                                             8
# UBENDIAN_BELT.csv                                            7
# NAMAQUALAND_NATAL_BELT_CENOZOIC.csv                          7
# TANZANIA_CRATON_CENOZOIC_QUATERNARY.csv                      7
# CARIBBEAN_LARGE_IGNEOUS_PROVINCE.csv                         6
# NAMAQUALAND_NATAL_BELT_PALEOZOIC.csv                         6
# NORTH_ATLANTIC_CRATON_MESOZOIC.csv                           5
# MCDONALD_ISLANDS.csv                                         5
# ZIMBABWE_CRATON.csv                                          5
# SCOTT_ISLAND.csv                                             5
# BRAZIL_BASIN.csv                                             4
# TUPA_VOLCANIC_FIELD.csv                                      4
# CAPE_VERDE_RISE.csv                                          3
# MAGELLAN_RISE.csv                                            3
# DHARWAR_CRATON_MESOZOIC.csv                                  3
# MADAGASCAR_SEYCHELLES_PROTEROZOIC.csv                        2
# UKRAINIAN_SHIELD_PROTEROZOIC.csv                             2
# CUVIER_OR_WALLABY_PLATEAU.csv                                2
# PENOKEAN_OROGEN.csv                                          2
# TUAMOTU_ISLANDS.csv                                          1
# MATSUMAE_PLATEAU.csv                                         1
# SAO_PAULO_PLATEAU.csv                                        1
# SIBERIAN_CRATON_CENOZOIC_QUATERNARY.csv                      1
# Name: FILENAME, Length: 305, dtype: int64

# %%
# Samples obtained per rock name

temp = master_file['ROCK NAME'].value_counts()
filter_ = r'\[(\d)*\]'

# Citations are removed from the index so that identical rock names have identical indexes.
temp.index = temp.index.astype(str).str.replace(filter_,'').str.strip().str.replace('  ',' ')

# Samples with identical rock names are regrouped
temp = temp.groupby(temp.index).sum().sort_values(ascending=False)
print(temp)
# Out:
# NOT GIVEN                                                                           52853
# BASALT                                                                              51809
# ANDESITE                                                                            19244
# RHYOLITE                                                                            17189
# THOLEIITE                                                                           11461
# ANDESITE, BASALTIC                                                                  10746
# DACITE                                                                               9912
# BASALT, ALKALINE                                                                     6757
# TRACHYTE                                                                             4952
# BASANITE                                                                             4628
# KIMBERLITE                                                                           4437
# KOMATIITE                                                                            3492
# BASALT, THOLEIITIC                                                                   3400
# DOLERITE                                                                             3085
# PHONOLITE                                                                            2860
# TRACHYBASALT                                                                         2134
# TRACHYANDESITE                                                                       2058
# BASALT, OLIVINE                                                                      1915
# PICRITE                                                                              1914
# HAWAIITE                                                                             1820
# RHYODACITE                                                                           1592
# DIABASE                                                                              1493
# TRACHYANDESITE, BASALTIC                                                             1317
# THOLEIITE, OLIVINE                                                                   1245
# BASALT, ALKALINE, OLIVINE                                                            1233
# SHOSHONITE                                                                           1021
# BASALT, TRANSITIONAL                                                                  960
# NEPHELINITE                                                                           949
# ADAKITE                                                                               886
# LATITE                                                                                788
# BASALT, KOMATIITIC                                                                    778
# TEPHRITE                                                                              760
# MUGEARITE                                                                             734
# BONINITE                                                                              688
# ANDESITE, AUGITE-HYPERSTHENE                                                          665
# LAMPROITE                                                                             573
# ANKARAMITE                                                                            567
# BASALT / NOT GIVEN                                                                    566
# BASALT, CALC-ALKALINE                                                                 504
# THOLEIITE, QUARTZ                                                                     501
# PHONOTEPHRITE                                                                         499
# BASALT, ANDESITIC                                                                     445
# BENMOREITE                                                                            433
# PANTELLERITE                                                                          429
# ANDESITE, PYROXENE                                                                    423
# PHONOLITE, TEPHRI                                                                     416
# THOLEIITE / BASALT                                                                    404
# BASALT, SUBALKALINE                                                                   402
# COMENDITE                                                                             394
# NEPHELINITE, OLIVINE                                                                  382
# TRACHYDACITE                                                                          366
# ANDESITE, THOLEIITIC                                                                  356
# TRACHYTE, ALKALINE                                                                    316
# ANDESITE / NOT GIVEN                                                                  314
# ANDESITE, HORNBLENDE                                                                  311
# BASALT, PICRITIC                                                                      295
# KOMATIITE, PERIDOTITIC                                                                291
# ANDESITE, HYPERSTHENE-AUGITE                                                          270
# LEUCITITE                                                                             270
# CARBONATITE                                                                           251
# PHONOLITE, AEGIRINE-SODALITE-ZEOLITE-NEPHELINE                                          1
# BASALT, TRANSITIONAL / NOT GIVEN / BASALT, ALKALINE / BASALT                            1
# PHONOLITE, AEGIRINE-CANCRINITE                                                          1
# PHONOLITE, AEGIRINE-ARFVEDSONITE-SODALITE-NEPHELINE                                     1
# BASALT, TRANSITIONAL / THOLEIITE, TRANSITIONAL / BASALT / NOT GIVEN                     1
# BASALT, TRANSITIONAL / TRACHYBASALT                                                     1
# BASALT, TRANSITIONAL / TRACHYTE / COMENDITE                                             1
# PHONOLITE, AEGIRINE-AMPHIBOLE-BIOTITE                                                   1
# PHONOLITE / TRACHYBASALT                                                                1
# TRACHYTE, FAYALITE                                                                      1
# BASANITE / BASALT, ALKALINE / NOT GIVEN                                                 1
# PHONOLITE / TRACHYANDESITE                                                              1
# BASANITE / BASALT, NEPHELINE                                                            1
# BASANITE / BASANITE, ANALCIME / BASALT, ALKALINE                                        1
# BASANITE / BASANITE, NEPHELINE / BASALT, ALKALINE                                       1
# BASANITE / HAWAIITE                                                                     1
# BASANITE / HAWAIITE, NEPHELINE                                                          1
# BASANITE / MELAFOIDITE                                                                  1
# PHONOLITE, AEGIRINE-COSSIRITE                                                           1
# PHONOLITE, ALKALIFELDSPAR                                                               1
# BASALT, THOLEIITIC, OLIVINE-AUGITE                                                      1
# BASALT, TRANSITIONAL / COMENDITE                                                        1
# PHONOLITE, LEUCITE-NEPHELINE                                                            1
# PHONOLITE, LEUCITE, TEPHRITIC / NOT GIVEN                                               1
# TRACHYRHYODACITE, ALKALINE                                                              1
# BASALT, THOLEIITIC, TRANSITIONAL / BASALT / BASALT, OLIVINE / ANDESITE, BASALTIC        1
# BASALT, THOLEIITIC, TRANSITIONAL / TRACHYANDESITE                                       1
# PHONOLITE, KAERSUTITE                                                                   1
# PHONOLITE, CANCRINITE-BIOTITE                                                           1
# BASALT, TRACHYTIC / TRACHYBASALT                                                        1
# BASALT, TRACHYTIC, HORNBLENDE-BIOTITE                                                   1
# TRACHYTE, HEDENBERGITE                                                                  1
# TRACHYTE, HAUYNE                                                                        1
# BASALT, TRANSITIONAL / BASALT / BASALT, ALKALINE                                        1
# BASALT, TRANSITIONAL / BASALT / NOT GIVEN                                               1
# BASALT, TRANSITIONAL / BASALT / PICRITE                                                 1
# PHONOLITE, ANALCIME                                                                     1
# PHONOLITE, AMPHIBOLE                                                                    1
# BASALT, TRANSITIONAL / BASALT, ALKALINE / NOT GIVEN                                     1
# TRACHYBASALT, OLIVINE-TITANAUGITE                                                       1
# Name: ROCK NAME, Length: 2606, dtype: int64

# %%
# Samples obtained per tectonic setting

master_file['TECTONIC SETTING'].value_counts()
# Out:
# CONVERGENT MARGIN       96893
# INTRAPLATE VOLCANICS    56862
# OCEAN ISLAND            41105
# FLOOD BASALT            35321
# RIFT VOLCANICS          19080
# ARCHEAN CRATON          14265
# Name: TECTONIC SETTING, dtype: int64

# %% [markdown]
# ### QA/QC
#
# Elements columns that doesn't contain enough data are dropped. Next, samples with missing observations in the remaining columns are dropped.

# %%
# Number of missing observations per element.

a = master_file.iloc[:, 28:-1].count(axis=0)
a = len(master_file.index) - a
print(a)
# Out:
# SIO2(WT%)           40076
# TIO2(WT%)           43653
# B2O3(WT%)          263516
# AL2O3(WT%)          43997
# CR2O3(WT%)         257718
# FE2O3(WT%)         192555
# FEO(WT%)           197575
# FEOT(WT%)          111286
# CAO(WT%)            43934
# MGO(WT%)            42363
# MNO(WT%)            50285
# NIO(WT%)           261112
# K2O(WT%)            39058
# NA2O(WT%)           45129
# P2O5(WT%)           56828
# H2O(WT%)           245587
# H2OP(WT%)          233659
# H2OM(WT%)          238728
# H2OT(WT%)          263526
# CO2(WT%)           243281
# CO1(WT%)           263506
# F(WT%)             256493
# CL(WT%)            253757
# CL2(WT%)           263223
# OH(WT%)            263302
# CH4(WT%)           263520
# SO2(WT%)           262816
# SO3(WT%)           258712
# SO4(WT%)           263492
# S(WT%)             254591
# LOI(WT%)           157659
# VOLATILES(WT%)     263526
# O(WT%)             263524
# OTHERS(WT%)        263510
# HE(CCM/G)          263526
# HE(CCMSTP/G)       262621
# HE3(CCMSTP/G)      263526
# HE3(AT/G)          263526
# HE4(CCM/G)         263526
# HE4(CCMSTP/G)      263526
# HE4(AT/G)          263526
# HE4(MOLE/G)        263526
# HE4(NCC/G)         263526
# HE(NCC/G)          263526
# LI(PPM)            245645
# BE(PPM)            251486
# B(PPM)             259544
# C(PPM)             263273
# CO2(PPM)           262826
# F(PPM)             260434
# NA(PPM)            263469
# MG(PPM)            263252
# AL(PPM)            263350
# P(PPM)             261700
# S(PPM)             256273
# CL(PPM)            256533
# K(PPM)             260809
# CA(PPM)            262596
# SC(PPM)            166898
# TI(PPM)            254525
# V(PPM)             141638
# CR(PPM)            127096
# MN(PPM)            259490
# FE(PPM)            263385
# CO(PPM)            173726
# NI(PPM)            122496
# CU(PPM)            178358
# ZN(PPM)            168345
# GA(PPM)            200859
# GE(PPM)            259931
# AS(PPM)            256128
# SE(PPM)            262480
# BR(PPM)            262806
# RB(PPM)             94978
# SR(PPM)             89223
# Y(PPM)             112506
# ZR(PPM)            102259
# NB(PPM)            120110
# MO(PPM)            250590
# RU(PPM)            260862
# RH(PPM)            261339
# PD(PPM)            260162
# AG(PPM)            260843
# CD(PPM)            259899
# IN(PPM)            262179
# SN(PPM)            251610
# SB(PPM)            253806
# TE(PPM)            263143
# I(PPM)             263339
# CS(PPM)            203632
# BA(PPM)            107090
# LA(PPM)            133751
# CE(PPM)            133081
# PR(PPM)            192765
# ND(PPM)            144517
# SM(PPM)            152373
# EU(PPM)            158611
# GD(PPM)            181073
# TB(PPM)            172685
# DY(PPM)            182286
# HO(PPM)            192549
# ER(PPM)            184133
# TM(PPM)            200857
# YB(PPM)            158764
# LU(PPM)            166499
# HF(PPM)            174954
# TA(PPM)            181218
# W(PPM)             253926
# RE(PPM)            260857
# OS(PPM)            260276
# IR(PPM)            260307
# PT(PPM)            260250
# AU(PPM)            260382
# HG(PPM)            263040
# TL(PPM)            256095
# PB(PPM)            171811
# BI(PPM)            260138
# TH(PPM)            142936
# U(PPM)             170870
# ND143_ND144        219185
# ND143_ND144_INI    263127
# EPSILON_ND         263250
# SR87_SR86          210776
# SR87_SR86_INI      262010
# PB206_PB204        236387
# PB206_PB204_INI    263253
# PB207_PB204        236432
# PB207_PB204_INI    263254
# PB208_PB204        236421
# PB208_PB204_INI    263253
# OS184_OS188        263480
# OS186_OS188        263460
# OS187_OS186        263314
# OS187_OS188        261328
# RE187_OS186        263382
# RE187_OS188        261979
# HF176_HF177        256982
# HE3_HE4            262724
# HE3_HE4(R/R(A))    261364
# HE4_HE3            263329
# HE4_HE3(R/R(A))    263433
# K40_AR40           263526
# AR40_K40           263380
# dtype: int64

# %%
# Elements with quantity of missing observations over *value* are dropped, with the exception of elements 
# in *index_keep*, and with the addition of elements in *index_drop*.

# PARAMETERS #
value = 152000  # Deletion threshold  (52: 152000)
index_drop = []  # ['MNO(WT%)', 'ND(PPM)', 'RB(PPM)']  # Deleted elements
index_keep = []  # ['TA(PPM)', 'HF(PPM)', 'SC(PPM)', 'TH(PPM)', 'CE(PPM)', 'ZR(PPM)', 'NB(PPM)', 'Y(PPM)']  # Preserved elements
##############

index_ = (a > value) & ~ a.index.isin(index_keep) | a.index.isin(index_drop)

# %%
# A file with deleted data is created. The original is unaltered.

filtered_file = master_file.copy();

# Removes columns with too much missing data
filtered_file.drop(a[index_].index.values, axis=1, inplace=True)

# Removes samples with missing data
filtered_file.dropna(subset=a[~ index_].index.values, inplace=True)

filtered_file = filtered_file.reset_index(drop=True)  # Removing data messes with the indexing

# %%
print('Shape of the dataset after transformation:', str(filtered_file.shape), 'Out of:', str(master_file.shape), '\n')
print(filtered_file.iloc[:, 28:-1].axes[1], '\n')
print(filtered_file['TECTONIC SETTING'].value_counts())
# Out:
# Shape of the dataset after transformation: (46690, 52) Out of: (263526, 172)
#
# Index(['SIO2(WT%)', 'TIO2(WT%)', 'AL2O3(WT%)', 'FEOT(WT%)', 'CAO(WT%)',
#        'MGO(WT%)', 'MNO(WT%)', 'K2O(WT%)', 'NA2O(WT%)', 'P2O5(WT%)', 'V(PPM)',
#        'CR(PPM)', 'NI(PPM)', 'RB(PPM)', 'SR(PPM)', 'Y(PPM)', 'ZR(PPM)',
#        'NB(PPM)', 'BA(PPM)', 'LA(PPM)', 'CE(PPM)', 'ND(PPM)', 'TH(PPM)'],
#       dtype='object')
#
# INTRAPLATE VOLCANICS    15837
# CONVERGENT MARGIN       13055
# FLOOD BASALT             6175
# OCEAN ISLAND             5138
# ARCHEAN CRATON           3454
# RIFT VOLCANICS           3031
# Name: TECTONIC SETTING, dtype: int64

# %% [markdown]
# ## Analysis
#
# Use either *lazy* or *custom* creation of sets.

# %% [markdown]
# ##### Lazy creation of training and testing sets:

# %%
X = filtered_file.iloc[:, 28:-1]
y = filtered_file['TECTONIC SETTING']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.55, random_state=42)

# %% [markdown]
# ##### Custom creation of training and testing sets:
# Allows splitting data by filenames.

# %%
# Reinitializes the generator.

generator = file_split_gen(filtered_file['FILENAME'], n_out=30, n_splits=3, seed=43)

# %%
# Splits the data. Run this cell again to progress through the splits.

train_ind, test_ind = next(generator)
X = filtered_file.iloc[:, 28:-1]
y = filtered_file['TECTONIC SETTING']

X_train, X_test = X.iloc[train_ind].reset_index(drop=True), X.iloc[test_ind].reset_index(drop=True)
y_train, y_test = y.iloc[train_ind].reset_index(drop=True), y.iloc[test_ind].reset_index(drop=True)
filenames_train = filtered_file['FILENAME'].iloc[train_ind].reset_index(drop=True)

count_ = y_test.value_counts()
print(count_, '\n')
print(len(count_), 'settings out of 6.')
print("Test data:", y_test.shape[0], "Out of:", filtered_file.shape[0])
print(len(filtered_file['FILENAME'][test_ind].value_counts()), 'test files out of', len(filtered_file['FILENAME'].value_counts()))
# Out:
# CONVERGENT MARGIN       2153
# INTRAPLATE VOLCANICS    1521
# OCEAN ISLAND            1492
# ARCHEAN CRATON           501
# RIFT VOLCANICS           391
# FLOOD BASALT             300
# Name: TECTONIC SETTING, dtype: int64
#
# 6 settings out of 6.
# Test data: 6358 Out of: 46690
# 30 test files out of 234

# %% [markdown]
# ### 1) SVM

# %%
# Launching the grid search.

C_range = 10.0 ** (np.arange(1, 4))
gamma_range= 10.0 ** (np.arange(-4, -1))
param_grid = dict(svc__C=C_range, svc__gamma=gamma_range)
pipeline = make_pipeline(StandardScaler(), SVC(cache_size=2000, class_weight='balanced'))
f1_scorer = make_scorer(f1_score, average='weighted')

start = datetime.datetime.now()
print("Start time :", start)

# Regular grid search.
# grid = GridSearchCV(pipeline, param_grid, cv=2, scoring=f1_scorer, n_jobs=-1, verbose=2)

# Grid search using file splitting.
cv = file_split_gen(filenames_train, n_out=20, n_splits=2, seed=43)
grid = GridSearchCV(pipeline, param_grid, cv=cv, scoring=f1_scorer, n_jobs=-1, verbose=2)

# Data fitting.
clf = grid.fit(X_train, y_train)  # Will take quite some time. View the progress on the console.

end = datetime.datetime.now()
print("Start time:", end)
print("Time elapsed:", end - start, '\n')

print("Best parameters set found on development set:")
print(clf.cv_results_['params'][clf.best_index_])
print("Score: %0.03f" % clf.best_score_)
# Out:
# Start time : 2017-07-18 09:35:02.366383
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [CV] svc__C=10.0, svc__gamma=0.0001 ..................................
# [CV] svc__C=10.0, svc__gamma=0.0001 ..................................
# [CV] svc__C=10.0, svc__gamma=0.001 ...................................
# [CV] svc__C=10.0, svc__gamma=0.001 ...................................
# [CV] svc__C=10.0, svc__gamma=0.01 ....................................
# [CV] svc__C=10.0, svc__gamma=0.01 ....................................
# [CV] svc__C=100.0, svc__gamma=0.0001 .................................
# [CV] svc__C=100.0, svc__gamma=0.0001 .................................
# [CV] svc__C=100.0, svc__gamma=0.001 ..................................
# [CV] svc__C=100.0, svc__gamma=0.001 ..................................
# [CV] svc__C=100.0, svc__gamma=0.01 ...................................
# [CV] svc__C=100.0, svc__gamma=0.01 ...................................
# [CV] svc__C=1000.0, svc__gamma=0.0001 ................................
# [CV] svc__C=1000.0, svc__gamma=0.0001 ................................
# [CV] svc__C=1000.0, svc__gamma=0.001 .................................
# [CV] svc__C=1000.0, svc__gamma=0.001 .................................
# [CV] svc__C=1000.0, svc__gamma=0.01 ..................................
# [CV] svc__C=1000.0, svc__gamma=0.01 ..................................
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] .................... svc__C=100.0, svc__gamma=0.01, total= 1.4min
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] ..................... svc__C=10.0, svc__gamma=0.01, total= 1.4min
# [CV] .................... svc__C=100.0, svc__gamma=0.01, total= 1.6min
# [CV] ..................... svc__C=10.0, svc__gamma=0.01, total= 1.5min
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] ................... svc__C=100.0, svc__gamma=0.001, total= 1.6min
# [Parallel(n_jobs=-1)]: Done   5 out of  18 | elapsed:  2.5min remaining:  6.5min
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] ................... svc__C=100.0, svc__gamma=0.001, total= 1.8min
# [CV] .................. svc__C=1000.0, svc__gamma=0.001, total= 1.9min
# [CV] .................... svc__C=10.0, svc__gamma=0.001, total= 1.9min
# [CV] .................. svc__C=1000.0, svc__gamma=0.001, total= 2.0min
# [CV] ................. svc__C=1000.0, svc__gamma=0.0001, total= 1.9min
# [CV] .................. svc__C=100.0, svc__gamma=0.0001, total= 1.9min
# [CV] .................... svc__C=10.0, svc__gamma=0.001, total= 2.0min
# [CV] .................. svc__C=100.0, svc__gamma=0.0001, total= 2.1min
# [CV] ................. svc__C=1000.0, svc__gamma=0.0001, total= 2.1min
# [CV] ................... svc__C=1000.0, svc__gamma=0.01, total= 2.4min
# [Parallel(n_jobs=-1)]: Done  15 out of  18 | elapsed:  3.1min remaining:   37.5s
# [CV] ................... svc__C=1000.0, svc__gamma=0.01, total= 2.5min
# [CV] ................... svc__C=10.0, svc__gamma=0.0001, total= 2.3min
# [CV] ................... svc__C=10.0, svc__gamma=0.0001, total= 2.4min
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:  3.5min finished
# Start time: 2017-07-18 09:40:05.274456
# Time elapsed: 0:05:02.908073
#
# Best parameters set found on development set:
# {'svc__C': 100.0, 'svc__gamma': 0.01}
# Score: 0.398

# %%
# Visualizing score per combination.

scores = clf.cv_results_['mean_test_score'].reshape((len(C_range), len(gamma_range)))
print("Mean scores:", '\n', scores)

stddev = clf.cv_results_['std_test_score'].reshape((len(C_range), len(gamma_range)))
print("Standard deviation:", '\n', stddev)

plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=0.3, right=0.8, bottom=0.3, top=0.8)
plt.imshow(scores, interpolation='nearest', cmap=plt.cm.hot, norm=MidpointNormalize(vmin=0.2, midpoint=0.83))
plt.xlabel('gamma')
plt.ylabel('C')
plt.colorbar()
plt.xticks(np.arange(len(gamma_range)), gamma_range, rotation=45)
plt.yticks(np.arange(len(C_range)), C_range)
plt.title('Validation accuracy')
plt.show()
# Out:
# Mean scores:
#  [[ 0.33983853  0.38044451  0.39623428]
#  [ 0.36491447  0.39397007  0.3982029 ]
#  [ 0.37700814  0.39572079  0.39203481]]
# Standard deviation:
#  [[ 0.08709503  0.09384678  0.07225311]
#  [ 0.09298568  0.08117955  0.06095616]
#  [ 0.07500299  0.07691411  0.04272331]]

# %%
# Selecting the best parameters and estimating success scores on test data.

best_C     = 10 ** (2)
best_gamma = 10 ** (-2)

pipeline = make_pipeline(StandardScaler(), SVC(C=best_C, gamma=best_gamma, cache_size=2000, class_weight='balanced'))
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)

# %%
# Viewing validation results.

f1 = f1_score(y_test, y_pred, average='weighted')

conf = confusion_matrix(y_test, y_pred)
conf = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]  # Normalizes
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.gray, norm=Normalize(1, 0))
plt.xlabel('Predicted')
plt.ylabel('Data')
plt.colorbar()
labels = sorted(filtered_file['TECTONIC SETTING'].unique())
range_ = np.arange(len(labels))
plt.xticks(range_, labels, rotation=90)
plt.yticks(range_, labels)
plt.title('Validation accuracy')

print('f1:', str(f1))
print('Train data:', y_train.shape[0], 'Test data:', y_test.shape[0])
plt.show()
# Out:
# f1: 0.64833883841
# Train data: 40332 Test data: 6358

# %% [markdown]
# ### 2) Nearest Neighbors

# %%
# Launching the grid search.

# neighbors_range = np.arange(10, 101, 10)
neighbors_range = np.arange(1, 11)
# neighbors_range = 10.0 ** (np.arange(0, 5))
weights = ['uniform', 'distance']
param_grid = dict(kneighborsclassifier__n_neighbors=neighbors_range, kneighborsclassifier__weights=weights)
pipeline = make_pipeline(StandardScaler(), KNeighborsClassifier())
# print(pipeline.get_params().keys())
f1_scorer = make_scorer(f1_score, average='weighted')

start = datetime.datetime.now()
print("Start time :", start)

# Regular grid search.
# grid = GridSearchCV(pipeline, param_grid, cv=2, scoring=f1_scorer, n_jobs=-1, verbose=2)

# Grid search using file splitting.
cv = file_split_gen(filenames_train, n_out=8, n_splits=2, seed=43)
grid = GridSearchCV(pipeline, param_grid, cv=cv, scoring=f1_scorer, n_jobs=-1, verbose=2)

# Data fitting.
clf = grid.fit(X_train, y_train)  # Will take quite some time. View the progress on the console.

end = datetime.datetime.now()
print("Start time:", end)
print("Time elapsed:", end - start, '\n')

print("Best parameters set found on development set:")
print(clf.cv_results_['params'][clf.best_index_])
print("Score: %0.03f" % clf.best_score_)
# Out:
# Start time : 2017-07-18 09:42:47.061254
# Fitting 2 folds for each of 20 candidates, totalling 40 fits
# [CV] kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform
# [CV] kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform
# [CV] kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance
# [CV] kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance
# [CV] kneighborsclassifier__n_neighbors=2, kneighborsclassifier__weights=uniform
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=2, kneighborsclassifier__weights=uniform
# [CV] kneighborsclassifier__n_neighbors=2, kneighborsclassifier__weights=distance
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=2, kneighborsclassifier__weights=distance
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform
# [CV]  kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform, total=   0.5s
# [CV] kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    1.9s
# [CV] kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance
# [CV]  kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance, total=   0.5s
# [CV]  kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform, total=   1.0s
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance
# [CV]  kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance, total=   0.9s
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=4, kneighborsclassifier__weights=uniform
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=4, kneighborsclassifier__weights=uniform
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=4, kneighborsclassifier__weights=distance
# [CV] kneighborsclassifier__n_neighbors=4, kneighborsclassifier__weights=distance
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform
# [CV] kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=6, kneighborsclassifier__weights=uniform
# [CV] kneighborsclassifier__n_neighbors=6, kneighborsclassifier__weights=uniform
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=6, kneighborsclassifier__weights=distance
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=6, kneighborsclassifier__weights=distance
# [CV] kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance
# [CV] kneighborsclassifier__n_neighbors=8, kneighborsclassifier__weights=uniform
# [CV] kneighborsclassifier__n_neighbors=8, kneighborsclassifier__weights=uniform
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=8, kneighborsclassifier__weights=distance
# [CV] kneighborsclassifier__n_neighbors=8, kneighborsclassifier__weights=distance
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform
# [CV] kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV]  kneighborsclassifier__n_neighbors=2, kneighborsclassifier__weights=uniform, total=   0.9s
# [CV] kneighborsclassifier__n_neighbors=10, kneighborsclassifier__weights=uniform
# [CV]  kneighborsclassifier__n_neighbors=2, kneighborsclassifier__weights=distance, total=   1.1s
# [CV]  kneighborsclassifier__n_neighbors=2, kneighborsclassifier__weights=uniform, total=   0.5s
# [CV] kneighborsclassifier__n_neighbors=10, kneighborsclassifier__weights=uniform
# [CV] kneighborsclassifier__n_neighbors=10, kneighborsclassifier__weights=distance
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV]  kneighborsclassifier__n_neighbors=2, kneighborsclassifier__weights=distance, total=   0.5s
# [CV] kneighborsclassifier__n_neighbors=10, kneighborsclassifier__weights=distance
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV]  kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform, total=   1.1s
# [CV]  kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance, total=   1.0s
# [CV]  kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform, total=   0.5s
# [CV]  kneighborsclassifier__n_neighbors=4, kneighborsclassifier__weights=uniform, total=   1.1s
# [CV]  kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance, total=   0.6s
# [CV]  kneighborsclassifier__n_neighbors=4, kneighborsclassifier__weights=distance, total=   1.2s
# [CV]  kneighborsclassifier__n_neighbors=4, kneighborsclassifier__weights=uniform, total=   0.6s
# [CV]  kneighborsclassifier__n_neighbors=4, kneighborsclassifier__weights=distance, total=   0.6s
# [CV]  kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform, total=   1.3s
# [CV]  kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance, total=   1.3s
# [CV]  kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance, total=   0.6s
# [Parallel(n_jobs=-1)]: Done  19 out of  40 | elapsed:   32.5s remaining:   35.9s
# [CV]  kneighborsclassifier__n_neighbors=6, kneighborsclassifier__weights=uniform, total=   2.0s
# [CV]  kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform, total=   2.1s
# [CV]  kneighborsclassifier__n_neighbors=6, kneighborsclassifier__weights=distance, total=   1.9s
# [CV]  kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform, total=   0.5s
# [CV]  kneighborsclassifier__n_neighbors=8, kneighborsclassifier__weights=uniform, total=   2.4s
# [CV]  kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance, total=   1.8s
# [CV]  kneighborsclassifier__n_neighbors=8, kneighborsclassifier__weights=distance, total=   1.6s
# [CV]  kneighborsclassifier__n_neighbors=6, kneighborsclassifier__weights=distance, total=   0.8s
# [CV]  kneighborsclassifier__n_neighbors=6, kneighborsclassifier__weights=uniform, total=   0.7s
# [CV]  kneighborsclassifier__n_neighbors=8, kneighborsclassifier__weights=distance, total=   0.7s
# [CV]  kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform, total=   0.9s
# [CV]  kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance, total=   0.9s
# [CV]  kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform, total=   0.7s
# [CV]  kneighborsclassifier__n_neighbors=8, kneighborsclassifier__weights=uniform, total=   1.2s
# [CV]  kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance, total=   2.7s
# [CV]  kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform, total=   1.9s
# [CV]  kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance, total=   1.0s
# [CV]  kneighborsclassifier__n_neighbors=10, kneighborsclassifier__weights=uniform, total=   1.7s
# [CV]  kneighborsclassifier__n_neighbors=10, kneighborsclassifier__weights=distance, total=   1.7s
# [CV]  kneighborsclassifier__n_neighbors=10, kneighborsclassifier__weights=uniform, total=   0.7s
# [CV]  kneighborsclassifier__n_neighbors=10, kneighborsclassifier__weights=distance, total=   1.0s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   48.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   48.2s finished
# Start time: 2017-07-18 09:43:36.636055
# Time elapsed: 0:00:49.574801
#
# Best parameters set found on development set:
# {'kneighborsclassifier__n_neighbors': 3, 'kneighborsclassifier__weights': 'distance'}
# Score: 0.444

# %%
# Visualizing score per combination.

scores = clf.cv_results_['mean_test_score'].reshape((len(neighbors_range), len(weights)))
print("Mean scores:", '\n', scores)

stddev = clf.cv_results_['std_test_score'].reshape((len(neighbors_range), len(weights)))
print("Standard deviation:", '\n', stddev)

plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=0.3, right=0.8, bottom=0.3, top=0.8)
plt.imshow(scores, interpolation='nearest', cmap=plt.cm.hot, norm=MidpointNormalize(vmin=0.4, midpoint=0.5))
plt.xlabel('Weights')
plt.ylabel('Quantity of neighbors')
plt.colorbar()
plt.xticks(np.arange(len(weights)), weights, rotation=45)
plt.yticks(np.arange(len(neighbors_range)), neighbors_range)
plt.title('Validation accuracy')
plt.show()
# Out:
# Mean scores:
#  [[ 0.43287755  0.43287755]
#  [ 0.3713089   0.43287755]
#  [ 0.43296957  0.44418977]
#  [ 0.41575894  0.43652212]
#  [ 0.42777404  0.43759607]
#  [ 0.42439483  0.43507877]
#  [ 0.43397109  0.44223968]
#  [ 0.43188887  0.43546618]
#  [ 0.43168312  0.43673222]
#  [ 0.43292759  0.43779063]]
# Standard deviation:
#  [[ 0.05306998  0.05306998]
#  [ 0.03652771  0.05306998]
#  [ 0.05492204  0.0556055 ]
#  [ 0.05068141  0.05576447]
#  [ 0.05792345  0.05519431]
#  [ 0.06238307  0.06009015]
#  [ 0.0610098   0.0646613 ]
#  [ 0.06762013  0.06495347]
#  [ 0.06957426  0.07379238]
#  [ 0.07205636  0.06898426]]

# %%
# Selecting the best parameters and estimating success scores on test data.

best_n      = 3
best_weight = 'distance'

pipeline = make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=best_n, weights=best_weight))
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)

# %%
# Viewing validation results.

f1 = f1_score(y_test, y_pred, average='weighted')

conf = confusion_matrix(y_test, y_pred)
conf = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]  # Normalizes
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.gray, norm=Normalize(1, 0))
plt.xlabel('Predicted')
plt.ylabel('Data')
plt.colorbar()
labels = sorted(filtered_file['TECTONIC SETTING'].unique())
range_ = np.arange(len(labels))
plt.xticks(range_, labels, rotation=90)
plt.yticks(range_, labels)
plt.title('Validation accuracy')

print('f1:', str(f1))
print('Train data:', y_train.shape[0], 'Test data:', y_test.shape[0])
plt.show()
# Out:
# f1: 0.638279367332
# Train data: 40332 Test data: 6358

# %% [markdown]
# ### 3) Random forest

# %%
# Launching the grid search.

range_1 = np.arange(1, 5)
range_2 = np.arange(0.2, 0.9, 0.2)
# estimators_range = np.arange(10, 101, 20)
param_grid = dict(extratreesclassifier__min_samples_leaf=range_1,
                 extratreesclassifier__max_features=range_2)
pipeline = make_pipeline(StandardScaler(), ExtraTreesClassifier(class_weight='balanced', max_depth=40, n_estimators=90))
# print(pipeline.get_params().keys())
f1_scorer = make_scorer(f1_score, average='weighted')

start = datetime.datetime.now()
print("Start time :", start)

# Regular grid search.
# grid = GridSearchCV(pipeline, param_grid, cv=2, scoring=f1_scorer, n_jobs=-1, verbose=2)

# Grid search using file splitting.
cv = file_split_gen(filenames_train, n_out=8, n_splits=3, seed=64)
grid = GridSearchCV(pipeline, param_grid, cv=cv, scoring=f1_scorer, n_jobs=-1, verbose=2)

# Data fitting.
clf = grid.fit(X_train, y_train)  # Will take quite some time. View the progress on the console.

end = datetime.datetime.now()
print("Start time:", end)
print("Time elapsed:", end - start, '\n')

print("Best parameters set found on development set:")
print(clf.cv_results_['params'][clf.best_index_])
print("Score: %0.03f" % clf.best_score_)
# Out:
# Start time : 2017-07-14 15:25:43.512880
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV] extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=1
# [CV] extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=1
# [CV] extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=1
# [CV] extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=2
# [CV] extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=2
# [CV] extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=2
# [CV] extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=3
# [CV] extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=3
# [CV] extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=3
# [CV] extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=4
# [CV] extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=4
# [CV] extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=4
# [CV] extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=1
# [CV] extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=1
# [CV] extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=1
# [CV] extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=2
# [CV] extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=2
# [CV] extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=2
# [CV] extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=3
# [CV] extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=3
# [CV] extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=3
# [CV] extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=4
# [CV] extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=4
# [CV] extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=4
# [CV] extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=1
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=1
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=1
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=2
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=2
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV] extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=2
# [CV] extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=3
# [CV]  extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=3, total=   3.8s
# [CV]  extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=3, total=   4.1s
# [CV]  extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=2, total=   4.4s
# [CV]  extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=2, total=   4.7s
# [CV] extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=3
# [CV]  extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=1, total=   5.4s
# [CV]  extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=1, total=   5.2s
# [CV]  extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=1, total=   5.3s
# [CV] extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=3
# [CV] extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=4
# [CV]  extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=2, total=   4.8s
# [CV] extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=4
# [CV] extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=4
# [CV]  extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=4, total=   3.8s
# [CV] extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=1
# [CV] extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=1
# [CV]  extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=4, total=   3.9s
# [CV]  extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=4, total=   4.1s
# [CV]  extratreesclassifier__max_features=0.2, extratreesclassifier__min_samples_leaf=3, total=   4.3s
# [CV] extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=1
# [Parallel(n_jobs=-1)]: Done  10 out of  48 | elapsed:    9.0s remaining:   34.1s
# [CV] extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=2
# [CV] extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=2
# [CV] extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=2
# [CV] extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=3
# [CV] extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=3
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV]  extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=3, total=   6.1s
# [CV] extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=3
# [CV]  extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=1, total=   8.0s
# [CV]  extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=4, total=   5.8s
# [CV]  extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=4, total=   6.1s
# [CV]  extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=2, total=   7.4s
# [CV]  extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=1, total=   8.0s
# [CV] extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=4
# [CV]  extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=2, total=   7.5s
# [CV]  extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=4, total=   6.1s
# [CV] extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=4
# [CV]  extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=3, total=   7.0s
# [CV] extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=4
# [CV]  extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=1, total=   8.3s
# [CV]  extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=2, total=   8.1s
# [CV]  extratreesclassifier__max_features=0.4, extratreesclassifier__min_samples_leaf=3, total=   6.9s
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV]  extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=3, total=   7.1s
# [CV]  extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=2, total=   8.2s
# [CV]  extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=4, total=   6.7s
# [CV]  extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=4, total=   7.1s
# [CV]  extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=3, total=   7.8s
# [CV]  extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=3, total=   7.8s
# [CV]  extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=2, total=   8.4s
# [CV]  extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=2, total=   8.5s
# [CV]  extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=1, total=   9.3s
# [CV]  extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=1, total=   9.4s
# [CV]  extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=1, total=   9.8s
# [Parallel(n_jobs=-1)]: Done  35 out of  48 | elapsed:   16.9s remaining:    6.3s
# [CV]  extratreesclassifier__max_features=0.6, extratreesclassifier__min_samples_leaf=4, total=   7.7s
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV]  extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=2, total=   9.5s
# [CV]  extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=2, total=   9.6s
# [CV]  extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=1, total=  10.4s
# [CV]  extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=1, total=  10.6s
# [CV]  extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=2, total=   9.1s
# [CV]  extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=1, total=  10.2s
# [CV]  extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=3, total=   9.2s
# [CV]  extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=3, total=   9.2s
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV]  extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=3, total=   8.3s
# [CV]  extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=4, total=   7.9s
# [CV]  extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=4, total=   7.9s
# [CV]  extratreesclassifier__max_features=0.8, extratreesclassifier__min_samples_leaf=4, total=   7.4s
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:   22.2s finished
# Start time: 2017-07-14 15:26:12.857502
# Time elapsed: 0:00:29.344622
#
# Best parameters set found on development set:
# {'extratreesclassifier__max_features': 0.40000000000000002, 'extratreesclassifier__min_samples_leaf': 1}
# Score: 0.662

# %%
# Visualizing score per combination.

scores = clf.cv_results_['mean_test_score'].reshape((len(range_2), len(range_1)))
print("Mean scores:", '\n', scores)

stddev = clf.cv_results_['std_test_score'].reshape((len(range_2), len(range_1)))
print("Standard deviation:", '\n', stddev)

plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=0.3, right=0.8, bottom=0.3, top=0.8)
plt.imshow(scores, interpolation='nearest', cmap=plt.cm.hot, norm=MidpointNormalize(vmin=0.4, midpoint=0.8))
plt.xlabel('2')
plt.ylabel('1')
plt.colorbar()
plt.xticks(np.arange(len(range_1)), range_1, rotation=45)
plt.yticks(np.arange(len(range_2)), range_2)
plt.title('Validation accuracy')
plt.show()
# Out:
# Mean scores:
#  [[ 0.65870629  0.65516619  0.63284434  0.620671  ]
#  [ 0.66217092  0.65555317  0.64668071  0.64293153]
#  [ 0.65805937  0.65681794  0.65363806  0.64183742]
#  [ 0.65689514  0.66146528  0.65216889  0.64360717]]
# Standard deviation:
#  [[ 0.06032164  0.06439582  0.06813206  0.07129212]
#  [ 0.05578691  0.07253315  0.07116052  0.06788045]
#  [ 0.06144188  0.06936749  0.07607089  0.06970607]
#  [ 0.06262407  0.07076913  0.0732647   0.07757996]]

# %%
# Selecting the best parameters and estimating success scores on test data.

best_depth      = 50
best_estimators = 100
best_leaf       = 3
best_features   = 0.8

clf = ExtraTreesClassifier(max_depth=best_depth, 
                           n_estimators=best_estimators, 
                           min_samples_leaf=best_leaf, 
                           max_features=best_features,  
                           class_weight='balanced')
pipeline = make_pipeline(StandardScaler(), clf)
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)

# %%
# Viewing validation results.

f1 = f1_score(y_test, y_pred, average='weighted')

conf = confusion_matrix(y_test, y_pred)
conf = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]  # Normalizes
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.gray, norm=Normalize(1, 0))
plt.xlabel('Predicted')
plt.ylabel('Data')
plt.colorbar()
labels = sorted(filtered_file['TECTONIC SETTING'].unique())
range_ = np.arange(len(labels))
plt.xticks(range_, labels, rotation=90)
plt.yticks(range_, labels)
plt.title('Validation accuracy')

print('f1:', str(f1))
print('Train data:', y_train.shape[0], 'Test data:', y_test.shape[0])
plt.show()
# Out:
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide
# f1: 0.610512581032
# Train data: 39923 Test data: 6769

# %%
# Importance of each element regarding classification.

feature_importance = clf.feature_importances_
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
plt.subplot(1, 2, 2)
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, filtered_file.iloc[:, 28:-1].axes[1].values[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()

# %% [markdown]
# ### 4) Deep learning - sklearn's Perceptron

# %%
# Launching the grid search.

range_1 = [(40,) * 3, (50,) * 3, (60,) * 3]
range_2 = 10.0 ** np.arange(-4, -3)
param_grid = dict(mlpclassifier__hidden_layer_sizes=range_1,
                  mlpclassifier__alpha=range_2)
pipeline = make_pipeline(StandardScaler(), MLPClassifier(tol=5 * 10e-3))
# print(pipeline.get_params().keys())
f1_scorer = make_scorer(f1_score, average='weighted')

start = datetime.datetime.now()
print("Start time :", start)

# Regular grid search.
# grid = GridSearchCV(pipeline, param_grid, cv=2, scoring=f1_scorer, n_jobs=-1, verbose=2)

# Grid search using file splitting.
cv = file_split_gen(filenames_train, n_out=12, n_splits=2, seed=64)
grid = GridSearchCV(pipeline, param_grid, cv=cv, scoring=f1_scorer, n_jobs=-1, verbose=2)

# Data fitting.
clf = grid.fit(X_train, y_train)  # Will take quite some time. View the progress on the console.

end = datetime.datetime.now()
print("Start time:", end)
print("Time elapsed:", end - start, '\n')

print("Best parameters set found on development set:")
print(clf.cv_results_['params'][clf.best_index_])
print("Score: %0.03f" % clf.best_score_)
# Out:
# Start time : 2017-07-17 17:14:24.237638
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# [CV] mlpclassifier__alpha=0.0001, mlpclassifier__hidden_layer_sizes=(40, 40, 40)
# [CV] mlpclassifier__alpha=0.0001, mlpclassifier__hidden_layer_sizes=(40, 40, 40)
# [CV] mlpclassifier__alpha=0.0001, mlpclassifier__hidden_layer_sizes=(50, 50, 50)
# [CV] mlpclassifier__alpha=0.0001, mlpclassifier__hidden_layer_sizes=(50, 50, 50)
# [CV] mlpclassifier__alpha=0.0001, mlpclassifier__hidden_layer_sizes=(60, 60, 60)
# [CV] mlpclassifier__alpha=0.0001, mlpclassifier__hidden_layer_sizes=(60, 60, 60)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV]  mlpclassifier__alpha=0.0001, mlpclassifier__hidden_layer_sizes=(40, 40, 40), total=   9.6s
# [CV]  mlpclassifier__alpha=0.0001, mlpclassifier__hidden_layer_sizes=(40, 40, 40), total=  11.4s
# [CV]  mlpclassifier__alpha=0.0001, mlpclassifier__hidden_layer_sizes=(50, 50, 50), total=  11.4s
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:   14.0s remaining:   14.0s
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [CV]  mlpclassifier__alpha=0.0001, mlpclassifier__hidden_layer_sizes=(50, 50, 50), total=  13.9s
# [CV]  mlpclassifier__alpha=0.0001, mlpclassifier__hidden_layer_sizes=(60, 60, 60), total=  13.6s
# [CV]  mlpclassifier__alpha=0.0001, mlpclassifier__hidden_layer_sizes=(60, 60, 60), total=  13.6s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:   15.8s finished
# Start time: 2017-07-17 17:14:44.403159
# Time elapsed: 0:00:20.165521
#
# Best parameters set found on development set:
# {'mlpclassifier__alpha': 0.0001, 'mlpclassifier__hidden_layer_sizes': (60, 60, 60)}
# Score: 0.627

# %%
# Visualizing score per combination.

scores = clf.cv_results_['mean_test_score'].reshape((len(range_2), len(range_1)))
print("Mean scores:", '\n', scores)

stddev = clf.cv_results_['std_test_score'].reshape((len(range_2), len(range_1)))
print("Standard deviation:", '\n', stddev)

plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=0.3, right=0.8, bottom=0.3, top=0.8)
plt.imshow(scores, interpolation='nearest', cmap=plt.cm.hot, norm=MidpointNormalize(vmin=0.4, midpoint=0.8))
plt.xlabel('2')
plt.ylabel('1')
plt.colorbar()
plt.xticks(np.arange(len(range_1)), range_1, rotation=45)
plt.yticks(np.arange(len(range_2)), range_2)
plt.title('Validation accuracy')
plt.show()
# Out:
# Mean scores:
#  [[ 0.6206957   0.62055463  0.62737224]]
# Standard deviation:
#  [[ 0.04403756  0.036548    0.05289003]]

# %%
# Selecting the best parameters and estimating success scores on test data.

best_layers = (60,) * 3
best_alpha  = 0.0001

clf = MLPClassifier(hidden_layer_sizes=best_layers, alpha=best_alpha, tol=5 * 10e-3)
pipeline = make_pipeline(StandardScaler(), clf)
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)

# %%
# Viewing validation results.

f1 = f1_score(y_test, y_pred, average='weighted')

conf = confusion_matrix(y_test, y_pred)
conf = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]  # Normalizes
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.gray, norm=Normalize(1, 0))
plt.xlabel('Predicted')
plt.ylabel('Data')
plt.colorbar()
labels = sorted(filtered_file['TECTONIC SETTING'].unique())
range_ = np.arange(len(labels))
plt.xticks(range_, labels, rotation=90)
plt.yticks(range_, labels)
plt.title('Validation accuracy')

print('f1:', str(f1))
print('Train data:', y_train.shape[0], 'Test data:', y_test.shape[0])
plt.show()
# Out:
# f1: 0.642691680677
# Train data: 42079 Test data: 4613

# %% [markdown]
# ### 5) Deep learning - TensorFlow

# %%
from tensorflow.contrib import learn
from tensorflow.contrib.learn.python.learn.estimators import model_fn as model_fn_lib

# %%
int_y_train, int_y_test = to_int(y_train), to_int(y_test)
oh_y_train, oh_y_test = one_hot(int_y_train), one_hot(int_y_test)
m_X_train, m_X_test = X_train.as_matrix().astype(np.float32), X_test.as_matrix().astype(np.float32)

nodes_in = filtered_file.shape[1] - 29
nodes_out = len(y_test.value_counts())
x = tf.placeholder('float', [None, nodes_in])
y = tf.placeholder('float')

# %% [markdown]
# Standard feedforward neural network:

# %%
# PARAMETERS #
nodes_1 = 800
nodes_2 = 800
epochs = 160
##############


def neural_network(input_):

    # Network

    l1 = {'weights': tf.Variable(tf.random_normal([nodes_in, nodes_1])),
          'biases':  tf.Variable(tf.random_normal([nodes_1]))}

    l2 = {'weights': tf.Variable(tf.random_normal([nodes_1, nodes_2])),
          'biases':  tf.Variable(tf.random_normal([nodes_2]))}

    out = {'weights': tf.Variable(tf.random_normal([nodes_2, nodes_out])),
           'biases':  tf.Variable(tf.random_normal([nodes_out]))}

    # Computing

    output_ = tf.add(tf.matmul(input_, l1['weights']), l1['biases'])
    output_ = tf.nn.sigmoid(output_)

    output_ = tf.add(tf.matmul(output_, l2['weights']), l2['biases'])
    output_ = tf.nn.sigmoid(output_)

    output_ = tf.add(tf.matmul(output_, out['weights']), out['biases'])

    return output_


def train_neural_network(data_X, data_y):
    prediction = neural_network(x)
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=prediction, labels=y))
    optimizer = tf.train.AdamOptimizer().minimize(cost)

    sess.run(tf.global_variables_initializer())

    for epoch in range(epochs):
        epoch_loss = 0
        _, c = sess.run([optimizer, cost], feed_dict={x: data_X, y: data_y})
        epoch_loss += c

        if epoch % 20 == 0:
            print('Epoch', epoch, 'completed out of', epochs, 'loss:', epoch_loss)

    prediction = tf.argmax(prediction, 1)
    correct = tf.equal(prediction, tf.argmax(y, 1))
    accuracy = tf.reduce_mean(tf.cast(correct, 'float'))

    return accuracy, prediction

# %%
try:
    sess.close()
except:
    pass

sess = tf.Session()
accuracy, prediction = train_neural_network(X_train, oh_y_train)

print('DONE.')
# Out:
# Epoch 0 completed out of 160 loss: 30.3016090393
# Epoch 20 completed out of 160 loss: 6.20601511002
# Epoch 40 completed out of 160 loss: 4.08385515213
# Epoch 60 completed out of 160 loss: 3.26419329643
# Epoch 80 completed out of 160 loss: 2.85150980949
# Epoch 100 completed out of 160 loss: 2.58473610878
# Epoch 120 completed out of 160 loss: 2.38874554634
# Epoch 140 completed out of 160 loss: 2.23285007477
# DONE.

# %%
with sess.as_default():
    print('Accuracy:', accuracy.eval({x: X_test, y: oh_y_test}))
    y_pred = prediction.eval(feed_dict={x: X_test})
    conf = tf.confusion_matrix(int_y_test.as_matrix(), y_pred).eval()

    # Viewing validation results.

    conf = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]  # Normalizes
    plt.imshow(conf, interpolation='nearest', cmap=plt.cm.gray, norm=Normalize(1, 0))
    plt.xlabel('Predicted')
    plt.ylabel('Data')
    plt.colorbar()
    labels = sorted(filtered_file['TECTONIC SETTING'].unique())
    range_ = np.arange(len(labels))
    plt.xticks(range_, labels, rotation=90)
    plt.yticks(range_, labels)
    plt.title('Validation accuracy')

    print('Train data:', y_train.shape[0], 'Test data:', y_test.shape[0])
    plt.show()
# Out:
# Accuracy: 0.445517
# Train data: 37779 Test data: 8911

# %% [markdown]
# Convolutional neural network:

# %%
def neural_network(features, labels, mode):
    # Input Layer
    input_layer = tf.reshape(features, [-1, nodes_in, 1])

    # Convolutional Layer #1 and Pooling Layer #1
    conv1 = tf.layers.conv1d(
        inputs=input_layer,
        filters=32,
        kernel_size=5,
        padding="same",
        activation=tf.nn.relu)
    pool1 = tf.layers.max_pooling1d(inputs=conv1, pool_size=2, strides=2)

    # Convolutional Layer #2 and Pooling Layer #2
    conv2 = tf.layers.conv1d(
        inputs=pool1,
        filters=64,
        kernel_size=5,
        padding="same",
        activation=tf.nn.relu)
    pool2 = tf.layers.max_pooling1d(inputs=conv2, pool_size=2, strides=2)

    # Dense Layer
    pool2_flat = tf.reshape(pool2, [-1, 5 * 64])
    dense = tf.layers.dense(inputs=pool2_flat, units=1024, activation=tf.nn.relu)
    dropout = tf.layers.dropout(
        inputs=dense, rate=0.4, training=mode == learn.ModeKeys.TRAIN)

    # Logits Layer
    logits = tf.layers.dense(inputs=dropout, units=10)

    loss = None
    train_op = None

    # Calculate Loss (for both TRAIN and EVAL modes)
    if mode != learn.ModeKeys.INFER:
        onehot_labels = tf.one_hot(indices=tf.cast(labels, tf.int32), depth=10)
        loss = tf.losses.softmax_cross_entropy(
            onehot_labels=onehot_labels, logits=logits)

    # Configure the Training Op (for TRAIN mode)
    if mode == learn.ModeKeys.TRAIN:
          train_op = tf.contrib.layers.optimize_loss(
          loss=loss,
          global_step=tf.contrib.framework.get_global_step(),
          learning_rate=0.001,
          optimizer="SGD")

    # Generate Predictions
    predictions = {
        "classes": tf.argmax(
            input=logits, axis=1),
        "probabilities": tf.nn.softmax(
            logits, name="softmax_tensor")
    }

    # Return a ModelFnOps object
    return model_fn_lib.ModelFnOps(
        mode=mode, predictions=predictions, loss=loss, train_op=train_op)


classifier = learn.Estimator(
     model_fn=neural_network, model_dir="/tmp/model_00")

# Train the model
classifier.fit(
    x=m_X_train,
    y=int_y_train,
    batch_size=1000,
    steps=1);
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f8c3466eb70>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': None}
# WARNING:tensorflow:From <ipython-input-121-050b732b794e>:70: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-121-050b732b794e>:70: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-121-050b732b794e>:70: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with batch_size is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/model_00/model.ckpt.
# INFO:tensorflow:loss = 68.1822, step = 1
# INFO:tensorflow:global_step/sec: 22.4411
# INFO:tensorflow:loss = 1.59455, step = 101 (4.459 sec)
# INFO:tensorflow:global_step/sec: 21.9517
# INFO:tensorflow:loss = 1.58004, step = 201 (4.558 sec)
# INFO:tensorflow:global_step/sec: 22.031
# INFO:tensorflow:loss = 1.40401, step = 301 (4.537 sec)
# INFO:tensorflow:global_step/sec: 21.9205
# INFO:tensorflow:loss = 1.39635, step = 401 (4.561 sec)
# INFO:tensorflow:global_step/sec: 22.1298
# INFO:tensorflow:loss = 1.31854, step = 501 (4.520 sec)
# INFO:tensorflow:global_step/sec: 21.8812
# INFO:tensorflow:loss = 1.29475, step = 601 (4.569 sec)
# INFO:tensorflow:global_step/sec: 22.1733
# INFO:tensorflow:loss = 1.29815, step = 701 (4.510 sec)
# INFO:tensorflow:global_step/sec: 21.9196
# INFO:tensorflow:loss = 1.24496, step = 801 (4.562 sec)
# INFO:tensorflow:global_step/sec: 21.9584
# INFO:tensorflow:loss = 1.29847, step = 901 (4.554 sec)
# INFO:tensorflow:global_step/sec: 22.336
# INFO:tensorflow:loss = 1.20391, step = 1001 (4.477 sec)
# INFO:tensorflow:global_step/sec: 22.1013
# INFO:tensorflow:loss = 0.657502, step = 119601 (4.525 sec)
# INFO:tensorflow:global_step/sec: 21.8985
# INFO:tensorflow:loss = 0.613464, step = 119701 (4.567 sec)
# INFO:tensorflow:global_step/sec: 21.6744
# INFO:tensorflow:loss = 0.652334, step = 119801 (4.614 sec)
# INFO:tensorflow:global_step/sec: 21.8777
# INFO:tensorflow:loss = 0.698645, step = 119901 (4.571 sec)
# INFO:tensorflow:Saving checkpoints for 120000 into /tmp/model_00/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.641189.

# %%
{'accuracy': 0.59232461, 'loss': 1.1490165, 'global_step': 10000}
{'accuracy': 0.60899651, 'loss': 1.1428412, 'global_step': 36235}
{'accuracy': 0.61984903, 'loss': 1.1337823, 'global_step': 46235}
{'accuracy': 0.61953443, 'loss': 1.1554782, 'global_step': 56235}
{'accuracy': 0.62488204, 'loss': 1.1921273, 'global_step': 76235}
{'accuracy': 0.63337529, 'loss': 1.2034205, 'global_step': 86235}
{'accuracy': 0.645486,   'loss': 1.2581534, 'global_step': 116235}
{'accuracy': 0.63101602, 'loss': 1.3505882, 'global_step': 136235}
{'accuracy': 0.6289714,  'loss': 1.3849444, 'global_step': 146235};

# %% [markdown]
# Specialized convolutional neural network:

# %%
def neural_network(features, labels, mode):
    # Input Layer
    input_layer = tf.reshape(features, [-1, nodes_in, 1])

    # Convolutional Layer #1 and Pooling Layer #1
    conv1 = tf.layers.conv1d(
        inputs=input_layer,
        filters=32,
        kernel_size=nodes_in,
        padding="same",
        activation=tf.nn.relu)
    pool1 = tf.layers.max_pooling1d(inputs=conv1, pool_size=2, strides=2)

    # Convolutional Layer #2 and Pooling Layer #2
    conv2 = tf.layers.conv1d(
        inputs=pool1,
        filters=32,
        kernel_size=int(2 * nodes_in / 3),
        padding="same",
        activation=tf.nn.relu)
    pool2 = tf.layers.max_pooling1d(inputs=conv2, pool_size=2, strides=2)

    # Convolutional Layer #3 and Pooling Layer #3
    conv3 = tf.layers.conv1d(
        inputs=pool1,
        filters=32,
        kernel_size=int(2 * nodes_in / 5),
        padding="same",
        activation=tf.nn.relu)
    pool3 = tf.layers.max_pooling1d(inputs=conv3, pool_size=2, strides=2)

    # Convolutional Layer #4 and Pooling Layer #4
    conv4 = tf.layers.conv1d(
        inputs=pool3,
        filters=32,
        kernel_size=int(1 * nodes_in / 5),
        padding="same",
        activation=tf.nn.relu)
    pool4 = tf.layers.max_pooling1d(inputs=conv4, pool_size=2, strides=2)

    # Dense Layer
    pool4_flat = tf.reshape(pool4, [-1, 64])
    dense = tf.layers.dense(inputs=pool4_flat, units=1024, activation=tf.nn.relu)
    dropout = tf.layers.dropout(
        inputs=dense, rate=0.4, training=mode == learn.ModeKeys.TRAIN)

    # Logits Layer
    logits = tf.layers.dense(inputs=dropout, units=10)

    loss = None
    train_op = None

    # Calculate Loss (for both TRAIN and EVAL modes)
    if mode != learn.ModeKeys.INFER:
        onehot_labels = tf.one_hot(indices=tf.cast(labels, tf.int32), depth=10)
        loss = tf.losses.softmax_cross_entropy(
            onehot_labels=onehot_labels, logits=logits)

    # Configure the Training Op (for TRAIN mode)
    if mode == learn.ModeKeys.TRAIN:
          train_op = tf.contrib.layers.optimize_loss(
          loss=loss,
          global_step=tf.contrib.framework.get_global_step(),
          learning_rate=0.001,
          optimizer="SGD")

    # Generate Predictions
    predictions = {
        "classes": tf.argmax(
            input=logits, axis=1),
        "probabilities": tf.nn.softmax(
            logits, name="softmax_tensor")
    }

    # Return a ModelFnOps object
    return model_fn_lib.ModelFnOps(
        mode=mode, predictions=predictions, loss=loss, train_op=train_op)


classifier = learn.Estimator(
      model_fn=neural_network, model_dir="/tmp/model_00")

# Train the model
classifier.fit(
    x=m_X_train,
    y=int_y_train,
    batch_size=1000,
    steps=1);
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f8c24145710>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': None}
# WARNING:tensorflow:From <ipython-input-83-a2ed2c80178b>:88: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-83-a2ed2c80178b>:88: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-83-a2ed2c80178b>:88: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with batch_size is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/model_1/model.ckpt-20001
# INFO:tensorflow:Saving checkpoints for 20002 into /tmp/model_1/model.ckpt.
# INFO:tensorflow:loss = 0.839306, step = 20002
# INFO:tensorflow:Loss for final step: 0.839306.
# WARNING:tensorflow:From <ipython-input-83-a2ed2c80178b>:91: calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# INFO:tensorflow:Restoring parameters from /tmp/model_1/model.ckpt-20002
# <generator object BaseEstimator._predict_generator at 0x7f8c24605678>

# %% [markdown]
# A: filter 16
# {'accuracy': 0.58210129, 'loss': 1.1463889, 'global_step': 10000}
# {'accuracy': 0.5805285,  'loss': 1.1905788, 'global_step': 20000}
# B: filter 32
# {'accuracy': 0.58383137, 'loss': 1.1549104, 'global_step': 10000}
# {'accuracy': 0.59169549, 'loss': 1.1536825, 'global_step': 20000}
# C: filter 4 on largest window
# {'accuracy': 0.58893502, 'loss': 1.0997757, 'global_step': 10000}
# {'accuracy': 0.58388507, 'loss': 1.1137487, 'global_step': 20001}

# %% [markdown]
# Analysis:

# %%
# Evaluate the model and print results
eval_results = classifier.predict(x=m_X_test)

# print('Accuracy:', accuracy.eval({x: X_test, y: oh_y_test}))
y_pred = pd.Series([i['classes'] for i in eval_results]).as_matrix()
with tf.Session():
    conf = tf.confusion_matrix(int_y_test.as_matrix(), y_pred).eval()

# Viewing validation results.

conf = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]  # Normalizes
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.gray, norm=Normalize(1, 0))
plt.xlabel('Predicted')
plt.ylabel('Data')
plt.colorbar()
labels = sorted(filtered_file['TECTONIC SETTING'].unique())
range_ = np.arange(len(labels))
plt.xticks(range_, labels, rotation=90)
plt.yticks(range_, labels)
plt.title('Validation accuracy')

print(f1_score(int_y_test.as_matrix(), y_pred, average='weighted'))
print('Train data:', y_train.shape[0], 'Test data:', y_test.shape[0])
plt.show()
# Out:
# WARNING:tensorflow:From <ipython-input-122-d4f687d11886>:2: calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# /home/CloudyOverhead/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# INFO:tensorflow:Restoring parameters from /tmp/model_00/model.ckpt-120000
# 0.633766778396
# Train data: 40332 Test data: 6358
